# %% [markdown]
# # Notes Maya remaining issues
#
# - Theory 2 does not seem to be included in the resultdata dataframe (and thus not in the analysis)
# - We have yet to integrate ~84 constructs from the updated LucidCharts
# - We have yet to finalize the mapping (review feb/march 2025)

# %% [markdown]
# ### Theory Integration
#
# We mapped constucts across a collection of behaviour change theories to ontologies in order to determine commonalities and show how these theories can be integrated.
#
# Here we parse the theory mapping and quantitatively analyse the results.

# %%
# conda activate ontos

! pip install openpyxl
! pip install pandas
! pip install py_horned_owl
! pip install whoosh
! pip install ontoutils
! pip install seaborn
# Out:
# Requirement already satisfied: openpyxl in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: pandas in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: py_horned_owl in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: whoosh in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (2.7.4)
# Requirement already satisfied: ontoutils in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (0.6.7)
# Requirement already satisfied: openpyxl in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from ontoutils) (3.1.5)
# Collecting argparse (from ontoutils)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: et-xmlfile in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from openpyxl->ontoutils) (1.1.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: seaborn in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# Prepare LucidChart files for further processing
import os 

theory_dir = 'theories_2025/processed'
theories = [file for file in os.listdir(theory_dir) if file.endswith(".csv")]

# %%
# First load the theory database
import TheoryDatabase
from TheoryDatabase import Theory, theories, Relation

TheoryDatabase.__init__("TheoryDatabase")
TheoryDatabase.setup()
theory_names = sorted(theories.keys())
# Out:
# About to parse theory:  1 Action Theory Model of Consumption
# Error parsing relation data:   124 Line Part of 5 26
# Error parsing relation data:   125 Line Part of 13 26
# Error parsing relation data:   126 Line Part of 17 26
# About to parse theory:  10 Containment Theory May 2020
# About to parse theory:  11 Control Theory
# Error parsing relation data:   24 Line  8
# About to parse theory:  12 Differential Association Theory
# About to parse theory:  13 Diffusion of Innovations
# Error parsing relation data:   187 Line
# About to parse theory:  14 Ecological Model for Preventing Type 2 Diabetes
# About to parse theory:  16 Extended parallel processing model
# About to parse theory:  17 Feedback Intervention Theory May 2020
# About to parse theory:  18 Focus Theory of Normative Conduct
# About to parse theory:  19 General Theory of Crime
# About to parse theory:  2 Affective Events Theory
# About to parse theory:  20 General Theory of Deviant Behaviour
# About to parse theory:  22 Goal-Framing Theory
# Error parsing relation data:   54 Line Type of 4 9
# Error parsing relation data:   55 Line Type of 9 8
# Error parsing relation data:   56 Line Type of 9 9
# Error parsing relation data:   58 Line Type of 5 9
# Error parsing relation data:   60 Line Type of 6 9
# About to parse theory:  23 Goal Setting theory
# About to parse theory:  24 Health Action Process Approach - for analysis
# About to parse theory:  25 Health Behaviour Goal Model May 2020
# About to parse theory:  26 Health Behaviour Internalisation Model
# About to parse theory:  27 Health Belief Model
# Error parsing relation data:   29 Line ​+ 13
# About to parse theory:  28 Health Promotion Model
# About to parse theory:  29 I-Change Model
# About to parse theory:  3 AIDS Risk Reduction Model
# About to parse theory:  30 Information-Motivation-Behavioural Skills Model
# About to parse theory:  31 Information-Motivation-Behavioural Skills Model of Adherence Behaviour
# About to parse theory:  32 Integrated Theoretical Model for Alcohol and Other Drug Abuse Prevention
# About to parse theory:  33 Integrated Theory of Drinking Behaviour
# About to parse theory:  34 Integrated Theory of Health Behaviour Change
# About to parse theory:  35 Integrative Model of Behavioural Prediction
# About to parse theory:  39 Model of Pro-Environmental Behavior
# About to parse theory:  4 Behavioural Ecological Model of AIDS Prevention
# About to parse theory:  40 Motivation-Opportunities-Abilities
# About to parse theory:  41 Needs-Opportunities-Abilities Model
# About to parse theory:  42 Norm Activation Theory
# About to parse theory:  43 Operant Conditioning
# About to parse theory:  44 Precaution Adoption Process Model
# About to parse theory:  45 Pressure System Model
# About to parse theory:  46 PRIME Theory
# About to parse theory:  47 Problem Behaviour Theory
# About to parse theory:  48 Prospect theory
# About to parse theory:  49 Protection Motivation Theory
# About to parse theory:  5 CEOS Theory
# About to parse theory:  50 Prototype willingness model
# About to parse theory:  51 Rational Addiction Model
# About to parse theory:  52 Reflective Impulsive Model
# About to parse theory:  53 Regulatory Fit Theory
# About to parse theory:  54 Relapse Prevention Theory
# About to parse theory:  55 Risk as Feelings Theory
# About to parse theory:  56 Self-determination theory
# About to parse theory:  57 Self-efficacy theory
# About to parse theory:  58 Self-Regulation Theory
# About to parse theory:  59 Six staged model of communication effects
# About to parse theory:  6 Change Theory
# About to parse theory:  60 Social Action Theory (Ewart)
# About to parse theory:  62 Social Change Theory
# About to parse theory:  63 Social Cognitive Theory
# About to parse theory:  64 Social consensus model of health education
# About to parse theory:  65 Social Development Model
# About to parse theory:  66 Social Ecological Model of Behaviour Change
# About to parse theory:  67 Social Ecological Model of Walking
# About to parse theory:  68 Social Identity Theory
# About to parse theory:  69 Social Influence Model
# About to parse theory:  70 Social Learning Theory
# About to parse theory:  71 Social Norms Theory
# About to parse theory:  72 Systems model of behaviour change
# About to parse theory:  73 Technology Acceptance Model
# About to parse theory:  74 Temporal Self-Regulation Theory
# About to parse theory:  75 Terror Management Theory
# About to parse theory:  76 Terror Management Health Model
# About to parse theory:  77 Theory of Interpersonal Behaviour
# About to parse theory:  78 Theory of Normative Social Behaviour
# About to parse theory:  79 Theory of Planned Behaviour
# About to parse theory:  8 COM-B
# About to parse theory:  80 Theory of Triadic Influence
# About to parse theory:  81 The Transcontextual Model of Motivation
# About to parse theory:  82 Transtheoretical Model of Behaviour Change
# About to parse theory:  83 Value Belief Norm Theory
# About to parse theory:  9 Consumption as social practices

# %%
import pandas as pd 

# Get construct names in the theory database to use for matching
theory_constrs = [{"Theory":t,"Construct":theories[t].constructs[c].name.strip()} for t in theories for c in theories[t].constructs]
df_theory_constrs = pd.DataFrame(theory_constrs)
df_theory_constrs
# Out:
#      Theory                                      Construct
# 0         1                                   Desirability
# 1         1                           Feasibility of goals
# 2         1                                 Goal intention
# 3         1                       Somatic marker processes
# 4         1  Previous emotional experiences with behaviour
# ...     ...                                            ...
# 1524      9                          Time-space structures
# 1525      9                                     Structures
# 1526      9                                     Lifestyles
# 1527      9                    Socio-technical innovations
# 1528      9                                  Social actors
#
# [1529 rows x 2 columns]

# %%
df_theory_constrs[df_theory_constrs["Theory"] == '24']
# Out:
#     Theory                  Construct
# 315     24              Self-efficacy
# 316     24                     Action
# 317     24     Recovery self-efficacy
# 318     24            Risk perception
# 319     24       Outcome expectancies
# 320     24  Maintenance self-efficacy
# 321     24         Perceived severity
# 322     24    Perceived vulnerability
# 323     24       Action self-efficacy
# 324     24                     Social
# 325     24                  Emotional
# 326     24                   Physical
# 327     24                  Intention
# 328     24                   Planning
# 329     24            Action planning
# 330     24   Perceived social support
# 331     24     Self-regulatory effort
# 332     24            Self-monitoring
# 333     24     Awareness of standards
# 334     24             Action control
# 335     24            Coping planning
# 336     24         Motivational phase
# 337     24           Volitional phase
# 338     24              Non-intenders
# 339     24                  Intenders
# 340     24                     Actors

# %%
import openpyxl
import pandas as pd

def parseConstructs(constructs_file):
    row_data = []
    out_of_scope_constructs = []  # List to store constructs that are "NotMappedOutOfScope" or "NotMappedUnclear"
    
    wb = openpyxl.load_workbook(constructs_file)
    sheet = wb['Sheet1']
    
    for row in sheet.iter_rows(min_row=2, min_col=0, max_row=1764, max_col=17):
        theory_num = row[0].value
        theory_name = row[1].value
        construct_name = row[2].value
        construct_defn = row[3].value
        ontology_id = row[5].value
        ontology_label = row[6].value
        alt_ontology_id = row[7].value
        alt_ontology_label = row[8].value
        alt_ontology_id2 = row[9].value
        alt_ontology_label2 = row[10].value
        alt_ontology_id3 = row[11].value
        alt_ontology_label3 = row[12].value
        mapping_notes = row[13].value  # after, skip two columns
        mapping_detail = row[16].value 

        if not (theory_num is None or construct_name is None):
            
            construct_name = construct_name.strip()
            query_result = df_theory_constrs.query(
            f"Theory == '{theory_num}' and Construct.str.lower() == '{construct_name.lower().replace("'", "").replace("\n", "")}'"
            )    
            
            if len(query_result) >= 1:
                if not (ontology_id is None or ontology_label is None):
                    theory_dict = {
                        "Theory_ID": theory_num,
                        "Theory_Name": theory_name,
                        "Construct": construct_name.strip(),
                        "Construct_Def": construct_defn,
                        "Ontology_ID": ontology_id.strip() if isinstance(ontology_id, str) else ontology_id,
                        "Ontology_Label": ontology_label.strip() if isinstance(ontology_label, str) else ontology_label,
                        "Alt_Ontology_ID": alt_ontology_id.strip() if alt_ontology_id else None,
                        "Alt_Ontology_Label": alt_ontology_label.strip() if alt_ontology_label else None,
                        "Alt_Ontology_ID_2": alt_ontology_id2.strip() if alt_ontology_id2 else None,
                        "Alt_Ontology_Label_2": alt_ontology_label2.strip() if alt_ontology_label2 else None,
                        "Alt_Ontology_ID_3": alt_ontology_id3.strip() if alt_ontology_id3 else None,
                        "Alt_Ontology_Label_3": alt_ontology_label3.strip() if alt_ontology_label3 else None,
                        "Mapping_Detail": mapping_detail
                    }
                    row_data.append(theory_dict)
                else:
                    if mapping_detail in ["NotMappedOutOfScope", "NotMappedUnclear"]:
                        # Save these constructs separately
                        out_of_scope_constructs.append({
                            "Theory_ID": theory_num,
                            "Theory_Name": theory_name,
                            "Construct": construct_name.strip(),
                            "Mapping_Detail": mapping_detail
                        })
                        
                    else:
                        print("Theory", theory_num, "and construct", construct_name, "have no annotations.")
            else: 
                print("Theory", theory_num, "and construct", construct_name, "do not appear to be in LucidChart.")
    
    df = pd.DataFrame(row_data)
    df_out_of_scope = pd.DataFrame(out_of_scope_constructs)  # Convert out-of-scope constructs to DataFrame
    
    return df, df_out_of_scope  # Return both DataFrames

# %%
#resultdata = parseConstructs("constructs/ConstructsOntologyMapping-20240819.xlsx")
resultdata, out_of_scope = parseConstructs("definitions/Final Constructs (Across Theory Mapping).xlsx")
#resultdata = parseConstructs("/Users/hastingj/Work/Python/TheoryDatabase/definitions/Final Constructs (Across Theory Mapping).xlsx")
# Out:
# Theory 4 and construct self-efficacy do not appear to be in LucidChart.
# Theory 4 and construct attitudes do not appear to be in LucidChart.
# Theory 4 and construct knowledge do not appear to be in LucidChart.
# Theory 4 and construct partner's sexual pleasure do not appear to be in LucidChart.
# Theory 5 and construct feelings do not appear to be in LucidChart.
# Theory 14 and construct community and environmental factors / environmental arm of the model do not appear to be in LucidChart.
# Theory 14 and construct cognitive factors (intrapersonal) / cognitive arm of the model do not appear to be in LucidChart.
# Theory 14 and construct incentive do not appear to be in LucidChart.
# Theory 22 and construct goal frame do not appear to be in LucidChart.
# Theory 29 and construct skills self-efficacy do not appear to be in LucidChart.
# Theory 29 and construct pros & cons (advantages/disadvantages) do not appear to be in LucidChart.
# Theory 29 and construct cognitive/rational pros & cons do not appear to be in LucidChart.
# Theory 29 and construct response efficacy / cognitive and emotional pros aresponse efficacy / cognitive and emotional pros and cons cons do not appear to be in LucidChart.
# Theory 29 and construct emotional pros & cons do not appear to be in LucidChart.
# Theory 30 and construct motivation to comply with referent others' wishes do not appear to be in LucidChart.
# Theory 30 and construct beliefs about support beliefs about support / opposition from significant others/ opposition from significant others do not appear to be in LucidChart.
# Theory 30 and construct moderating variables do not appear to be in LucidChart.
# Theory 32 and construct motivation to change do not appear to be in LucidChart.
# Theory 33 and construct expectancies about alcohol's effects do not appear to be in LucidChart.
# Theory 41 and construct safety have no annotations.
# Theory 41 and construct spatial have no annotations.
# Theory 41 and construct privacy have no annotations.
# Theory 41 and construct status have no annotations.
# Theory 41 and construct social justice have no annotations.
# Theory 43 and construct operant conditioning do not appear to be in LucidChart.
# Theory 43 and construct operant extinction do not appear to be in LucidChart.
# Theory 43 and construct negative reinforcement do not appear to be in LucidChart.
# Theory 43 and construct positive punishment do not appear to be in LucidChart.
# Theory 43 and construct consequences do not appear to be in LucidChart.
# Theory 52 and construct truth values have no annotations.
# Theory 54 and construct bidirectional influence do not appear to be in LucidChart.
# Theory 56 and construct informational aspect do not appear to be in LucidChart.
# Theory 56 and construct intrapersonal events do not appear to be in LucidChart.
# Theory 58 and construct stages of the self-regulation process do not appear to be in LucidChart.
# Theory 63 and construct basic capabilities do not appear to be in LucidChart.
# Theory 63 and construct triadic reciprocality do not appear to be in LucidChart.
# Theory 65 and construct opportunities for involvement (prosocial / antisocial) do not appear to be in LucidChart.
# Theory 65 and construct reinforcement for involvement (prosocial / antisocial) do not appear to be in LucidChart.
# Theory 65 and construct association with non-delinquent peers do not appear to be in LucidChart.
# Theory 65 and construct non-delinquent behaviour do not appear to be in LucidChart.
# Theory 79 and construct control beliefs do not appear to be in LucidChart.
# Theory 82 and construct maintenance do not appear to be in LucidChart.
# Theory 82 and construct preparation do not appear to be in LucidChart.
# Theory 82 and construct contemplation do not appear to be in LucidChart.
# Theory 82 and construct action do not appear to be in LucidChart.
# Theory 82 and construct precontemplation do not appear to be in LucidChart.
# Theory 83 and construct personal values do not appear to be in LucidChart.

# %%
# Create a check: Which LucidChart Constructs are not in the Mapping Spreadsheet

for theory_id in theories:
    theory = theories[theory_id]
    # Convert construct names in resultdata to lowercase for case-insensitive matching
    construct_mapping_list = resultdata.loc[resultdata["Theory_ID"] == pd.to_numeric(theory_id), "Construct"].str.lower().tolist()
    out_of_scope_list = out_of_scope.loc[out_of_scope["Theory_ID"] == pd.to_numeric(theory_id), "Construct"].str.lower().tolist()
    construct_list = construct_mapping_list + out_of_scope_list
    #print(out_of_scope_list)
    for construct in theory.constructs.values():
        # Convert construct.name to lowercase before checking
        if construct.name.lower() not in construct_list:
            print("In theory", theory_id, construct.name, "does not appear to be in the mapping spreadsheet")
# Out:
# In theory 1 Antecedents of goal-directed behaviour does not appear to be in the mapping spreadsheet
# In theory 11 General course of action / senses does not appear to be in the mapping spreadsheet
# In theory 14  does not appear to be in the mapping spreadsheet
# In theory 14 Internal incentive does not appear to be in the mapping spreadsheet
# In theory 14 Cognitive factors  (intrapersonal) / cognitive arm of the model does not appear to be in the mapping spreadsheet
# In theory 14 Community and environmental factors  / Environmental arm of the model does not appear to be in the mapping spreadsheet
# In theory 14 External incentives does not appear to be in the mapping spreadsheet
# In theory 22 Hedonic does not appear to be in the mapping spreadsheet
# In theory 22 Goals does not appear to be in the mapping spreadsheet
# In theory 22 Behaviour does not appear to be in the mapping spreadsheet
# In theory 22 Principles, values, norms does not appear to be in the mapping spreadsheet
# In theory 22 Situational factors does not appear to be in the mapping spreadsheet
# In theory 22 Self-enhancement values does not appear to be in the mapping spreadsheet
# In theory 22 Self-transcendence values does not appear to be in the mapping spreadsheet
# In theory 22 Egoistic values does not appear to be in the mapping spreadsheet
# In theory 22 Altruistic values does not appear to be in the mapping spreadsheet
# In theory 22 Biospheric values does not appear to be in the mapping spreadsheet
# In theory 22 Symbols does not appear to be in the mapping spreadsheet
# In theory 22 Injunctive norms does not appear to be in the mapping spreadsheet
# In theory 22 Costliness of behaviour does not appear to be in the mapping spreadsheet
# In theory 29 Motivation factors does not appear to be in the mapping spreadsheet
# In theory 29 Response efficacy / cognitive and emotional pros and cons does not appear to be in the mapping spreadsheet
# In theory 29 Performance skills does not appear to be in the mapping spreadsheet
# In theory 29 Plan enactment does not appear to be in the mapping spreadsheet
# In theory 29 Cognizance does not appear to be in the mapping spreadsheet
# In theory 29 Personal does not appear to be in the mapping spreadsheet
# In theory 29 Action planning does not appear to be in the mapping spreadsheet
# In theory 29 Coping planning does not appear to be in the mapping spreadsheet
# In theory 30 Beliefs about support / opposition from significant others does not appear to be in the mapping spreadsheet
# In theory 30 Motivation to comply with referent others' wishes does not appear to be in the mapping spreadsheet
# In theory 30 Complexity of AIDS preventive behaviour does not appear to be in the mapping spreadsheet
# In theory 31 Moderating variables does not appear to be in the mapping spreadsheet
# In theory 32 Motivation to  change does not appear to be in the mapping spreadsheet
# In theory 33 Expectancies about alcohol's effects does not appear to be in the mapping spreadsheet
# In theory 4 Risk behaviours does not appear to be in the mapping spreadsheet
# In theory 4 Delinquency does not appear to be in the mapping spreadsheet
# In theory 4 High-risk sports does not appear to be in the mapping spreadsheet
# In theory 4 Condom use / sexual behaviour does not appear to be in the mapping spreadsheet
# In theory 4 Partner's sexual pleasure does not appear to be in the mapping spreadsheet
# In theory 4 Peer / social reactions does not appear to be in the mapping spreadsheet
# In theory 4 Minor discomfort does not appear to be in the mapping spreadsheet
# In theory 4 Decreased sensitivity does not appear to be in the mapping spreadsheet
# In theory 41 Status does not appear to be in the mapping spreadsheet
# In theory 41 Privacy does not appear to be in the mapping spreadsheet
# In theory 41 Safety does not appear to be in the mapping spreadsheet
# In theory 41 Social justice does not appear to be in the mapping spreadsheet
# In theory 41 Spatial does not appear to be in the mapping spreadsheet
# In theory 42 Social does not appear to be in the mapping spreadsheet
# In theory 42 Accountability does not appear to be in the mapping spreadsheet
# In theory 42 Arousal of some sense of responsibility to respond does not appear to be in the mapping spreadsheet
# In theory 42 Activation of norms does not appear to be in the mapping spreadsheet
# In theory 43 Neutral stimuli does not appear to be in the mapping spreadsheet
# In theory 43 Extinction does not appear to be in the mapping spreadsheet
# In theory 43 Primary reinforcer does not appear to be in the mapping spreadsheet
# In theory 43 Multiple primary reinforcers does not appear to be in the mapping spreadsheet
# In theory 43 Response cost does not appear to be in the mapping spreadsheet
# In theory 43 Shaping and chaining does not appear to be in the mapping spreadsheet
# In theory 43 Stimulus and situational generalisation does not appear to be in the mapping spreadsheet
# In theory 43 Skill performance deficits does not appear to be in the mapping spreadsheet
# In theory 43 Response generalisation does not appear to be in the mapping spreadsheet
# In theory 5 Action generation does not appear to be in the mapping spreadsheet
# In theory 5 Physical states does not appear to be in the mapping spreadsheet
# In theory 5 Decisions, plans and scripts does not appear to be in the mapping spreadsheet
# In theory 5 Conscious analysis and interpretation of inputs does not appear to be in the mapping spreadsheet
# In theory 5 Impulses does not appear to be in the mapping spreadsheet
# In theory 52 Truth values does not appear to be in the mapping spreadsheet
# In theory 54 Self-regulation does not appear to be in the mapping spreadsheet
# In theory 56 Supports does not appear to be in the mapping spreadsheet
# In theory 56 Frustration of needs does not appear to be in the mapping spreadsheet
# In theory 56 Satisfaction / fulfillment of needs does not appear to be in the mapping spreadsheet
# In theory 56 Integrated regulation does not appear to be in the mapping spreadsheet
# In theory 56 Non-regulation does not appear to be in the mapping spreadsheet
# In theory 56 Social contexts does not appear to be in the mapping spreadsheet
# In theory 56 Behaviour does not appear to be in the mapping spreadsheet
# In theory 56 Thwarts does not appear to be in the mapping spreadsheet
# In theory 56 Autonomous motivation does not appear to be in the mapping spreadsheet
# In theory 58 Behaviour does not appear to be in the mapping spreadsheet
# In theory 58 Discrepancy does not appear to be in the mapping spreadsheet
# In theory 58 Self-reinforcement does not appear to be in the mapping spreadsheet
# In theory 58 Self-monitoring outcome does not appear to be in the mapping spreadsheet
# In theory 63 Outcome expectations does not appear to be in the mapping spreadsheet
# In theory 64  does not appear to be in the mapping spreadsheet
# In theory 65 Delinquent / non-delinquent Behaviour does not appear to be in the mapping spreadsheet
# In theory 65 Reinforcement for  involvement (prosocial / antisocial) does not appear to be in the mapping spreadsheet
# In theory 65 Opportunities for  involvement (prosocial / antisocial) does not appear to be in the mapping spreadsheet
# In theory 65 Sex does not appear to be in the mapping spreadsheet
# In theory 65 SES does not appear to be in the mapping spreadsheet
# In theory 65 Race does not appear to be in the mapping spreadsheet
# In theory 65 Communities does not appear to be in the mapping spreadsheet
# In theory 65 External constraints does not appear to be in the mapping spreadsheet
# In theory 65 Position in the social structure does not appear to be in the mapping spreadsheet
# In theory 65 Constitutional factors does not appear to be in the mapping spreadsheet
# In theory 68  does not appear to be in the mapping spreadsheet
# In theory 79 Behavioural belief strength does not appear to be in the mapping spreadsheet
# In theory 79 Behavioural belief composite does not appear to be in the mapping spreadsheet
# In theory 79 Normative beliefs composite does not appear to be in the mapping spreadsheet
# In theory 79 Control beliefs compoosite does not appear to be in the mapping spreadsheet
# In theory 79 Normative belief strength does not appear to be in the mapping spreadsheet
# In theory 79 Control belief strength does not appear to be in the mapping spreadsheet
# In theory 79 Control belief does not appear to be in the mapping spreadsheet
# In theory 82 Stage of change does not appear to be in the mapping spreadsheet
# In theory 82 Contemplation preparation transition does not appear to be in the mapping spreadsheet
# In theory 82 Preparation action transition does not appear to be in the mapping spreadsheet
# In theory 82 Precontemplation contemplation transition does not appear to be in the mapping spreadsheet
# In theory 82 Action maintenance transition does not appear to be in the mapping spreadsheet
# In theory 82 Self-efficacy temptation combination does not appear to be in the mapping spreadsheet
# In theory 83 Personal  values does not appear to be in the mapping spreadsheet
# In theory 83 Altruistic values does not appear to be in the mapping spreadsheet
# In theory 83 Biospheric values does not appear to be in the mapping spreadsheet

# %%
merged_lists = resultdata[['Ontology_ID', 'Alt_Ontology_ID', 'Alt_Ontology_ID_2', 'Alt_Ontology_ID_3']].apply(lambda row: row.tolist(), axis=1).tolist()
merged_lists = [ list(filter(lambda x: x is not None, l)) for l in merged_lists ]

#print(merged_lists)
print(len(merged_lists))

from collections import Counter

# Get the lengths of the inner lists
lengths = [len(l) for l in merged_lists]

# Use Counter to get the counts of each length
length_counts = Counter(lengths)

print(length_counts)
# Out:
# 1392
# Counter({4: 1255, 3: 119, 1: 14, 2: 4})

# %%
mapping_counts = resultdata['Mapping_Detail'].value_counts()

mapping_counts   # These don't seem to quite correspond to the final annotations -- things are flagged as 'not mapped' when sometimes they are.
# Out:
# Mapping_Detail
# WellMapped                        797
# MappedToBroaderTerm               348
# MultiplyMappedMultipleMeanings    101
# NotMappedOutOfScope                66
# NotMappedUnclear                   23
# MappingDoubted                     23
# MultiplyMappedBroadMeaning         20
# PartialMappingMultipleMeanings      5
# MultiplyMappedAmbiguousMeaning      4
# NotMappedONTOLOGYCLASSMISSING       1
# TO DO                               1
# Name: count, dtype: int64

# %%
import pyhornedowl

ontoname = "bcio.owl" # Downloaded from GitHub to the local directory

onto = pyhornedowl.open_ontology(ontoname)

prefixes = [ ["ADDICTO","http://addictovocab.org/ADDICTO_"],
             ["BFO","http://purl.obolibrary.org/obo/BFO_"],
             ["CHEBI","http://purl.obolibrary.org/obo/CHEBI_"],
             ["UBERON","http://purl.obolibrary.org/obo/UBERON_"],
             ["PATO","http://purl.obolibrary.org/obo/PATO_"],
             ["BCIO","http://humanbehaviourchange.org/ontology/BCIO_"],
             ["SEPIO","http://purl.obolibrary.org/obo/SEPIO_"],
             ["OMRSE","http://purl.obolibrary.org/obo/OMRSE_"],
             ["OBCS","http://purl.obolibrary.org/obo/OBCS_"],
             ["OGMS","http://purl.obolibrary.org/obo/OGMS_"],
             ["ENVO","http://purl.obolibrary.org/obo/ENVO_"],
             ["OBI", "http://purl.obolibrary.org/obo/OBI_"],
             ["MFOEM","http://purl.obolibrary.org/obo/MFOEM_"],
             ["MF","http://purl.obolibrary.org/obo/MF_"],
             ["CHMO","http://purl.obolibrary.org/obo/CHMO_"],
             ["DOID","http://purl.obolibrary.org/obo/DOID_"],
             ["IAO","http://purl.obolibrary.org/obo/IAO_"],
             ["ERO","http://purl.obolibrary.org/obo/ERO_"],
             ["PO","http://purl.obolibrary.org/obo/PO_"],
             ["RO","http://purl.obolibrary.org/obo/RO_"],
             ["APOLLO_SV","http://purl.obolibrary.org/obo/APOLLO_SV_"],
             ["PDRO","http://purl.obolibrary.org/obo/PDRO_"],
             ["GAZ","http://purl.obolibrary.org/obo/GAZ_"],
             ["GSSO","http://purl.obolibrary.org/obo/GSSO_"], 
             ["GO","http://purl.obolibrary.org/obo/GO_"],
             ["NBO","http://purl.obolibrary.org/obo/NBO_"],
             ["RBBO","https://purl.org/turbbo/RBBO_"],
             ["GMHO", "https://galenos.org.uk/ontologies/GMHO_"],
             ["PR", "http://purl.obolibrary.org/obo/PR_"],
             ["STATO", "http://purl.obolibrary.org/obo/STATO_"],
             ["CMO", "http://purl.obolibrary.org/obo/CMO_"],
             ["EFO", "http://www.ebi.ac.uk/efo/EFO_"],
             ["OMIABIS", "http://purl.obolibrary.org/obo/OMIABIS_"],
             ["OPMI", "http://purl.obolibrary.org/obo/OPMI_"],
             ["COB", "http://purl.obolibrary.org/obo/COB_"],
            ["SDGIO", "http://purl.unep.org/sdg/SDGIO_"]
           ]

RDFSLABEL = "http://www.w3.org/2000/01/rdf-schema#label"

for prefix in prefixes:
    onto.add_prefix_mapping(prefix[0],prefix[1])

print (f"Loaded ontology has {len(onto.get_classes())} classes.")
print (f"Loaded ontology has {len(onto.get_axioms())} axioms.")

for c in onto.get_classes():
    print(onto.get_id_for_iri(c),onto.get_annotation(c, RDFSLABEL))
# Out:
# Loaded ontology has 2504 classes.
# Loaded ontology has 16587 axioms.
# BCIO:010101 friend
# SDGIO:00010029 employment status
# BCIO:007055 demonstrate the behaviour BCT
# BCIO:036024 personal bodily care behaviour
# BCIO:015015 language proficiency
# BCIO:036075 harmful behaviour
# BCIO:006053 knowledge regarding a behaviour
# BCIO:015014 religious group membership
# BCIO:050377 e-cigarette use
# BCIO:015618 proportion personal history of intervention exposure for the same outcome behaviour population statistic
# ADDICTO:0001303 beneficial process
# BCIO:050553 communication recipient
# BCIO:011019 playable electronic storage mode of delivery
# BCIO:015120 foster parent
# BCIO:006030 belief about severity of an outcome
# BCIO:015442 independently wealthy status population statistic
# BCIO:044062 communication avoiding interrupting
# BCIO:010129 volunteering of person source
# BCIO:044079 active participation encouraging communication style
# BCIO:050413 providing healthcare
# BCIO:007053 re-attribute cause BCT
# BCIO:007202 promise positive consequence for behaviour BCT
# BCIO:006111 decision simplification
# BCIO:010080 assembler
# BCIO:006026 belief about likelihood of consequences of an occurrence
# BCIO:006116 decision-making
# BCIO:010025 teaching professional
# BCIO:015290 proportion discipline of current programme of study or training population statistic
# BCIO:026018 drug or alcohol rehabilitation facility
# ADDICTO:0000399 self-identity
# BFO:0000017 realizable
# BCIO:015443 percentage independently wealthy status population statistic
# BCIO:007182 inform about positive environmental consequences BCT
# BCIO:015457 percentage individual income population statistic
# BCIO:015446 mean individual human behaviour population statistic
# BCIO:050642 environmental opportunity for comfort
# BCIO:006000 behaviour change intervention mechanism of action
# BCIO:050565 amount of social reinforcement for a behaviour
# BCIO:009000 behaviour change intervention schedule of delivery
# BCIO:007168 advise specific behaviour BCT
# BCIO:050461 talking
# BCIO:015417 minimum human age population statistic
# BCIO:026041 transportation
# BCIO:015445 individual human behaviour population statistic
# BCIO:015370 percentage grandmother population statistic
# BCIO:050727 norms-related social environmental system
# BCIO:015273 child relation population statistic
# BCIO:015759 percentage stepson population statistic
# BCIO:050817 frequency of past behaviour
# BCIO:006127 episodic memory
# BCIO:050214 attentional self-regulation capability
# BCIO:007092 associative learning to extinguish behaviour BCT
# BCIO:015314 proportion employment status population statistic
# BCIO:007143 enable person to manage automatic responses BCT
# BCIO:007286 remove aversive consequence for behaviour BCT
# BCIO:026042 public transportation
# BCIO:015374 proportion grandparent population statistic
# BCIO:010091 masters student or trainee
# SDGIO:00010026 unemployed
# BCIO:015456 median individual income population statistic
# BCIO:015755 stepsister population statistic
# BCIO:007064 inform about social consequences BCT
# BCIO:050936 awareness of standards
# BCIO:006309 habit learning
# BCIO:015165 ability to speak in intervention language population statistic
# BCIO:026050 path or pavement for cyclists
# BCIO:050617 comparative desirability appraisal
# BCIO:007050 guide how to perform behaviour BCT
# BCIO:015785 unemployed status population statistic
# BCIO:006152 belief about control over behaviour
# BCIO:050591 belief about enablers of a behaviour
# BCIO:007190 promise to remove aversive consequence for behaviour BCT
# BCIO:015628 minimum personal history part of intervention exposure population statistic
# BCIO:015777 percentage uncle population statistic
# BCIO:044014 asking focused questions
# BCIO:007006 agree outcome goal BCT
# BCIO:015448 maximum individual human behaviour population statistic
# BCIO:007137 persuade about personal capability BCT
# BCIO:036032 bullying behaviour
# BCIO:028000 behaviour change intervention scenario plan
# BCIO:015645 percentage personal vulnerability population statistic
# BCIO:050951 willingness to cease behaviour
# BCIO:006163 targeted mental distancing
# BCIO:015636 maximum personal psychological attribute population statistic
# BCIO:015159 personal psychological attribute
# BCIO:050296 mechanism of action through environmental disposition
# BCIO:015704 proportion retired status population statistic
# BCIO:007275 provide reduced frequency of aversive material consequence for outcome of behaviour BCT
# BCIO:010009 medical doctor
# BCIO:050583 behavioural opportunity through information
# BCIO:031000 behaviour change intervention study sample
# BCIO:050835 response cost
# BCIO:050839 task complexity
# BCIO:050421 distress minimisation behaviour
# BCIO:007198 promise aversive social consequence for situation specific behaviour BCT
# BCIO:015394 percentage history of exposure to an occupational hazard population statistic
# BCIO:044123 warm communication style
# BCIO:007303 suggest how to perform behaviour BCT
# BCIO:006025 belief about likelihood of health consequences of behaviour
# MFOEM:000218 enjoyment
# BCIO:015327 female biological sex population statistic
# BCIO:015156 niece
# BCIO:015170 proportion ability to write in intervention language population statistic
# BCIO:015107 male biological sex
# MFOEM:000002 appraisal process
# BCIO:006109 feeling an urge
# BCIO:011042 injection mode of delivery
# BCIO:050957 organisational attribute
# MF:0000027 planning
# GAZ:00000448 geographic location
# BCIO:044107 intellectual communication style
# BCIO:015212 proportion adoptive sibling population statistic
# BCIO:050450 abstinence end point
# MF:0000033 mental disposition
# BCIO:050216 belief about anticipated regret
# BCIO:006088 healthcare access
# BCIO:006091 temporal behavioural opportunity
# BCIO:015226 percentage asexual population statistic
# BCIO:015685 percentage religious group membership population statistic
# BCIO:006034 belief about choice over a behaviour
# BCIO:050475 doctoral student role
# BCIO:015009 queer
# BCIO:050892 social grouping
# BCIO:015303 employed full time population statistic
# BCIO:050415 self-injecting consumption
# BCIO:015697 percentage renter of housing from a social provider population statistic
# MFOEM:000022 interpersonal disgust
# BCIO:011057 group-based mode of delivery
# BCIO:010037 social professional
# BCIO:015087 higher education student role
# BCIO:015440 percentage income-related welfare benefit population statistic
# BCIO:026035 arts and entertainment facility
# BCIO:015347 proportion foster mother population statistic
# BCIO:015210 adoptive sibling population statistic
# BCIO:050590 belief about emotional consequences of goal attainment
# BCIO:050213 professional network
# BCIO:050829 purchasing behaviour
# BCIO:010074 health care assistant
# BCIO:036041 mind-body behaviour
# BCIO:007119 imagine reward BCT
# BCIO:007084 reduce cue frequency BCTs
# BCIO:006099 social influence behaviour
# BCIO:050734 physiological need
# BCIO:010076 protective services worker
# GO:0007610 behavior
# BCIO:050403 undergoing vaccination
# BCIO:015085 school student role
# BCIO:044078 shifting focus of communication
# BCIO:010106 number of people delivering intervention to each participant
# BCIO:044061 interrupting
# BCIO:015019 ability to comprehend spoken intervention language
# BCIO:015680 proportion questioning sexual orientation population statistic
# BCIO:015283 percentage cousin population statistic
# BCIO:006065 need for autonomy
# BCIO:050732 person’s social environmental system
# BCIO:011050 temperature mode of delivery
# BCIO:015720 single population statistic
# BCIO:050867 imagination capability
# BCIO:050598 belief about social influence
# BCIO:015158 insured party role
# BCIO:018000 behaviour change intervention evaluation study
# BCIO:050844 action planning
# BCIO:015267 caste membership population statistic
# BCIO:015250 percentage biological sex population statistic
# BCIO:011062 push mode of delivery
# BCIO:037000 intervention
# BCIO:007098 overcorrect unwanted behaviour BCT
# BCIO:036021 creative expressive behaviour
# BCIO:050827 past occurrence of a target behaviour
# BCIO:050601 belief about task complexity
# BCIO:015497 masters student role population statistic
# BCIO:015556 proportion occupational role population statistic
# BCIO:050435 behavioural attribute
# BCIO:050946 mental rehearsal to guide and motivate behaviour
# BFO:0000019 quality
# BCIO:006060 motivational orientation
# BCIO:036100 individual human behaviour pattern
# BCIO:044021 communication acknowledging difficulties
# BCIO:050451 abstinence from a behaviour
# BCIO:027000 behaviour change intervention scenario report
# OPMI:0000326 status
# BCIO:015204 adoptive mother population statistic
# BCIO:015261 bisexual population statistic
# BCIO:026038 criminal justice facility
# BCIO:015321 family member population statistic
# BCIO:050463 high emotional management exertion expended on a behaviour
# BCIO:015285 disabled population statistic
# BCIO:007277 provide reduced frequency of aversive social consequence for behaviour BCT
# BCIO:015203 proportion adoptive father population statistic
# BCIO:015568 proportion outpatient role population statistic
# BCIO:050631 dissonance reduction process for a behaviour
# BCIO:015738 percentage step-sibling population statistic
# BCIO:007135 advise paradoxical behaviour BCT
# GO:0007613 memory
# BCIO:015555 percentage occupational role population statistic
# BCIO:050789 technology availability
# BCIO:050446 change outcome goal BCT
# BCIO:015772 proportion twin population statistic
# BCIO:050371 dressing behaviour
# BCIO:007099 generalise behaviour BCT
# BCIO:026040 military facility
# BCIO:044053 communication using slang
# BCIO:015413 percentage household income population statistic
# BCIO:010047 nursing and midwifery associate professional
# BCIO:015141 adoptive sister
# BCIO:015468 insured party role population statistic
# IAO:0000030 information content entity
# BCIO:015653 proportion personal vulnerability to harmful behaviour population statistic
# BCIO:011018 virtual reality mode of delivery
# BCIO:006090 social behavioural opportunity
# BCIO:050828 positive behavioural consequence
# BCIO:015058 self employed status
# BCIO:007056 reframe past behaviour BCT
# BCIO:050563 aesthetic appreciation disposition
# BCIO:006124 generalisation in learning
# BCIO:015747 percentage stepdaughter population statistic
# BCIO:015630 median personal history part of intervention exposure population statistic
# BCIO:050736 positive mental health
# BCIO:050745 propositional cognitive representation
# BCIO:007081 cue BCT
# BFO:0000182 history
# BCIO:015284 proportion cousin population statistic
# BCIO:015632 proportion personal history part of intervention exposure population statistic
# BCIO:036036 physical combat behaviour
# ENVO:01001813 construction
# BCIO:015545 proportion not seeking employment population statistic
# BCIO:007017 monitoring BCT
# BCIO:050375 non-linguistic communication behaviour using eye contact
# BCIO:050596 belief about severity of AIDS
# OGMS:0000060 bodily process
# BCIO:008000 behaviour change intervention delivery
# BCIO:015200 proportion adoptive daughter population statistic
# BCIO:050686 internal attribution of a behaviour
# BCIO:050782 stability of living conditions
# MFOEM:000169 satisfaction
# BCIO:015132 stepson
# BFO:0000001 entity
# BCIO:021000 behaviour change intervention evaluation report
# BCIO:006046 action schema
# BCIO:015487 proportion linguistic capability population statistic
# BCIO:050225 belief about ones physical environment
# BCIO:050443 experience-related behaviour
# BCIO:006103 self-regulation of behaviour
# BCIO:015121 foster mother
# BCIO:041000 human population
# BCIO:007278 provide reduced frequency of aversive social consequence for outcome of behaviour BCT
# BCIO:050585 belief about a behaviour meeting a need
# BCIO:050220 belief about likelihood of emotional consequences of behaviour
# BCIO:050393 intravenous self-injecting
# BCIO:007221 promise positive social consequence for completion of behavioural sequence BCT
# BCIO:015634 mean personal psychological attribute population statistic
# BCIO:015185 proportion achieved master's or equivalent level population statistic
# BCIO:026049 path or pavement for pedestrians
# BCIO:015729 maximum socioeconomic status score population statistic
# BCIO:006024 belief about likelihood of consequences of behaviour
# BCIO:050379 vaping device use
# BCIO:044105 impatient communication style
# BCIO:050316 subjective need
# BCIO:015343 percentage foster father population statistic
# BCIO:050474 disabled
# BCIO:015044 discipline of highest level of formal educational qualification achieved
# BCIO:015507 percentage member of a multi-person household all related population statistic
# BCIO:006003 friendship network
# BCIO:015768 percentage transgender population statistic
# BCIO:050616 communication skill
# BCIO:015449 median individual human behaviour population statistic
# BCIO:044071 reflective communication
# BCIO:015027 household income
# BCIO:007239 prompt thinking related to successful performance BCT
# BCIO:015018 ability to speak in intervention language
# BCIO:015422 proportion immigrant population statistic
# BCIO:011011 television mode of delivery
# BCIO:050358 reviewing prescribed medication
# BCIO:050235 non-judgmental acknowledgement
# BCIO:006149 belief about the personal desirability of consequences of a behaviour
# ADDICTO:0000179 personal stake
# BCIO:050397 social support behaviour
# SEPIO:0000125 research study
# BCIO:015264 caregiving role population statistic
# BCIO:044111 non-confrontational communication style
# BCIO:050592 belief about goal attainment
# BCIO:015463 percentage informal education student role population statistic
# BCIO:007260 provide positive material consequence for completion of behavioural sequence BCT
# BCIO:015694 percentage renter population statistic
# BCIO:050551 research study sample
# BCIO:050825 monitoring behaviour
# BFO:0000027 object aggregate
# BCIO:011035 ingestion mode of delivery
# BCIO:007014 create behavioural contract BCT
# BCIO:007295 remove positive material consequence for outcome of behaviour BCT
# BCIO:044026 communication checking for others' understanding
# BCIO:015397 percentage history of exposure to childhood maltreatment population statistic
# BCIO:015411 maximum household income population statistic
# BCIO:010119 psychological influence on intervention delivery of person source
# BCIO:015379 percentage health insurance policy holder role population statistic
# BCIO:050223 appraisal as caused by external non-human factors
# GO:0098596 imitative learning
# BCIO:050880 social consequence of behaviour appraisal process
# MFOEM:000195 affective process
# BCIO:007005 set outcome goal BCT
# BCIO:036054 excretion behaviour
# BCIO:007294 remove positive material consequence for behaviour BCT
# IAO:0000102 data about an ontology part
# BCIO:010082 armed forces occupation
# ENVO:01001784 compound astronomical body part
# BCIO:006119 associative learning
# BCIO:015098 gender identity
# BCIO:015301 percentage employed population statistic
# BCIO:050372 appearance-based bodily behaviour
# BCIO:015384 heterosexual population statistic
# BCIO:010121 knowledge or skill
# BCIO:015118 stepmother
# BCIO:011000 behaviour change intervention mode of delivery
# BCIO:015613 mean personal history of intervention exposure for the same outcome behaviour population statistic
# MF:0000018 attending
# BCIO:010107 total number of people able to deliver intervention
# BCIO:015515 member of a multi-person multi-generational household population statistic
# BCIO:050883 strength of group support for an intervention
# BCIO:011030 audio informational mode of delivery
# BCIO:015137 biological sibling
# BCIO:006113 dissonance reduction process
# BCIO:015498 percentage masters student role population statistic
# BCIO:015503 member of a multi-person household population statistic
# BCIO:026039 factory facility
# BCIO:011029 e-book mode of delivery
# BCIO:007065 inform about emotional consequences BCT
# BCIO:050641 environmental disposition that increases likelihood of harmful behaviour
# BCIO:044076 re-evaluation prompting reflective communication
# BCIO:050442 vocalisation behaviour
# BCIO:015464 proportion informal education student role population statistic
# BCIO:010098 sibling relationship
# BCIO:015136 sibling
# BCIO:010102 colleague
# BCIO:015472 percentage interpersonal role population statistic
# BCIO:050437 health-related behaviour
# BCIO:036001 human life function
# OMRSE:00000061 architectural structure
# BCIO:050834 regulatory behaviour
# BCIO:015364 percentage graduate student role population statistic
# BCIO:015800 percentage voluntary worker status population statistic
# BCIO:050943 group decision-making
# BCIO:010078 craft and related trades worker
# BCIO:015201 adoptive father population statistic
# BCIO:006047 decision
# BCIO:007058 instruct how to perform a behaviour BCT
# BFO:0000030 object
# BCIO:050557 social influence intervention through mass media
# BCIO:007290 remove aversive social consequence for behaviour BCT
# BCIO:015337 percentage foster child population statistic
# BCIO:015091 caste membership
# BCIO:007097 context-specific repetition of alternative behaviour BCT
# IAO:0000007 action specification
# BCIO:015217 percentage adoptive son population statistic
# BCIO:011034 somatic mode of delivery
# BCIO:050885 underestimated perceived descriptive norm
# BCIO:050778 social reinforcement process for a behaviour
# BCIO:036064 transporting behaviour
# BCIO:015309 employed part time population statistic
# BCIO:015183 achieved master's or equivalent level population statistic
# BCIO:007251 provide positive consequence for alternative behaviour BCT
# BCIO:044065 negotiation
# BCIO:036076 impulsiveness
# BCIO:010071 personal care worker
# BCIO:044054 communication using specialist language
# BCIO:050942 empathy
# BCIO:050802 approval seeking behaviour
# BCIO:015372 grandparent population statistic
# BFO:0000040 material entity
# BCIO:015016 ability to read in intervention language
# BCIO:007192 promise aversive material consequence for behaviour BCT
# BCIO:007140 prompt self-talk BCT
# BCIO:011023 video call mode of delivery
# BCIO:050783 stimulus
# BCIO:050684 intermittent schedule of reinforcement
# BFO:0000031 generically dependent continuant
# BCIO:006080 mental image
# BCIO:010038 psychologist
# BCIO:007012 attend to discrepancy between current behaviour and goal BCT
# BCIO:036073 avoidance behaviour
# BCIO:026026 secondary school
# BCIO:015219 adult population statistic
# BCIO:015644 median personal vulnerability population statistic
# BCIO:050606 belief about the positive emotional consequences of a behaviour
# BCIO:050722 negative reinforcer
# BCIO:011044 intravenous injection mode of delivery
# BCIO:015614 minimum personal history of intervention exposure for the same outcome behaviour population statistic
# BCIO:011053 wearable stimulus mode of delivery
# BCIO:015452 individual income population statistic
# BCIO:015523 minimum mental capability population statistic
# BCIO:015743 stepchild population statistic
# BCIO:034000 population behaviour
# BCIO:050209 individual human behaviour change
# BCIO:050360 providing healthcare advice
# BCIO:050681 intention for collective behaviour
# BCIO:050487 personal history part
# BCIO:006004 mental skill
# BCIO:010089 undergraduate student or trainee
# BCIO:050822 identity congruence
# BCIO:050570 attending to a goal
# BCIO:050886 extent of past behavioural achievement
# BCIO:015329 proportion female biological sex population statistic
# BCIO:025000 behaviour change intervention outcome estimate
# BCIO:011040 buccal mode of delivery
# BCIO:050777 social justice
# BCIO:015148 foster brother
# BCIO:015509 member of a multi-person household not related population statistic
# BCIO:007141 advise to keep behaviour goal in mind BCT
# BFO:0000006 spatial region
# BCIO:010079 plant and machine operator
# BCIO:007276 provide reduced frequency of aversive consequence for outcome of behaviour BCT
# BCIO:010032 music teacher
# OBI:0000260 plan
# BCIO:011045 intramuscular injection mode of delivery
# BCIO:007183 inform about positive health consequences BCT
# BCIO:015086 vocational training student or trainee role
# BCIO:050820 harm prevention
# BCIO:050925 dyad
# BCIO:044020 classroom-style discussion
# BCIO:015742 proportion stepbrother population statistic
# MFOEM:000056 sadness
# ADDICTO:0000381 identity
# BCIO:015511 proportion member of a multi-person household not related population statistic
# BCIO:010045 health associate professional
# BCIO:050338 advise sensory ways to increase positive emotions BCT
# BCIO:015222 agreed rent-free occupier population statistic
# BCIO:015436 in uncertain employment population statistic
# BCIO:050755 reinforcement process
# BCIO:044084 autonomy-supportive communication style
# BCIO:015673 maximum quantity of valuable material resource owned population statistic
# BCIO:010014 midwifery professional
# BCIO:015787 proportion unemployed status population statistic
# BCIO:015066 independently wealthy status
# BCIO:044070 paraphrasing
# BCIO:050477 having enacted a behaviour
# BCIO:050774 social group attribute
# BCIO:010051 dental assistant and therapist
# BCIO:007274 provide reduced frequency of aversive material consequence for behaviour BCT
# BCIO:050231 temporal orientation to the present
# BCIO:050456 crying
# BCIO:050705 mental feedback process
# BCIO:015282 cousin population statistic
# BCIO:015225 asexual population statistic
# MF:0000203 personality trait
# BCIO:050266 ruminating
# BCIO:015395 proportion history of exposure to an occupational hazard population statistic
# BCIO:026031 social centre or Community Hall facility
# BCIO:007066 monitor emotional consequences BCT
# BCIO:044113 patient communication style
# BCIO:015266 proportion caregiving role population statistic
# BCIO:007025 self-monitor outcome of behaviour BCT
# BCIO:026016 doctor-led primary care facility
# BCIO:015708 second generation immigrant population statistic
# BCIO:050609 belief that a behaviour is compulsory
# BCIO:006132 mentally comparing against a standard
# BCIO:050739 positive reinforcer
# BCIO:050738 positive reinforcement process
# BCIO:015548 proportion not working for health reasons population statistic
# BCIO:007034 arrange support BCT
# BCIO:010061 sport and fitness worker
# BCIO:011026 video game mode of delivery
# BCIO:015748 proportion stepdaughter population statistic
# BCIO:007211 promise positive material consequence for approximating behaviour BCT
# BCIO:050747 psychological attachment
# BCIO:050390 humorous communication style
# BCIO:006049 goal
# BCIO:007285 remove consequence for behaviour BCT
# BCIO:015528 mother population statistic
# ENVO:00000109 woodland area
# BCIO:015103 transgender
# BCIO:050366 providing occupational therapy
# BCIO:050229 professional identity
# BCIO:015385 percentage heterosexual population statistic
# BCIO:015570 percentage owner population statistic
# BCIO:015543 not seeking employment population statistic
# BCIO:015740 stepbrother population statistic
# BCIO:026046 outdoor environment
# BCIO:015693 renter population statistic
# BCIO:015164 proportion ability to read in intervention language population statistic
# BCIO:007176 inform about environmental consequences BCT
# BCIO:015797 percentage vocational training student or trainee role population statistic
# BCIO:007237 promise to remove positive social consequence for behaviour BCT
# BCIO:050800 observational learning
# BCIO:015020 member of a one person household
# BCIO:007100 set graded tasks BCT
# BCIO:015601 maximum personal history of events that influence behaviour  population statistic
# BCIO:015592 mean personal history of behavioural lapse population statistic
# BCIO:050862 empathising
# BCIO:015527 proportion mental capability population statistic
# BCIO:015176 proportion achieved doctoral or equivalent level education population statistic
# BCIO:044043 communication using a particular form of address
# BCIO:015017 ability to write in intervention language
# BCIO:036008 learning behaviour
# BCIO:015580 proportion parental role population statistic
# BCIO:015373 percentage grandparent population statistic
# BCIO:015160 personal vulnerability
# BCIO:050357 social prescribing
# BCIO:007222 promise positive social consequence for incompatible behaviour BCT
# OBI:0000093 patient role
# BCIO:044101 empathic communication style
# BCIO:050640 emotional-relevance appraisal of possible consequences
# BCIO:015640 personal vulnerability population statistic
# MFOEM:000075 appraisal of causal agency
# BCIO:007253 provide positive consequence for approximating behaviour BCT
# BCIO:050673 harmful fear reduction mental process
# BCIO:015353 proportion foster sibling population statistic
# BCIO:015688 percentage rent-free occupier population statistic
# BCIO:015598 personal history of events that influence behaviour  population statistic
# BCIO:050932 social norm monitoring
# BCIO:010017 veterinarian
# BCIO:007063 inform about health consequences BCT
# BCIO:015255 biological sister population statistic
# BCIO:050811 cue management behaviour
# BCIO:015403 percentage homemaker status population statistic
# BCIO:050395 sniffing consumption
# MF:0000015 imagination
# BCIO:010115 religious group membership of person source
# BCIO:015758 stepson population statistic
# BCIO:015133 foster child
# BCIO:050573 awareness of others’ need
# BCIO:015595 median personal history of behavioural lapse population statistic
# BCIO:007273 provide reduced frequency of aversive consequence for behaviour BCT
# BCIO:026019 community healthcare facility
# MFOEM:000091 appraisal of avoidability of consequences
# BCIO:015418 maximum human age population statistic
# BCIO:010023 audiologist and speech therapist
# OMRSE:00000191 residential facility
# BCIO:015048 achieved upper secondary education
# BCIO:007291 remove aversive social consequence for outcome of behaviour BCT
# BCIO:050872 positive evaluative belief about achieving a goal
# BCIO:050650 evaluative belief formation
# BCIO:015334 percentage foster brother population statistic
# BCIO:050757 reminder stimulus
# BCIO:007299 review behaviour goal plan BCT
# BCIO:050420 digital interaction behaviour
# BCIO:050486 personal history of same intervention exposure
# OMRSE:00000094 policy holder role
# BCIO:015610 percentage personal history of intervention exposure for the same outcome population statistic
# BCIO:015481 linguistic capability population statistic
# BCIO:015651 median personal vulnerability to harmful behaviour population statistic
# BCIO:015659 proportion policy holder role population statistic
# BCIO:010093 discipline of current programme of study or training
# BCIO:050350 advise behavioural ways to increase positive emotions BCT
# BCIO:050362 providing healthcare treatment
# GO:0032501 multicellular organismal process
# BCIO:015492 percentage male biological sex population statistic
# ADDICTO:0000349 addiction
# ADDICTO:0001087 social identity
# BCIO:050933 Knowledge regarding social environment
# BCIO:007220 promise positive social consequence for approximating behaviour BCT
# BCIO:044085 collaborative communication style
# BCIO:015230 proportion aunt population statistic
# BCIO:015573 percentage owner-occupier population statistic
# BCIO:044115 polite communication style
# BCIO:050927 control over behaviour
# IAO:0000078 curation status specification
# BCIO:011048 physical stimulus mode of delivery
# BCIO:050902 behavioural ease
# BCIO:010015 traditional and complementary medicine professional
# BCIO:050929 monitoring of others
# BCIO:046000 intervention content
# BCIO:015412 median household income population statistic
# BCIO:007068 increase salience of consequences BCT
# BCIO:050428 behavioural frequency
# BCIO:015550 mean number of years in education completed population statistic
# BCIO:007242 provide aversive consequence for situation specific behaviour BCT
# OMRSE:00000104 hospice facility
# BCIO:007078 implore to change behaviour BCT
# BCIO:050643 environmental opportunity for pleasure
# BCIO:050455 behavioural duration
# BCIO:015075 divorced or separated
# BCIO:044023 communication asking permission to provide information and advice
# BCIO:015351 foster sibling population statistic
# BCIO:010123 expertise discipline
# BCIO:015289 percentage discipline of current programme of study or training population statistic
# BCIO:050578 behavioural cue
# BCIO:015476 minimum language proficiency population statistic
# BCIO:050743 pro-social group
# BCIO:015359 proportion foster son population statistic
# BCIO:015179 proportion achieved early childhood education population statistic
# BCIO:050622 control over one’s life
# BCIO:011021 call mode of delivery
# BCIO:050871 persistent goal pursuit process
# BCIO:015661 percentage preschool student role population statistic
# BCIO:015518 member of a one person household population statistic
# BCIO:050480 mother
# BCIO:050947 motivation to deviate
# BCIO:050359 administering vaccine
# BCIO:036062 manufacturing behaviour
# BCIO:015405 homosexual population statistic
# BFO:0000020 specifically dependent continuant
# BCIO:010117 health status of person source
# BCIO:010034 legal, social and cultural professional
# BCIO:015199 percentage adoptive daughter population statistic
# BCIO:010010 generalist medical practitioner
# MFOEM:000061 appraisal of pleasantness
# BCIO:036113 substance use behaviour
# BCIO:007186 outcome consequence BCT
# BCIO:007152 indirectly restructure the physical environment BCT
# MFOEM:000020 core disgust
# BCIO:044091 communication style conveying hopefulness
# BCIO:026013 homeless setting
# BCIO:015576 percentage parent population statistic
# BCIO:011036 transdermal mode of delivery
# BCIO:050320 goal conflict
# BCIO:011009 labelling mode of delivery
# OBI:0000011 planned process
# BCIO:015076 widowed
# BCIO:007244 provide aversive material consequence for situation specific behaviour BCT
# BCIO:050695 low capability to enact a behaviour
# BCIO:015031 renter of housing from a social provider
# BCIO:050750 psychological attachment to conventional society
# BCIO:015504 percentage member of a multi-person household population statistic
# BCIO:015419 median human age population statistic
# ADDICTO:0001127 desire
# BCIO:015534 niece population statistic
# BCIO:050327 affective attitude towards a behaviour
# BCIO:015336 foster child population statistic
# BCIO:015187 percentage achieved primary education population statistic
# BCIO:010033 arts teacher
# BCIO:050768 self-regulation through behavioural feedback
# BCIO:050464 high mental exertion expended on a behaviour
# BCIO:010138 organisational source role
# BCIO:015538 percentage non-gendered identity population statistic
# BCIO:011008 printed publication mode of delivery
# BCIO:050772 social environmental disposition
# BCIO:007261 provide positive material consequence for incompatible behaviour BCT
# BCIO:036005 object management behaviour
# BCIO:015454 minimum individual income population statistic
# BCIO:015095 intervention population
# BCIO:010103 employer
# BCIO:007270 provide positive social consequence for situation specific behaviour BCT
# BCIO:026030 sport and exercise facility
# BCIO:010064 fitness and recreation instructor and programme leader
# BCIO:011058 uni-directional mode of delivery
# BCIO:050232 regret
# BCIO:050818 goal-directed behaviour
# BCIO:050559 inform about negative consequences BCT
# BCIO:044024 communication avoiding argumentation
# BCIO:015675 queer population statistic
# BCIO:015420 immigrant population statistic
# BCIO:044059 emotionally expressive communication
# BCIO:007292 remove consequence for outcome of behaviour BCT
# BCIO:015763 proportion student or trainee role population statistic
# BCIO:015216 adoptive son population statistic
# BCIO:050299 mechanism of action through personal role
# BCIO:015619 personal history of same intervention exposure population statistic
# BCIO:007194 promise aversive material consequence for outcome of behaviour
# MFOEM:000203 feeling of pain
# BCIO:010036 librarian, archivist and curator
# BCIO:015560 organisational role population statistic
# BCIO:036068 reclining
# BCIO:050293 mechanism of action through bodily disposition
# BCIO:015026 individual income
# BCIO:050401 participating in healthcare testing
# BCIO:007170 expose to sustained aversive stimulus BCT
# BCIO:015631 percentage personal history part of intervention exposure population statistic
# BCIO:015390 highest level of formal educational qualification achieved population statistic
# BCIO:007196 promise to remove aversive consequence for outcome of behaviour BCT
# GO:0003008 system process
# BCIO:015532 percentage nephew population statistic
# BCIO:050566 anxiety about use of technology
# IAO:0000310 document
# BCIO:050448 population behaviour pattern
# BCIO:006022 belief about control over one's future
# BCIO:007142 advise to keep outcome goal in mind BCT
# BCIO:050916 participant engagement with intervention
# BCIO:015323 proportion family member population statistic
# BCIO:015356 proportion foster sister population statistic
# BCIO:015310 percentage employed part time population statistic
# BCIO:011047 chewable substance mode of delivery
# BCIO:044114 persuasive communication style
# BCIO:036007 environmental system management behaviour
# RO:0002577 system
# BCIO:015575 parent population statistic
# BCIO:006052 knowledge
# BCIO:010040 religious professional
# BCIO:015678 questioning sexual orientation population statistic
# BCIO:015603 percentage personal history of events that influence behaviour  population statistic
# BFO:0000144 process profile
# BCIO:015308 proportion employed in shift work population statistic
# BCIO:007175 increase salience of behaviour BCT
# BCIO:026034 hospitality and catering facility
# BCIO:015218 proportion adoptive son population statistic
# BCIO:050460 postural expressive behaviour
# BCIO:010139 organisation source
# BCIO:015458 proportion individual income population statistic
# BCIO:007019 record behaviour without feedback BCT
# BCIO:015307 percentage employed in shift work population statistic
# BCIO:050341 advise sensory ways to reduce negative emotions BCT
# BCIO:010125 acquired knowledge or skill
# BCIO:015167 proportion ability to speak in intervention language population statistic
# BCIO:015335 proportion foster brother population statistic
# BFO:0000024 fiat object part
# BCIO:015396 history of exposure to childhood maltreatment population statistic
# OPMI:0000121 socioeconomic status
# BCIO:007184 inform about positive social consequences BCT
# BCIO:050364 providing psychological treatment
# BCIO:044087 communication style conveying acceptance
# BCIO:050713 motivation to reduce harm
# BCIO:007209 promise positive material consequence for behaviour BCT
# BCIO:050803 association behaviour with a pro-social group
# BCIO:036063 reading behaviour
# BCIO:007021 record outcome of behaviour without feedback BCT
# BCIO:006130 iconic memory
# BCIO:050339 advise sensory ways to reduce positive emotions BCT
# BCIO:015220 percentage adult population statistic
# BCIO:015145 stepbrother
# BCIO:015088 undergraduate student role
# BCIO:015517 proportion member of a multi-person multi-generational household population statistic
# BCIO:007234 promise to remove aversive social consequence for outcome of behaviour BCT
# BCIO:010083 researcher
# BCIO:010066 information and communications technician
# BCIO:050953 desire for continued life
# BCIO:015435 proportion in short term or temporary employment with known conditions population statistic
# BCIO:044030 exploring communication
# BCIO:050491 situational personal attribute
# BCIO:015080 outpatient role
# BCIO:006010 physical skill
# BCIO:015346 percentage foster mother population statistic
# BCIO:006092 internal stimulus for behaviour
# BCIO:010024 optometrist and ophthalmic optician
# BCIO:010022 dietician and nutritionist
# BCIO:015757 proportion stepsister population statistic
# BCIO:015520 proportion member of a one person household population statistic
# BCIO:050470 moderate cognitive exertion expended on a behaviour
# BCIO:015061 not seeking employment
# BCIO:050804 behaviour chain
# SDGIO:00010028 owner
# BCIO:015100 ability to read in intervention language population statistic
# BCIO:050648 evaluative belief about the positive consequences of a behaviour
# BCIO:015069 socioeconomic status score
# BCIO:015037 income-related welfare benefit
# BCIO:015161 personal history
# BCIO:050552 communication channel
# BCIO:050589 belief about effort required for a behaviour
# BCIO:011027 website mode of delivery
# BCIO:015295 percentage divorced or separated population statistic
# BCIO:007004 agree behaviour goal BCT
# BCIO:050668 goal about one’s resources
# BCIO:015299 proportion doctoral student role population statistic
# BCIO:050361 making a referral to another health care service
# BCIO:050918 low frequency of past behaviour
# BCIO:015716 proportion sexual orientation population statistic
# MF:0000083 mental imagery
# MF:0000045 wanting
# BCIO:015506 member of a multi-person household all related population statistic
# BCIO:050408 participating in occupational therapy
# BCIO:015679 percentage questioning sexual orientation population statistic
# BCIO:010013 nursing professional
# BCIO:010006 professional
# BCIO:015590 proportion patient role population statistic
# BCIO:007249 provide aversive social consequence for outcome of behaviour BCT
# BCIO:015792 mean value of valuable material resource owned population statistic
# BCIO:050715 motivational disposition not to change behaviour
# BCIO:007023 provide feedback on behaviour BCT
# BCIO:015117 step-parent
# BCIO:050810 criminal behaviour
# BCIO:015696 renter of housing from a social provider population statistic
# BCIO:007136 change the body BCT
# BCIO:006154 self-efficacy belief for a behaviour
# BCIO:050922 behaviour enacter
# BCIO:050915 rural area
# BCIO:015482 mean linguistic capability population statistic
# BCIO:011061 asynchronous mode of delivery
# BCIO:015794 maximum value of valuable material resource owned population statistic
# BCIO:050723 negative social environmental system
# BCIO:015760 proportion stepson population statistic
# MFOEM:000009 anger
# BCIO:007233 promise to remove aversive social consequence for behaviour BCT
# BCIO:015599 mean personal history of events that influence behaviour  population statistic
# BCIO:015692 proportion rent-free occupier without owner's permission population statistic
# BCIO:050440 position-related behaviour
# BCIO:050680 innate drive
# BCIO:015172 percentage achieved bachelor's degree or equivalent level population statistic
# BCIO:015208 percentage adoptive parent population statistic
# BCIO:011065 arts feature mode of delivery
# BCIO:015537 non-gendered identity population statistic
# BCIO:050434 emotional management exertion expended on a behaviour
# BCIO:050874 self-awareness process in relation to a problem
# BCIO:015514 proportion member of a multi-person household some related population statistic
# BCIO:050742 privacy
# BCIO:050488 personal history part of intervention exposure
# BCIO:010054 medical assistant
# BCIO:050754 reflective reasoning
# BCIO:050791 threat appraisal
# BCIO:015012 immigrant
# BCIO:029000 behaviour change intervention social setting
# MF:0000006 judging
# BCIO:050737 positive punishing stimulus
# BCIO:015296 proportion divorced or separated population statistic
# BCIO:044018 branded communication
# BCIO:007181 inform about positive emotional consequences BCT
# BCIO:015168 ability to write in intervention language population statistic
# BCIO:006114 goal setting process
# BCIO:050913 safety
# BCIO:015717 sibling population statistic
# BCIO:007167 advise sensory ways to change emotions BCT
# BCIO:015466 percentage inpatient role population statistic
# BCIO:015431 percentage in permanent employment population statistic
# BCIO:011014 electronic billboard mode of delivery
# BCIO:006162 mental distancing
# BCIO:050753 reflective mental process
# BCIO:015166 percentage ability to speak in intervention language population statistic
# BCIO:032000 behaviour change intervention tailoring
# ENVO:00000000 geographic feature
# BCIO:050724 negotiating skill
# BCIO:015455 maximum individual income population statistic
# OMRSE:00000102 health care facility
# BCIO:015140 adoptive sibling
# BCIO:015360 gender identity population statistic
# BCIO:050324 belief about quality of life
# BCIO:015345 foster mother population statistic
# BCIO:050230 temporal orientation to the future
# BCIO:007188 promise to remove consequence for behaviour BCT
# BCIO:015559 proportion occupier of employer-provided housing population statistic
# BCIO:015571 proportion owner population statistic
# BCIO:044090 communication style conveying genuineness
# BCIO:015129 adoptive son
# BCIO:007082 cue signalling reward BCT
# UBERON:0001062 anatomical entity
# BCIO:050224 belief about healthcare accessibility
# BCIO:044034 communication highlighting a contradiction
# BCIO:015642 minimum personal vulnerability population statistic
# BCIO:044098 didactic communication style
# ADDICTO:0000511 subjective craving
# BCIO:050914 urban area
# BCIO:050462 high cognitive exertion expended on a behaviour
# BCIO:015040 quantity of valuable material resource owned
# MFOEM:000080 feeling tired
# BCIO:050369 handwashing
# MFOEM:000109 feeling energetic
# BCIO:015689 proportion rent-free occupier population statistic
# BCIO:007144 promote pharmacological support BCT
# BCIO:050444 reflectiveness
# BCIO:050453 behaviour end point
# BCIO:015474 language proficiency population statistic
# BCIO:015211 percentage adoptive sibling population statistic
# OMRSE:00000076 household
# BCIO:050843 accepting responsibility for changing one’s behaviour
# BCIO:015130 stepchild
# BCIO:007174 increase awareness of option of novel behaviour BCT
# BCIO:050891 social group
# BCIO:050900 social behavioural consequence
# BCIO:050430 behavioural form
# BCIO:044016 asking open-ended questions
# BCIO:050890 protective factor for harmful behaviour
# BCIO:050454 behaviour starting point
# BCIO:036069 sitting
# BCIO:007147 advise how to change emotions BCT
# BCIO:007138 prompt mental rehearsal of successful performance BCT
# BCIO:006308 need-based motivation
# BCIO:015676 percentage queer population statistic
# BCIO:007178 inform about negative environmental consequences BCT
# BCIO:015274 percentage child relation population statistic
# BCIO:050368 bodily hygiene behaviour
# BCIO:015623 median personal history of same intervention exposure population statistic
# BCIO:015257 proportion biological sister population statistic
# BCIO:015152 grandfather
# BCIO:050431 mental exertion expended on a behaviour
# BCIO:015344 proportion foster father population statistic
# BCIO:036047 enjoyment behaviour
# BCIO:015097 ethnic group membership
# BCIO:015116 adoptive father
# BCIO:015123 child relation
# BCIO:011032 textual mode of delivery
# BCIO:026012 residential care or assisted living
# BCIO:002000 behaviour change intervention outcome behaviour
# ENVO:00000064 road
# BCIO:015522 mean mental capability population statistic
# BCIO:007035 arrange instrumental support BCT
# BCIO:015626 personal history part of intervention exposure population statistic
# BCIO:015730 median socioeconomic status score population statistic
# BCIO:015039 valuable material resource owned
# BCIO:026051 psychiatric facility
# BCIO:050634 drive process
# BCIO:015221 proportion adult population statistic
# BCIO:050706 mental process attribute
# BCIO:047000 behaviour change intervention temporal context
# BCIO:006096 goal pursuit process
# BCIO:044013 asking closed-ended questions
# BCIO:015252 biological sibling population statistic
# BCIO:015484 maximum linguistic capability population statistic
# BCIO:007217 promise to remove positive consequence for outcome of behaviour BCT
# BCIO:015245 proportion biological mother population statistic
# ENVO:00000070 human construction
# BCIO:007160 adopt changed self-identity BCT
# BCIO:006303 belief about responsibility to act
# BCIO:015223 percentage agreed rent-free occupier population statistic
# BCIO:015386 proportion heterosexual population statistic
# BCIO:015421 percentage immigrant population statistic
# BCIO:015703 percentage retired status population statistic
# BCIO:044069 offering reassurance
# BCIO:050700 low physical opportunity to enact a behaviour
# BCIO:010068 services and sales worker
# BCIO:044075 emotion-emphasising reflective communication
# BCIO:015224 proportion agreed rent-free occupier population statistic
# BCIO:015171 achieved bachelor's degree or equivalent level population statistic
# BCIO:050452 abstinence start point
# BCIO:015414 proportion household income population statistic
# BCIO:015298 percentage doctoral student role population statistic
# MFOEM:000003 physiological process involved in an emotion
# BCIO:015766 proportion teenager population statistic
# BCIO:015701 proportion residential facility owner population statistic
# BCIO:015163 history of exposure to an occupational hazard
# BCIO:006040 perceived descriptive behavioural norm
# BCIO:044109 legitimising communication style
# BCIO:050352 providing healthcare testing
# BCIO:006104 behavioural self-regulation of behaviour
# BCIO:015361 percentage gender identity population statistic
# BCIO:006150 evaluative belief about others
# BCIO:006021 belief about consequences of goal attainment
# BCIO:015024 member of a multi-person household some related
# BCIO:050709 motivational disposition for behavioural maintenance
# BCIO:036102 tobacco use behaviour pattern
# BCIO:015602 median personal history of events that influence behaviour  population statistic
# BCIO:007072 awareness of other peoples thoughts, feelings and actions BCT
# BCIO:036110 employment behaviour
# MFOEM:000032 surprise
# BCIO:050863 feeling of uncertainty
# BCIO:015530 proportion mother population statistic
# BCIO:007177 inform about negative emotional consequences BCT
# BCIO:015191 proportion achieved upper secondary education  population statistic
# BCIO:011003 face to face mode of delivery
# BCIO:007054 conduct a behavioural experiment BCT
# BCIO:050234 impulse
# BCIO:050717 need for comfort
# BCIO:050899 family behavioural consequence
# BCIO:044106 informal communication style
# BCIO:006043 self-efficacy belief for a behaviour and its associated outcomes
# BCIO:036067 lying down
# BCIO:050787 supportive social environmental system
# BCIO:044006 person-centred intervention delivery
# BCIO:050917 high frequency of past behaviour
# BCIO:050441 socially-related behaviour
# BCIO:007024 self-monitor behaviour BCT
# BCIO:050373 non-linguistic communication behaviour using vocalisations
# BCIO:050604 belief about the financial consequences of a behaviour
# BCIO:050414 diagnostic healthcare behaviour
# BCIO:044008 source-led intervention delivery
# BCIO:050887 leadership role
# BCIO:050805 behaviour pattern maintenance
# BCIO:050928 fear of death
# BCIO:015182 proportion achieved lower secondary education population statistic
# BCIO:015471 interpersonal role population statistic
# BCIO:007036 arrange emotional support BCT
# BCIO:011064 gamification mode of delivery
# BCIO:015711 self employed status population statistic
# BCIO:036028 physical impact behaviour
# BCIO:015122 foster father
# BCIO:026027 vocational facility
# BCIO:050633 dissonance reduction through mental process
# BCIO:015798 proportion vocational training student or trainee role population statistic
# BCIO:015401 proportion homeless person population statistic
# UBERON:0000465 material anatomical entity
# BCIO:050897 evaluative belief about achieving a goal
# BCIO:050826 parenting behaviour
# BCIO:007157 prompt focus on self-identity BCT
# BCIO:015493 proportion male biological sex population statistic
# BCIO:044046 communication using preferred form of address
# BCIO:015270 child population statistic
# BCIO:007235 promise to remove positive material consequence for behaviour BCT
# BCIO:015251 proportion biological sex population statistic
# BCIO:006157 mental plan for coping with barriers
# BCIO:015109 percentage ability to read in intervention language population statistic
# MFOEM:000006 subjective emotional feeling
# BCIO:007087 arrange satiation BCT
# BCIO:010111 female gender
# BCIO:007033 advise to seek appraisal support BCT
# BCIO:050847 belief in false minority
# OMRSE:00000235 money
# BCIO:026002 within-country location
# BCIO:015769 proportion transgender population statistic
# BCIO:007255 provide positive consequence for incompatible behaviour BCT
# BCIO:015013 second generation immigrant
# BCIO:026020 community outpatient clinic facility
# BCIO:050607 belief about the positive health consequences of a behaviour
# BCIO:015227 proportion asexual population statistic
# BCIO:007041 deliver emotional support BCT
# BCIO:010029 primary school teacher
# BCIO:026045 ambulance
# BCIO:050644 evaluation of information about behavioural self-efficacy
# BCIO:050873 positive evaluative belief about interacting with others
# BCIO:015125 biological daughter
# BCIO:006042 normative belief
# BCIO:015242 proportion biological father population statistic
# BCIO:050228 mental plan
# BCIO:006301 belief about others' susceptibility
# BCIO:044128 source visual style
# BCIO:010000 behaviour change intervention source
# BCIO:050808 collective behaviour
# BCIO:015690 rent-free occupier without owner's permission population statistic
# BCIO:015128 adoptive daughter
# ...
# MF:0000032 bodily disposition
# BCIO:036084 association behaviour
# OMRSE:00000114 emergency department facility
# ENVO:00000111 forested area
# BCIO:007165 advise behavioural ways to change emotions BCT
# BCIO:036034 human communication behaviour
# BCIO:015459 influencer role population statistic
# BCIO:015268 percentage caste membership population statistic
# BCIO:015262 percentage bisexual population statistic
# BCIO:050704 mechanism of action through social group attribute
# BCIO:015192 adoptive brother population statistic
# BCIO:015731 stay at home parent or guardian status population statistic
# MFOEM:000028 anxiety
# BCIO:015338 proportion foster child population statistic
# BCIO:015231 biological brother population statistic
# BCIO:036106 cigarette smoking behaviour pattern
# BCIO:015764 teenager population statistic
# BCIO:015727 mean socioeconomic status score population statistic
# BCIO:015605 personal history of intervention exposure for the same outcome population statistic
# BCIO:010007 science and engineering professional
# BCIO:015378 health insurance policy holder role population statistic
# MFOEM:000210 negative surprise
# BCIO:015552 maximum number of years in education completed population statistic
# ADDICTO:0001140 addiction strength
# BCIO:015400 percentage homeless person population statistic
# OMRSE:00000064 school facility
# BCIO:006304 behavioural importance-based motivation
# BCIO:050809 coping behaviour
# BCIO:015519 percentage member of a one person household population statistic
# BCIO:010122 pre-existing knowledge or skill
# BCIO:006039 perceived norm
# BCIO:050597 belief about severity of health condition
# MFOEM:000076 appraisal as caused by self
# BCIO:044051 communication using neutral language
# BCIO:050671 group evaluative behavioural norm
# BCIO:007197 promise aversive social consequence for behaviour BCT
# BCIO:015151 grandmother
# BCIO:015206 proportion adoptive mother population statistic
# BCIO:007018 observe behaviour without feedback BCT
# BCIO:015023 member of a multi-person household all related
# BCIO:044055 communication avoiding offensive language
# BCIO:015406 percentage homosexual population statistic
# BCIO:015260 proportion biological son population statistic
# BCIO:050730 peer influence behaviour
# BCIO:044119 semi-structured communication style
# BCIO:050752 reflective capability
# BCIO:015318 expertise discipline population statistic
# BCIO:015174 achieved doctoral or equivalent level education population statistic
# BCIO:044120 structured communication style
# BCIO:050651 evaluative belief formation about a behaviour
# MF:0000088 subliminal process
# BCIO:015008 questioning sexual orientation
# BCIO:022000 behaviour change intervention dose
# BCIO:050561 acquired drive
# BCIO:011006 letter mode of delivery
# BCIO:015588 patient role population statistic
# BCIO:050721 negative reinforcement process
# BCIO:006023 belief about gain
# BCIO:015055 in permanent employment
# BCIO:044000 behaviour change intervention style of delivery
# BCIO:015073 in a stable or common law relationship
# BCIO:015803 percentage widowed population statistic
# BCIO:015376 percentage having enacted a behaviour population statistic
# BCIO:015131 stepdaughter
# BCIO:015367 percentage grandfather population statistic
# BCIO:007180 inform about negative social consequences BCT
# BCIO:007250 provide consequence for outcome of behaviour BCT
# BCIO:050580 behavioural dissonance reduction through mental process
# BCIO:006107 value-congruent self-regulation
# BCIO:044001 intervention content communication process
# BCIO:050955 attachment to a caregiver
# BCIO:050792 traditional personal value
# BCIO:050353 providing health screening
# BCIO:050714 motivational disposition
# BCIO:050812 domestic behaviour
# BCIO:006102 plan enactment
# BCIO:010092 doctoral student or trainee
# BCIO:050663 feedback process to a person
# BCIO:015049 achieved bachelor's degree or equivalent level
# BCIO:015734 step-parent population statistic
# BCIO:015070 interpersonal role
# BCIO:015508 proportion member of a multi-person household all related population statistic
# BCIO:050716 motivational disposition to change behaviour
# BCIO:050796 well-specified goal
# BCIO:006100 internal reward for a response
# BCIO:050718 need to hold a world view
# BCIO:006146 belief about social support
# BCIO:044092 communication style conveying perceived superiority
# BCIO:011056 pair-based mode of delivery
# MFOEM:000026 fear
# BCIO:050726 normative goal
# BCIO:050678 information devaluing
# BCIO:015399 homeless person population statistic
# BCIO:007069 consider pros and cons BCT
# BCIO:015068 socioeconomic status category
# BCIO:006058 mental imagery disposition
# ENVO:00000091 beach
# BCIO:015038 health insurance policy holder role
# BCIO:050823 impact of behaviour on environment
# MF:0000041 belief
# BCIO:007013 review outcome goal BCT
# BCIO:006072 stereotype
# BCIO:044096 controlling communication style
# BCIO:015460 percentage influencer role population statistic
# BCIO:044122 verbally dominant communication style
# BCIO:050208 tobacco use cessation
# BCIO:050639 emotional opportunity
# BCIO:007300 set measurable behaviour goal BCT
# BCIO:050227 disengagement due to workload
# BCIO:044094 communication style conveying support for change
# BCIO:015288 discipline of current programme of study or training population statistic
# BCIO:036011 social organisation behaviour
# BCIO:006081 personal role
# MFOEM:000007 emotional action tendency
# BCIO:007191 promise aversive consequence for situation specific behaviour BCT
# BCIO:006136 intrinsic motivation
# BCIO:050938 centralisation of decision-making
# BCIO:036070 standing
# BCIO:011037 alimentary mode of delivery
# BCIO:010008 health professional
# BCIO:050336 advise cognitive ways to increase negative emotions BCT
# BCIO:050850 cognitive bias disposition
# BCIO:007134 conserve mental resources BCT
# BCIO:006161 avoidance mental process
# BCIO:050569 assigned goal
# BCIO:015700 percentage residential facility owner population statistic
# BCIO:007080 prompt intended action BCT
# BCIO:007161 adopt positive self-identity BCT
# BCIO:015150 grandparent
# BCIO:015369 grandmother population statistic
# BCIO:011063 pull mode of delivery
# BCIO:026029 community facility
# BCIO:044124 relationship building
# ADDICTO:0001109 public policy
# BCIO:050238 non-linguistic communication behaviour
# ENVO:01000452 environmental disposition
# BCIO:050956 degree of organisational hierarchie
# BCIO:050649 evaluative belief about the possible future consequences of one’s behaviour
# ENVO:00000106 grassland area
# ADDICTO:0000750 financial cost of a product or service
# BCIO:015714 sexual orientation population statistic
# BCIO:050447 intentionality
# BCIO:050858 denial belief about norm relevance
# BCIO:050586 belief about a behavioural rule
# BCIO:050432 physical exertion expended on a behaviour
# BCIO:050367 providing speech and language therapy
# BCIO:050944 knowledge regarding one's environment
# BCIO:015354 foster sister population statistic
# MF:0000030 representation
# BCIO:050564 affective attitude acquired through association
# BCIO:015339 foster daughter population statistic
# BCIO:006064 psychological need
# BCIO:010053 physiotherapy technician and assistant
# BCIO:050924 behaviour non-intender
# BCIO:015683 proportion relationship status population statistic
# BCIO:015710 proportion second generation immigrant population statistic
# BCIO:015104 cisgender
# BCIO:050799 appraisal of desirability
# BCIO:015382 percentage health status attribute population statistic
# SDGIO:00010001 education process
# BCIO:050417 oral consumption
# BCIO:015441 proportion income-related welfare benefit population statistic
# BCIO:010011 specialist medical practitioner
# BCIO:007264 provide positive consequence for outcome of behaviour BCT
# BCIO:015784 proportion undergraduate student role population statistic
# BCIO:015213 adoptive sister population statistic
# BCIO:015190 percentage achieved upper secondary education  population statistic
# BCIO:015056 in short term or temporary employment with known conditions
# BCIO:015702 retired status population statistic
# BCIO:010004 occupational role of source
# BCIO:015600 minimum personal history of events that influence behaviour  population statistic
# MF:0000020 mental process
# BCIO:044100 easily comprehended communication style
# BCIO:044038 communication involving agreement followed by highlighting incongruent aspects
# BCIO:050576 behaviour maintenance self-efficacy
# BCIO:050365 providing creative arts therapy
# BCIO:036029 posture behaviour
# BCIO:050676 high opportunity to enact a behaviour
# BCIO:007302 suggest different perspective on behaviour BCT
# BCIO:044009 active listening
# BCIO:050654 external stimulus
# BCIO:010003 personal role of source
# ENVO:00000562 park
# BCIO:050662 feedback process related to identity
# BCIO:015483 minimum linguistic capability population statistic
# BCIO:007252 provide positive consequence for behaviour BCT
# BCIO:044015 asking leading questions
# BCIO:015668 percentage protective factor for harmful behaviour population statistic
# BCIO:015276 cisgender population statistic
# MFOEM:000103 appraisal of dangerousness
# BCIO:015774 percentage unawareness of a behaviour population statistic
# BCIO:010005 manager
# BCIO:015202 percentage adoptive father population statistic
# BCIO:050363 providing physical therapy
# BCIO:015799 voluntary worker status population statistic
# BCIO:036039 skill development behaviour
# GO:0098597 observational learning
# BCIO:050815 emotionally expressive behaviour
# MF:0000021 interpersonal process
# BCIO:015765 percentage teenager population statistic
# MF:0000012 arousal
# BCIO:050482 personal history of behavioural lapse
# MFOEM:000042 happiness
# BCIO:006143 belief about message trustworthiness
# BCIO:050950 social learning
# BCIO:010001 person source role
# BCIO:050330 advise to avoid people who do an unwanted behaviour BCT
# BCIO:050666 generalised reinforcer
# BCIO:015521 mental capability population statistic
# BCIO:015488 long-term disabled population statistic
# BCIO:015119 stepfather
# BCIO:015028 residential facility owner
# ADDICTO:0000352 adult
# BCIO:007284 reduce distraction BCT
# BCIO:015358 percentage foster son population statistic
# BCIO:050608 belief about the positive social consequences of a behaviour
# BCIO:050926 awareness of mortality
# BCIO:015146 foster sibling
# BCIO:007121 vicarious punishment BCT
# BCIO:010020 environmental and occupational health and hygiene professional
# BCIO:050769 similarity to other people
# BCIO:006066 need for self-esteem
# BCIO:007257 provide positive material consequence for behaviour BCT
# BCIO:007028 social support BCT
# BCIO:015547 percentage not working for health reasons population statistic
# BCIO:015371 proportion grandmother population statistic
# BCIO:044049 communication using interjections to signal attentiveness
# BCIO:026006 high-income area
# BCIO:015430 occupational role
# BCIO:007241 provide aversive consequence for behaviour BCT
# BCIO:036086 nurture behaviour
# BCIO:010062 athlete and sports player
# BCIO:015639 proportion personal psychological attribute population statistic
# BCIO:015057 in uncertain employment
# BCIO:011060 synchronous mode of delivery
# BCIO:015544 percentage not seeking employment population statistic
# BCIO:006147 evaluative belief about a behaviour
# BCIO:015112 biological mother
# BCIO:015002 human age
# BCIO:044002 behaviour change intervention content communication process
# BCIO:050594 belief about likelihood of financial consequences of a behaviour
# GO:0007612 learning
# BCIO:007151 directly restructure the physical environment BCT
# BCIO:044040 communication involving elaboration of arguments
# BCIO:007268 provide positive social consequence for completion of behavioural sequence BCT
# BCIO:015779 undecidedness about enacting a behaviour population statistic
# BCIO:015237 biological daughter population statistic
# BCIO:006069 need to feel competent
# BCIO:050767 self-motive
# BCIO:015006 heterosexual
# BCIO:003000 behaviour change intervention
# BCIO:015248 proportion biological parent population statistic
# BCIO:026009 household residence
# BCIO:050875 self-identity appraisal informed by one’s behaviour
# BCIO:050945 learning goal
# BCIO:015469 percentage insured party role population statistic
# BCIO:050388 communication showing acknowledgement
# BCIO:015475 mean language proficiency population statistic
# BCIO:015153 aunt
# BCIO:007096 context-specific repetition of behaviour BCT
# BCIO:006086 behavioural opportunity
# BCIO:007042 deliver informational support BCT
# BCIO:050429 number of behavioural occurrences
# BCIO:010048 nursing associate professional
# BCIO:044131 anxious communication style
# BCIO:015139 biological brother
# BCIO:010070 sales worker
# BCIO:015562 proportion organisational role population statistic
# BCIO:026017 care home facility
# MFOEM:000212 negative emotion
# BCIO:050423 eating
# BCIO:050840 threat-reducing behaviour
# BCIO:015649 minimum personal vulnerability to harmful behaviour population statistic
# BCIO:050337 advise cognitive ways to reduce negative emotions BCT
# BCIO:015115 adoptive mother
# BCIO:050351 advise behavioural ways to reduce positive emotions BCT
# BCIO:015652 percentage personal vulnerability to harmful behaviour population statistic
# BCIO:006142 belief about the credibility of a message's source
# BCIO:010039 social work and counselling professional
# BCIO:036033 care-giving behaviour
# BCIO:015287 proportion disabled population statistic
# BCIO:015041 value of valuable material resource owned
# BCIO:015215 proportion adoptive sister population statistic
# BCIO:015272 proportion child population statistic
# ADDICTO:0001273 public health promotion policy
# BCIO:007095 substitute behaviour BCT
# BCIO:015001 behaviour change intervention participant
# BCIO:015313 percentage employment status population statistic
# BCIO:015561 percentage organisational role population statistic
# BCIO:007179 inform about negative health consequences BCT
# BCIO:050728 observational learning capability
# BCIO:050692 legal behavioural constraint
# BCIO:007288 remove aversive material consequence for outcome of behaviour BCT
# BCIO:050848 capability to imagine future scenarios
# BCIO:050699 low opportunity to enact a goal-directed behaviour
# BCIO:044130 readability
# BCIO:015796 vocational training student or trainee role population statistic
# BCIO:026022 educational facility
# BCIO:007185 manage mental processes BCT
# BCIO:015425 proportion in a legal marriage or union population statistic
# BCIO:050317 subjective want
# BCIO:050877 social approval pleasure
# BCIO:015577 proportion parent population statistic
# BCIO:015615 maximum personal history of intervention exposure for the same outcome behaviour population statistic
# ENVO:01000254 environmental system
# BCIO:015564 percentage other sexual orientation population statistic
# BCIO:043000 process attribute
# BCIO:015686 proportion religious group membership population statistic
# BCIO:050859 desired self-regulatory standard
# BCIO:011017 3-D projection mode of delivery
# BCIO:050683 intention to enact a behaviour
# BCIO:007090 associative learning BCT
# BCIO:015783 percentage undergraduate student role population statistic
# BCIO:015551 minimum number of years in education completed population statistic
# BCIO:006079 desired standard
# BCIO:015177 achieved early childhood education population statistic
# BCIO:015247 percentage biological parent population statistic
# BCIO:015090 masters student role
# BCIO:015437 percentage in uncertain employment population statistic
# BFO:0000016 disposition
# OBI:0000245 organization
# BCIO:015662 proportion preschool student role population statistic
# BCIO:050355 prescribing medication
# BCIO:007223 promise positive social consequence for situation specific behaviour BCT
# BCIO:007248 provide aversive social consequence for situation specific behaviour BCT
# BCIO:015355 percentage foster sister population statistic
# BCIO:007061 plan inclusion of enjoyment BCT
# BCIO:050211 substance use behaviour pattern
# BCIO:015786 percentage unemployed status population statistic
# BCIO:007225 promise reduced frequency of aversive consequence for behaviour BCT
# MFOEM:000193 mood process
# BCIO:015005 bisexual
# BCIO:015767 transgender population statistic
# BCIO:015648 mean personal vulnerability to harmful behaviour population statistic
# BCIO:015042 number of years in education completed

# %%
ontoid_counts = resultdata['Ontology_ID'].value_counts()

for (cid, count) in ontoid_counts.items():
    if cid == 0: 
        continue
    ciri = onto.get_iri_for_id(cid)
    if ciri:
        clabel = onto.get_annotation(ciri, RDFSLABEL)
    else:
        print("No IRI found for ID",cid)
    if not clabel: 
        print(cid,ciri,clabel,count)
# Out:
# No IRI found for ID
# ADDICTO:0001378 http://addictovocab.org/ADDICTO_0001378 None 1
# BCIO:037017 http://humanbehaviourchange.org/ontology/BCIO_037017 None 1
# BCIO:037024 http://humanbehaviourchange.org/ontology/BCIO_037024 None 1
# BCIO:006098 http://humanbehaviourchange.org/ontology/BCIO_006098 None 1
# ADDICTO:0001377 http://addictovocab.org/ADDICTO_0001377 None 1

# %%
sum([len(theories[t].constructs) for t in theories])
# Out:
# 1529

# %%
# Average, min and max number of annotations per theory
# group the annotations df by theory_id then count the rows with non-null ontology IDs, then plot

import statistics
import seaborn as sns
import matplotlib.pyplot as plt

theory_annotations = {}

for theory_id in theory_names:
    onto_ids = set(resultdata.query("Theory_ID == "+theory_id)['Ontology_ID'])
    #print(theory_id,":",onto_ids)
    theory_annotations[theory_id]=onto_ids

annot_nums = [(n, len(t)) for n,t in theory_annotations.items()]
annot_nums
# Out:
# [('1', 28),
#  ('10', 17),
#  ('11', 9),
#  ('12', 16),
#  ('13', 38),
#  ('14', 16),
#  ('16', 20),
#  ('17', 25),
#  ('18', 6),
#  ('19', 13),
#  ('2', 6),
#  ('20', 8),
#  ('22', 5),
#  ('23', 23),
#  ('24', 23),
#  ('25', 14),
#  ('26', 12),
#  ('27', 10),
#  ('28', 18),
#  ('29', 28),
#  ('3', 20),
#  ('30', 17),
#  ('31', 23),
#  ('32', 13),
#  ('33', 18),
#  ('34', 17),
#  ('35', 16),
#  ('39', 21),
#  ('4', 23),
#  ('40', 6),
#  ('41', 27),
#  ('42', 19),
#  ('43', 11),
#  ('44', 7),
#  ('45', 13),
#  ('46', 13),
#  ('47', 10),
#  ('48', 10),
#  ('49', 21),
#  ('5', 13),
#  ('50', 10),
#  ('51', 17),
#  ('52', 18),
#  ('53', 13),
#  ('54', 19),
#  ('55', 10),
#  ('56', 14),
#  ('57', 32),
#  ('58', 16),
#  ('59', 19),
#  ('6', 7),
#  ('60', 46),
#  ('62', 12),
#  ('63', 8),
#  ('64', 11),
#  ('65', 9),
#  ('66', 21),
#  ('67', 16),
#  ('68', 11),
#  ('69', 22),
#  ('70', 16),
#  ('71', 7),
#  ('72', 23),
#  ('73', 17),
#  ('74', 9),
#  ('75', 7),
#  ('76', 11),
#  ('77', 16),
#  ('78', 17),
#  ('79', 10),
#  ('8', 10),
#  ('80', 26),
#  ('81', 11),
#  ('82', 12),
#  ('83', 12),
#  ('9', 10)]

# %%
print(len(annot_nums))
annot_nums_lens = [k for (a,k) in annot_nums]

print("Mean",statistics.mean(annot_nums_lens),"Max",max(annot_nums_lens),"Min",min(annot_nums_lens))

annot_nums.sort(key = lambda x: int(x[0]))

print(annot_nums)
# Out:
# 76
# Mean 15.763157894736842 Max 46 Min 5
# [('1', 28), ('2', 6), ('3', 20), ('4', 23), ('5', 13), ('6', 7), ('8', 10), ('9', 10), ('10', 17), ('11', 9), ('12', 16), ('13', 38), ('14', 16), ('16', 20), ('17', 25), ('18', 6), ('19', 13), ('20', 8), ('22', 5), ('23', 23), ('24', 23), ('25', 14), ('26', 12), ('27', 10), ('28', 18), ('29', 28), ('30', 17), ('31', 23), ('32', 13), ('33', 18), ('34', 17), ('35', 16), ('39', 21), ('40', 6), ('41', 27), ('42', 19), ('43', 11), ('44', 7), ('45', 13), ('46', 13), ('47', 10), ('48', 10), ('49', 21), ('50', 10), ('51', 17), ('52', 18), ('53', 13), ('54', 19), ('55', 10), ('56', 14), ('57', 32), ('58', 16), ('59', 19), ('60', 46), ('62', 12), ('63', 8), ('64', 11), ('65', 9), ('66', 21), ('67', 16), ('68', 11), ('69', 22), ('70', 16), ('71', 7), ('72', 23), ('73', 17), ('74', 9), ('75', 7), ('76', 11), ('77', 16), ('78', 17), ('79', 10), ('80', 26), ('81', 11), ('82', 12), ('83', 12)]

# %%
plt.figure(figsize=(9, 3))

sns.barplot({k:v for (k,v) in annot_nums})
plt.xticks(rotation=90,fontsize=8)
plt.show()

# %%
# As a proportion of the number of constructs as well ... 

theory_construct_lens = {k:len(t.constructs) for k,t in theories.items()}

theory_proportion_annot = [(k,v/theory_construct_lens[k]) for k,v in annot_nums]

theory_proportion_annot

print("Minimum",min([v for (k,v) in theory_proportion_annot]),"Mean",statistics.mean([v for (k,v) in theory_proportion_annot]),"Maximum",max([v for (k,v) in theory_proportion_annot]))

plt.figure(figsize=(9, 3))
sns.barplot({k:v for (k,v) in theory_proportion_annot})
plt.xticks(rotation=90,fontsize=8)
plt.show()
# Out:
# Minimum 0.2777777777777778 Mean 0.8065348088816696 Maximum 1.0

# %% [markdown]
# #### Counts and interpretation of ontology annotation dataset
#
# We look at the most common ontology annotations and visualise these

# %%
ontolabel_counts = {}

for (cid, count) in ontoid_counts.items():
    if isinstance(cid,str):
        ciri = onto.get_iri_for_id(cid)
        if ciri: 
            clabel = onto.get_annotation(ciri, RDFSLABEL)
            #print(cid,ciri,clabel,count)
            if clabel:
                ontolabel_counts[cid+" "+clabel]=count
            else: 
                ontolabel_counts[cid]=count

plt.figure(figsize=(6, 3))
sns.histplot(ontoid_counts.values ,log=True)
plt.xticks(rotation=90,fontsize=8)
plt.xlabel("Count of annotations")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 ontolabel_counts = {}
# ----> 3 for (cid, count) in ontoid_counts.items():
#       4     if isinstance(cid,str):
#       5         ciri = onto.get_iri_for_id(cid)
#
# NameError: name 'ontoid_counts' is not defined

# %%
selected_ontocounts = {k:v for k,v in ontolabel_counts.items() if v>=10}

plt.figure(figsize=(9, 3))
sns.barplot(selected_ontocounts)
plt.xticks(rotation=90,fontsize=8)
plt.show()

# %% [markdown]
# #### Interpret the annotations
# We have loaded the annotation dataset, the ontology and the theory dataset. Now we would like to use the annotations to integrate across theories.
#
# - Statistics for overlaps between theories based on common annotations
# - Percentage containment as was previously reported based on lexical matching. Now using ontology annotations. This answers the research question "which theories are comparable"? i.e. which theories partially overlap by referring to the same entities?
# - Maximal set of compatible and consistent entities and relationships as a single "mega-theory"
# - Weighting of statements based on how often they appear in different theories, what are the most common statements? Mega-theory by consensus (voting)?

# %% [markdown]
# #### Overlaps between theories based on common annotations
#
# We calculate how many common annotations are shared pairwise between each combination of theories . This gives us a measure for how overlapping each pair of theories is.

# %%
#print(theory_annotations)

theories_in_order = list(theory_annotations.keys())
theories_in_order.sort(key = lambda x: int(x))

theory_annot_overlaps = {}

for t1 in theories_in_order: 
    results_t1 = {}
    for t2 in theories_in_order: 
        onto_ids_t1 = theory_annotations[t1]
        onto_ids_t2 = theory_annotations[t2]
        overlaps = [value for value in onto_ids_t1 if value in onto_ids_t2]
        results_t1[t2]=overlaps
    theory_annot_overlaps[t1]=results_t1

print(theory_annot_overlaps)

# %%
result_overlap_perc = []
annots_nums_dict = {k:v for (k,v) in annot_nums}

interesting_overlaps = {}

counter = 0
for t1 in theory_annot_overlaps:
    num_annots = annots_nums_dict[t1]
    if num_annots == 0: 
        print("Theory", t1, "has no annotations")
    else:
        result_overlap_perc.append([])
        for t2,overlaps in theory_annot_overlaps[t1].items():
            num_overlaps = len(overlaps)
            perc = num_overlaps / num_annots * 100
            result_overlap_perc[counter].append(perc)
            if perc < 100 and perc > 40:
                interesting_overlaps[t1+'-'+t2] = perc
        counter = counter+1

results_perc_overlap = pd.DataFrame(result_overlap_perc, theory_annot_overlaps.keys(),theory_annot_overlaps.keys())

results_perc_overlap


plt.figure()  # figsize=(9, 9)
sns.heatmap(results_perc_overlap)
plt.xticks(rotation=90,fontsize=8)
plt.show()

# %%
# Select just the higher ones...

interesting_overlaps_sorted = [ (k,v) for k,v in interesting_overlaps.items()]
interesting_overlaps_sorted.sort(reverse=True, key=lambda x: x[1])
interesting_overlaps_sorted

plt.figure(figsize=(9, 3))
sns.barplot({k:v for (k,v) in interesting_overlaps_sorted})
plt.xticks(rotation=90,fontsize=8)
plt.show()

# %% [markdown]
# #### Common Assertions
#
# We collapse the theory assertions to triples using the ontology annotations rather than the construct labels.
# Then we look at how common the assertions are across different theories.

# %%
annotated_triples = []

for theory_num, theory in theories.items():
    for triple in theory.triples:
        if triple.reified_rel is None: # Ignore the reified rels - too complex for this process now
            construct1 = triple.const1.name
            construct2 = triple.const2.name
            #print(f"Construct 1: '{construct1}', Construct 2: '{construct2}'")
            relationship = triple.relStr
            if 'relationship' not in construct1 and 'relationship' not in construct2:
                c1annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct1.lower().replace("\n","").replace("'","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                c2annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct2.lower().replace("\n","").replace("'","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                constr1_annots = [c for c in c1annots.values.flatten().tolist() if c]
                constr2_annots = [c for c in c2annots.values.flatten().tolist() if c]
                if len(constr1_annots)>0 and len(constr2_annots)>0: 
                    for annot1 in constr1_annots: 
                        for annot2 in constr2_annots:
                            if annot1 != annot2: 
                                a1iri = onto.get_iri_for_id(annot1)
                                a2iri = onto.get_iri_for_id(annot2)
                                a1label = onto.get_annotation(a1iri, RDFSLABEL) if a1iri else annot1
                                a2label = onto.get_annotation(a2iri, RDFSLABEL) if a2iri else annot2
                                #print("Theory",theory_num,"Construct1",construct1,"Annot1",annot1,"Rel",relationship,"Construct2",construct2,"Annot2",annot2)

                                annotated_triples.append( (annot1,a1label,relationship,annot2,a2label) )
                else:
                    print("Not including",theory_num,construct1,constr1_annots,construct2,constr2_annots)

#annotated_triples
# Out:
# Not including 1 Feedback ['BCIO:007023'] Antecedents of goal-directed behaviour []
# Not including 1 Subjective norms ['BCIO:006042', 'BCIO:006059'] Antecedents of goal-directed behaviour []
# Not including 1 Anticipated emotions ['BCIO:050590'] Antecedents of goal-directed behaviour []
# Not including 1 Social identity processes ['BCIO:050775'] Antecedents of goal-directed behaviour []
# Not including 1 Somatic marker processes ['BCIO:050564'] Antecedents of goal-directed behaviour []
# Not including 1 Goal intention ['BCIO:006016'] Antecedents of goal-directed behaviour []
# Not including 1 Attitudes ['BCIO:050328'] Antecedents of goal-directed behaviour []
# Not including 1 Perceived behavioural control ['BCIO:006034', 'MFOEM:000075'] Antecedents of goal-directed behaviour []
# Not including 1 Desire ['MF:0000045', 'BCIO:050316'] Antecedents of goal-directed behaviour []
# Not including 1 Frequency of past behaviour ['BCIO:050817'] Antecedents of goal-directed behaviour []
# Not including 1 Moral imperatives ['BCIO:006063'] Antecedents of goal-directed behaviour []
# Not including 1 Implementation intentions ['BCIO:006016'] Antecedents of goal-directed behaviour []
# Not including 1 Trying ['BCIO:006096'] Antecedents of goal-directed behaviour []
# Not including 1 Recency of past behaviour ['BCIO:050453', 'BCIO:050481'] Antecedents of goal-directed behaviour []
# Not including 1 Desirability ['BCIO:050617'] Antecedents of goal-directed behaviour []
# Not including 1 Feasibility of goals ['BCIO:050592'] Antecedents of goal-directed behaviour []
# Not including 1 Normative beliefs ['BCIO:006042'] Antecedents of goal-directed behaviour []
# Not including 1 Motivation to comply ['BCIO:006059'] Antecedents of goal-directed behaviour []
# Not including 1 Beliefs ['MF:0000041', 'BCIO:006019'] Antecedents of goal-directed behaviour []
# Not including 1 Evaluations ['BCIO:006038', 'BCIO:006148'] Antecedents of goal-directed behaviour []
# Not including 11 Input function (perception) ['MF:0000019'] General course of action / senses []
# Not including 11 Program control ['BCIO:050859'] General course of action / senses []
# Not including 11 General course of action / senses [] Reference value ['BCIO:006079']
# Not including 11 General course of action / senses [] Hierarchy of systems ['BCIO:050956']
# Not including 12 Priority [] Differential association ['BCIO:036084']
# Not including 4 Minor discomfort [] Hassles ['BCIO:050577']
# Not including 4 Decreased sensitivity [] Hassles ['BCIO:050577']
# Not including 4 Drug use and abuse ['BCIO:036113'] Risk behaviours []
# Not including 4 High-risk sports [] Risk behaviours []
# Not including 4 Delinquency [] Risk behaviours []
# Not including 41 Demography [] Macro / societal factors ['ENVO:01000254']
# Not including 41 Safety [] Needs ['BCIO:006064']
# Not including 41 Status [] Needs ['BCIO:006064']
# Not including 41 Privacy [] Needs ['BCIO:006064']
# Not including 41 Social justice [] Needs ['BCIO:006064']
# Not including 41 Spatial [] Abilities ['BCIO:050215']
# Not including 42 Recognition of own ability to provide relief ['BCIO:006043'] Arousal of some sense of responsibility to respond []
# Not including 42 Activation of norms [] Assessment, evaluation and reassessment ['BCIO:006038']
# Not including 42 Causal responsibility ['BCIO:006078'] Arousal of some sense of responsibility to respond []
# Not including 42 Distinctive Suitability ['BCIO:006154', 'MFOEM:000006'] Arousal of some sense of responsibility to respond []
# Not including 42 Directed appeal ['BCIO:036025'] Arousal of some sense of responsibility to respond []
# Not including 42 Accountability [] Arousal of some sense of responsibility to respond []
# Not including 42 Social norms ['BCIO:050671'] Social []
# Not including 42 Arousal of some sense of responsibility to respond [] Perception of need and responsibility ['BCIO:050585']
# Not including 42 Social [] Costs and benefits ['BCIO:050649']
# Not including 42 Social norms ['BCIO:050671'] Activation of norms []
# Not including 42 Specific personal norms ['BCIO:006063'] Activation of norms []
# Not including 43 Stimulus and situational generalisation [] Stimulus ['BCIO:050783']
# Not including 43 Operant behaviour ['BCIO:036000'] Shaping and chaining []
# Not including 43 Operant behaviour ['BCIO:036000'] Stimulus and situational generalisation []
# Not including 43 Reinforcement ['BCIO:050756'] Extinction []
# Not including 43 Shaping and chaining [] Reinforcement ['BCIO:050756']
# Not including 43 Operant behaviour ['BCIO:036000'] Response generalisation []
# Not including 43 Response generalisation [] Response ['BCIO:036000']
# Not including 43 Skill performance deficits [] Reinforcement ['BCIO:050756']
# Not including 43 Response cost [] Reinforcement ['BCIO:050756']
# Not including 45 Precontemplative with no prior behaviour change attempts ['BCIO:050715'] Clinical scenarios []
# Not including 45 Contemplative or preparative with no prior behaviour change attempts ['BCIO:050697'] Clinical scenarios []
# Not including 45 Behaviour modification or maintenance of behaviour change [] Clinical scenarios []
# Not including 45 Lapse ['BCIO:050482'] Clinical scenarios []
# Not including 45 Precontemplative or contemplative with prior behaviour change attempts ['BCIO:050697'] Clinical scenarios []
# Not including 45 Clinical scenarios [] Behaviour change ['BCIO:050209']
# Not including 48 Gains [] Edited prospects ['BCIO:006026', 'BCIO:050633']
# Not including 48 Losses [] Edited prospects ['BCIO:006026', 'BCIO:050633']
# Not including 48 Reference point [] Coding ['MFOEM:000085']
# Not including 48 Prospect [] Coding ['MFOEM:000085']
# Not including 48 Segregation ['BCIO:006115'] Editing phase []
# Not including 48 Certainty effect ['BCIO:050849'] Editing phase []
# Not including 48 Isolation effect ['BCIO:006115'] Editing phase []
# Not including 48 Detection of dominance ['BCIO:006115'] Editing phase []
# Not including 56 Motivation ['BCIO:006133'] Behaviour []
# Not including 56 Satisfaction / fulfillment of needs [] Intrinsic regulation ['BCIO:050822']
# Not including 56 Frustration of needs [] Non-regulation []
# Not including 56 Supports [] Satisfaction / fulfillment of needs []
# Not including 56 Thwarts [] Frustration of needs []
# Not including 56 Non-regulation [] Amotivation ['BCIO:050697', 'ENVO:01000254', 'BCIO:050701', 'BCIO:050697']
# Not including 56 Social contexts [] Needs ['BCIO:006064']
# Not including 56 Integrated regulation [] Extrinsic motivation / goals ['BCIO:006307']
# Not including 56 Autonomous motivation [] Motivation ['BCIO:006133']
# Not including 56 Intrinsic regulation ['BCIO:050822'] Autonomous motivation []
# Not including 56 Integrated regulation [] Autonomous motivation []
# Not including 56 Identified regulation ['BCIO:050843'] Autonomous motivation []
# Not including 56 Supports [] Social contexts []
# Not including 56 Thwarts [] Social contexts []
# Not including 58 Attributional processes ['BCIO:050689'] Self-reinforcement []
# Not including 58 Self-reinforcement stage ['BCIO:006106'] Behaviour []
# Not including 58 Behaviour [] Self-monitoring stage ['BCIO:006137']
# Not including 58 Self-monitoring outcome [] Self-evaluation stage ['BCIO:050853']
# Not including 58 Self-monitoring outcome [] Discrepancy []
# Not including 58 Standards ['BCIO:006079'] Discrepancy []
# Not including 58 Self-reinforcement [] Self-reinforcement stage ['BCIO:006106']
# Not including 58 Discrepancy [] Self-regulation ['BCIO:050268']
# Not including 60 Self-change processes ['BCIO:050268'] Action state []
# Not including 60 Outcomes ['BCIO:050806'] Action state []
# Not including 60 Health protective action / health habits ['BCIO:050821'] Action state []
# Not including 60 Social interdependence ['BCIO:006099'] Action state []
# Not including 62 Key events [] External environment ['BCIO:050727']
# Not including 62 Secular trends [] External environment ['BCIO:050727']
# Not including 62 Technologies [] External environment ['BCIO:050727']
# Not including 63 Outcome expectations [] Forethought capability ['BCIO:006005']
# Not including 63 Outcome expectations [] Self-regulatory capability ['BCIO:006005']
# Not including 65 Social Bonding ['BCIO:050749'] Delinquent / non-delinquent Behaviour []
# Not including 65 Units of Socialisation ['BCIO:006001'] Delinquent / non-delinquent Behaviour []
# Not including 65 Units of Socialisation ['BCIO:006001'] Opportunities for  involvement (prosocial / antisocial) []
# Not including 65 External constraints [] Delinquent / non-delinquent Behaviour []
# Not including 65 Units of Socialisation ['BCIO:006001'] Reinforcement for  involvement (prosocial / antisocial) []
# Not including 65 Position in the social structure [] Opportunities for  involvement (prosocial / antisocial) []
# Not including 65 Constitutional factors [] Reinforcement for  involvement (prosocial / antisocial) []
# Not including 65 Constitutional factors [] Opportunities for  involvement (prosocial / antisocial) []
# Not including 65 Reinforcement for  involvement (prosocial / antisocial) [] Involvement (prosocial / antisocial) ['BCIO:036025']
# Not including 65 Opportunities for  involvement (prosocial / antisocial) [] Involvement (prosocial / antisocial) ['BCIO:036025']
# Not including 65 Communities [] Units of Socialisation ['BCIO:006001']
# Not including 65 Sex [] Position in the social structure []
# Not including 65 SES [] Position in the social structure []
# Not including 65 Race [] Position in the social structure []
# Not including 82 Stimulus control ['BCIO:050811'] Action maintenance transition []
# Not including 82 Counter-conditioning ['BCIO:050846'] Preparation action transition []
# Not including 82 Counter-conditioning ['BCIO:050846'] Action maintenance transition []
# Not including 82 Reinforcement management ['BCIO:050738'] Action maintenance transition []
# Not including 82 Self-liberation ['BCIO:006154'] Contemplation preparation transition []
# Not including 82 Self-liberation ['BCIO:006154'] Action maintenance transition []
# Not including 82 Precontemplation contemplation transition [] Stage of change []
# Not including 82 Precontemplation contemplation transition [] Stage of change []
# Not including 82 Contemplation preparation transition [] Stage of change []
# Not including 82 Preparation action transition [] Stage of change []
# Not including 82 Contemplation preparation transition [] Stage of change []
# Not including 82 Action maintenance transition [] Stage of change []
# Not including 82 Preparation action transition [] Stage of change []
# Not including 82 Action maintenance transition [] Stage of change []
# Not including 83 Self-transcendent values ['BCIO:050708', 'BCIO:050781'] New ecological paradigm []
# Not including 83 Egoistic values ['BCIO:050637'] New ecological paradigm []
# Not including 83 Traditional values ['BCIO:050792'] New ecological paradigm []
# Not including 83 New ecological paradigm [] Awareness of consequences (beliefs) ['BCIO:006306']
# Not including 83 Openness to change values ['BCIO:050729'] New ecological paradigm []
# Not including 83 Self-transcendent values ['BCIO:050708', 'BCIO:050781'] Personal  values []
# Not including 83 Egoistic values ['BCIO:050637'] Personal  values []
# Not including 83 Traditional values ['BCIO:050792'] Personal  values []
# Not including 83 Openness to change values ['BCIO:050729'] Personal  values []
# Not including 83 Altruistic values [] Self-transcendent values ['BCIO:050708', 'BCIO:050781']
# Not including 83 Biospheric values [] Self-transcendent values ['BCIO:050708', 'BCIO:050781']

# %%
from collections import Counter

cnt = Counter(annotated_triples)

cnt
# Out:
# Counter({('BFO:0000038',
#           'one-dimensional temporal region',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 9,
#          ('BCIO:006001',
#           'social environmental system',
#           'Part of',
#           'ENVO:01000254',
#           'environmental system'): 8,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 7,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 6,
#          ('BCIO:006125',
#           'operant conditioning',
#           'Type of',
#           'BCIO:050684',
#           'intermittent schedule of reinforcement'): 5,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:006099',
#           'social influence behaviour'): 4,
#          ('BCIO:006090',
#           'social behavioural opportunity',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 4,
#          ('BCIO:006048',
#           'behavioural decision',
#           'Type of',
#           'BCIO:006116',
#           'decision-making'): 4,
#          ('BCIO:006048',
#           'behavioural decision',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 4,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 4,
#          ('BCIO:006043',
#           'self-efficacy belief for a behaviour and its associated outcomes',
#           'Positively influences',
#           'BCIO:006016',
#           'behavioural intention'): 4,
#          ('BCIO:050576',
#           'behaviour maintenance self-efficacy',
#           'Influences',
#           'MF:0000027',
#           'planning'): 4,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 4,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 4,
#          ('BFO:0000038',
#           'one-dimensional temporal region',
#           'Transitions to',
#           'BCIO:050683',
#           'intention to enact a behaviour'): 4,
#          ('BFO:0000038',
#           'one-dimensional temporal region',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 4,
#          ('BCIO:050750',
#           'psychological attachment to conventional society',
#           'Part of',
#           'BCIO:050749',
#           'psychological attachment formation to conventional society'): 4,
#          ('BCIO:050671',
#           'group evaluative behavioural norm',
#           'Part of',
#           'BCIO:006090',
#           'social behavioural opportunity'): 4,
#          ('BCIO:006148',
#           'evaluative belief about the consequences of behaviour',
#           'Influences (*)',
#           'BCIO:050328',
#           'attitude'): 3,
#          ('BCIO:006090',
#           'social behavioural opportunity',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 3,
#          ('BCIO:006042',
#           'normative belief',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 3,
#          ('OMRSE:00000064',
#           'school facility',
#           'Type of',
#           'BCIO:006001',
#           'social environmental system'): 3,
#          ('BCIO:050219',
#           'belief about health consequences of behaviour',
#           'Part of',
#           'BCIO:006019',
#           'belief about consequences of behaviour'): 3,
#          ('BCIO:006064',
#           'psychological need',
#           'Part of',
#           'BCIO:006133',
#           'behavioural motivation'): 3,
#          ('MFOEM:000001',
#           'emotion process',
#           'Part of',
#           'MFOEM:000195',
#           'affective process'): 3,
#          ('BCIO:050806',
#           'behavioural consequence',
#           'Influences',
#           'BCIO:006133',
#           'behavioural motivation'): 3,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Influences',
#           'MF:0000041',
#           'belief'): 3,
#          ('BCIO:006039',
#           'perceived norm',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 3,
#          ('BCIO:006154',
#           'self-efficacy belief for a behaviour',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 3,
#          ('BCIO:050215',
#           'behavioural capability',
#           'Part of',
#           'BCIO:006086',
#           'behavioural opportunity'): 3,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BCIO:050683',
#           'intention to enact a behaviour'): 3,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 3,
#          ('BCIO:050477',
#           'having enacted a behaviour',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 3,
#          ('BCIO:050477',
#           'having enacted a behaviour',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 3,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Influences',
#           'ENVO:01000254',
#           'environmental system'): 3,
#          ('BCIO:006133',
#           'behavioural motivation',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 3,
#          ('BCIO:007055',
#           'demonstrate the behaviour BCT',
#           'Type of',
#           'BCIO:003000',
#           'behaviour change intervention'): 3,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:050848',
#           'capability to imagine future scenarios'): 3,
#          ('BCIO:006001',
#           'social environmental system',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 3,
#          ('BCIO:050300',
#           'personal attribute',
#           'Part of',
#           'MF:0000032',
#           'bodily disposition'): 3,
#          ('BCIO:050300',
#           'personal attribute',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 3,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:036035',
#           'economic behaviour'): 3,
#          ('BCIO:006059',
#           'motivation to comply',
#           'Influences (*)',
#           'BCIO:006042',
#           'normative belief'): 2,
#          ('BCIO:006019',
#           'belief about consequences of behaviour',
#           'Influences (*)',
#           'BCIO:050328',
#           'attitude'): 2,
#          ('BCIO:050671',
#           'group evaluative behavioural norm',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 2,
#          ('MF:0000019',
#           'perception',
#           'Influences',
#           'BCIO:050859',
#           'desired self-regulatory standard'): 2,
#          ('BCIO:050859',
#           'desired self-regulatory standard',
#           'Part of',
#           'BCIO:050956',
#           'degree of organisational hierarchie'): 2,
#          ('BCIO:050478',
#           'influencer role',
#           'Influences',
#           'BCIO:006116',
#           'decision-making'): 2,
#          ('BCIO:006001',
#           'social environmental system',
#           'Type of',
#           'BCIO:036034',
#           'human communication behaviour'): 2,
#          ('BCIO:050887',
#           'leadership role',
#           'Type of',
#           'BCIO:036034',
#           'human communication behaviour'): 2,
#          ('BCIO:050889',
#           'person in a social environmental system',
#           'Type of',
#           'BCIO:036034',
#           'human communication behaviour'): 2,
#          ('BCIO:006001',
#           'social environmental system',
#           'Type of',
#           'BCIO:050556',
#           'mass media mode of delivery'): 2,
#          ('BCIO:050328',
#           'attitude',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 2,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Part of',
#           'BCIO:006042',
#           'normative belief'): 2,
#          ('BCIO:006031',
#           'belief about personal susceptibility',
#           'Part of',
#           'BCIO:006306',
#           'belief about threat'): 2,
#          ('BCIO:050603',
#           'belief about the discrepancy between one’s current and target state',
#           'Part of',
#           'BCIO:007012',
#           'attend to discrepancy between current behaviour and goal BCT'): 2,
#          ('MF:0000202',
#           'personality',
#           'Part of',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('BCIO:006040',
#           'perceived descriptive behavioural norm',
#           'Type of',
#           'BCIO:006039',
#           'perceived norm'): 2,
#          ('BCIO:006041',
#           'perceived evaluative behavioural norm',
#           'Type of',
#           'BCIO:006039',
#           'perceived norm'): 2,
#          ('BCIO:006062',
#           'promotion focused motivational orientation',
#           'Type of',
#           'BCIO:006005',
#           'self-regulation capability'): 2,
#          ('MFOEM:000001',
#           'emotion process',
#           'Influences',
#           'BCIO:050328',
#           'attitude'): 2,
#          ('BCIO:050328',
#           'attitude',
#           'Influences',
#           'BCIO:050832',
#           'reflective behaviour'): 2,
#          ('MFOEM:000001',
#           'emotion process',
#           'Influences',
#           'BCIO:050813',
#           'emotional behaviour'): 2,
#          ('MFOEM:000204',
#           'emotional personality trait',
#           'Influences',
#           'MFOEM:000001',
#           'emotion process'): 2,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:050328',
#           'attitude'): 2,
#          ('BCIO:007022',
#           'provide feedback BCT',
#           'Influences (*)',
#           'BCIO:006133',
#           'behavioural motivation'): 2,
#          ('BCIO:006019',
#           'belief about consequences of behaviour',
#           'Positively influences',
#           'BCIO:006016',
#           'behavioural intention'): 2,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Influences',
#           'MF:0000027',
#           'planning'): 2,
#          ('BCIO:006043',
#           'self-efficacy belief for a behaviour and its associated outcomes',
#           'Positively influences',
#           'BCIO:050844',
#           'action planning'): 2,
#          ('MF:0000027',
#           'planning',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:050576',
#           'behaviour maintenance self-efficacy',
#           'Positively influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:006043',
#           'self-efficacy belief for a behaviour and its associated outcomes',
#           'Part of',
#           'BCIO:006016',
#           'behavioural intention'): 2,
#          ('BCIO:050844',
#           'action planning',
#           'Type of',
#           'MF:0000027',
#           'planning'): 2,
#          ('BCIO:050624',
#           'coping planning',
#           'Type of',
#           'MF:0000027',
#           'planning'): 2,
#          ('MF:0000027',
#           'planning',
#           'Part of',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:050576',
#           'behaviour maintenance self-efficacy',
#           'Part of',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:050576',
#           'behaviour maintenance self-efficacy',
#           'Type of',
#           'BCIO:006043',
#           'self-efficacy belief for a behaviour and its associated outcomes'): 2,
#          ('BCIO:050219',
#           'belief about health consequences of behaviour',
#           'Correlates with',
#           'BCIO:006020',
#           'belief about social consequences of behaviour'): 2,
#          ('BCIO:006154',
#           'self-efficacy belief for a behaviour',
#           'Correlates with',
#           'BCIO:050219',
#           'belief about health consequences of behaviour'): 2,
#          ('BCIO:006154',
#           'self-efficacy belief for a behaviour',
#           'Part of',
#           'BCIO:006019',
#           'belief about consequences of behaviour'): 2,
#          ('BCIO:006133',
#           'behavioural motivation',
#           'Influences',
#           'BCIO:006034',
#           'belief about choice over a behaviour'): 2,
#          ('BCIO:006064',
#           'psychological need',
#           'Part of',
#           'BCIO:050767',
#           'self-motive'): 2,
#          ('MF:0000048',
#           'mental capability',
#           'Type of',
#           'BCIO:050215',
#           'behavioural capability'): 2,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Part of',
#           'BCIO:006086',
#           'behavioural opportunity'): 2,
#          ('BCIO:050698',
#           'low opportunity to enact a behaviour',
#           'Part of',
#           'BCIO:006086',
#           'behavioural opportunity'): 2,
#          ('BCIO:006154',
#           'self-efficacy belief for a behaviour',
#           'Part of',
#           'BCIO:006043',
#           'self-efficacy belief for a behaviour and its associated outcomes'): 2,
#          ('BCIO:006001',
#           'social environmental system',
#           'Influences',
#           'BCIO:006099',
#           'social influence behaviour'): 2,
#          ('MF:0000041',
#           'belief',
#           'Influences',
#           'ADDICTO:0001135',
#           'alcohol consumption pattern'): 2,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 2,
#          ('MF:0000041',
#           'belief',
#           'Part of',
#           'MF:0000033',
#           'mental disposition'): 2,
#          ('MF:0000041',
#           'belief',
#           'Part of',
#           'MF:0000020',
#           'mental process'): 2,
#          ('MF:0000041',
#           'belief',
#           'Part of',
#           'BCIO:015161',
#           'personal history'): 2,
#          ('BCIO:006154',
#           'self-efficacy belief for a behaviour',
#           'Type of',
#           'MF:0000041',
#           'belief'): 2,
#          ('BCIO:050577',
#           'behavioural barrier',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:006041',
#           'perceived evaluative behavioural norm',
#           'Part of',
#           'BCIO:006039',
#           'perceived norm'): 2,
#          ('BCIO:006052',
#           'knowledge',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('MFOEM:000195',
#           'affective process',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:015098',
#           'gender identity',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 2,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 2,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Part of',
#           'BCIO:006063',
#           'personal value'): 2,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:006086',
#           'behavioural opportunity'): 2,
#          ('BCIO:050215',
#           'behavioural capability',
#           'Influences',
#           'BCIO:006133',
#           'behavioural motivation'): 2,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:050215',
#           'behavioural capability'): 2,
#          ('BCIO:050643',
#           'environmental opportunity for pleasure',
#           'Part of',
#           'BCIO:006064',
#           'psychological need'): 2,
#          ('BCIO:006086',
#           'behavioural opportunity',
#           'Part of',
#           'BCIO:006064',
#           'psychological need'): 2,
#          ('BCIO:006064',
#           'psychological need',
#           'Part of',
#           'BCIO:050215',
#           'behavioural capability'): 2,
#          ('BCIO:006019',
#           'belief about consequences of behaviour',
#           'Type of',
#           'BCIO:050649',
#           'evaluative belief about the possible future consequences of one’s behaviour'): 2,
#          ('BCIO:050760',
#           'schedule of reinforcement',
#           'Type of',
#           'BCIO:050756',
#           'reinforcer'): 2,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BCIO:050683',
#           'intention to enact a behaviour'): 2,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BCIO:050493',
#           'undecidedness about enacting a behaviour'): 2,
#          ('BFO:0000038',
#           'one-dimensional temporal region',
#           'Transitions to',
#           'BCIO:050493',
#           'undecidedness about enacting a behaviour'): 2,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 2,
#          ('BCIO:050683',
#           'intention to enact a behaviour',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 2,
#          ('BCIO:050683',
#           'intention to enact a behaviour',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 2,
#          ('BCIO:050923',
#           'behaviour intender',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 2,
#          ('BCIO:050923',
#           'behaviour intender',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 2,
#          ('ADDICTO:0000399',
#           'self-identity',
#           'Influences',
#           'BCIO:050638',
#           'emotion about self'): 2,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Part of',
#           'ADDICTO:0000399',
#           'self-identity'): 2,
#          ('BCIO:050228',
#           'mental plan',
#           'Part of',
#           'ADDICTO:0000399',
#           'self-identity'): 2,
#          ('ADDICTO:0000399',
#           'self-identity',
#           'Part of',
#           'MF:0000032',
#           'bodily disposition'): 2,
#          ('BCIO:050638',
#           'emotion about self',
#           'Influences',
#           'ADDICTO:0000399',
#           'self-identity'): 2,
#          ('BCIO:050819',
#           'harm preventing behaviour',
#           'Type of',
#           'BCIO:050890',
#           'protective factor for harmful behaviour'): 2,
#          ('BCIO:050489',
#           'personal vulnerability to harmful behaviour',
#           'Type of',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('BCIO:006086',
#           'behavioural opportunity',
#           'Type of',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Type of',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('ENVO:01000254',
#           'environmental system',
#           'Part of',
#           'BCIO:006086',
#           'behavioural opportunity'): 2,
#          ('BCIO:050231',
#           'temporal orientation to the present',
#           'Influences',
#           'ADDICTO:0000349',
#           'addiction'): 2,
#          ('BCIO:006049',
#           'goal',
#           'Type of',
#           'BCIO:050818',
#           'goal-directed behaviour'): 2,
#          ('BCIO:006307',
#           'extrinsic motivation',
#           'Type of',
#           'BCIO:006133',
#           'behavioural motivation'): 2,
#          ('BCIO:050697',
#           'low motivational disposition to change behaviour',
#           'Type of',
#           'BCIO:006133',
#           'behavioural motivation'): 2,
#          ('ENVO:01000254',
#           'environmental system',
#           'Type of',
#           'BCIO:006133',
#           'behavioural motivation'): 2,
#          ('BCIO:007094',
#           'practise behaviour BCT',
#           'Influences',
#           'BCIO:050886',
#           'extent of past behavioural achievement'): 2,
#          ('BCIO:007055',
#           'demonstrate the behaviour BCT',
#           'Influences',
#           'GO:0098597',
#           'observational learning'): 2,
#          ('BCIO:007094',
#           'practise behaviour BCT',
#           'Type of',
#           'BCIO:003000',
#           'behaviour change intervention'): 2,
#          ('BCIO:007089',
#           'systematically desensitise BCT',
#           'Type of',
#           'BCIO:003000',
#           'behaviour change intervention'): 2,
#          ('BCIO:006152',
#           'belief about control over behaviour',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 2,
#          ('BCIO:006152',
#           'belief about control over behaviour',
#           'Part of',
#           'BCIO:050735',
#           'positive evaluative belief about a behaviour'): 2,
#          ('BCIO:050215',
#           'behavioural capability',
#           'Part of',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('BCIO:006001',
#           'social environmental system',
#           'Influences',
#           'BCIO:050671',
#           'group evaluative behavioural norm'): 2,
#          ('BCIO:050215',
#           'behavioural capability',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 2,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Influences',
#           'BCIO:050215',
#           'behavioural capability'): 2,
#          ('BCIO:006005',
#           'self-regulation capability',
#           'Type of',
#           'BCIO:050215',
#           'behavioural capability'): 2,
#          ('BCIO:050792',
#           'traditional personal value',
#           'Part of',
#           'BCIO:050749',
#           'psychological attachment formation to conventional society'): 2,
#          ('BCIO:050215',
#           'behavioural capability',
#           'Influences (*)',
#           'BCIO:036025',
#           'inter-personal behaviour'): 2,
#          ('BCIO:006002',
#           'family environmental system',
#           'Type of',
#           'BCIO:006001',
#           'social environmental system'): 2,
#          ('BCIO:010104',
#           'peer',
#           'Type of',
#           'BCIO:006001',
#           'social environmental system'): 2,
#          ('BCIO:050775',
#           'social identity process',
#           'Part of',
#           'BCIO:006090',
#           'social behavioural opportunity'): 2,
#          ('BCIO:050800',
#           'observational learning',
#           'Part of',
#           'BCIO:006090',
#           'social behavioural opportunity'): 2,
#          ('BCIO:050672',
#           'group facilitation behaviour',
#           'Part of',
#           'BCIO:006090',
#           'social behavioural opportunity'): 2,
#          ('ADDICTO:0001087',
#           'social identity',
#           'Part of',
#           'BCIO:006090',
#           'social behavioural opportunity'): 2,
#          ('BCIO:006001',
#           'social environmental system',
#           'Part of',
#           'BCIO:050891',
#           'social group'): 2,
#          ('BCIO:006095',
#           'normative behaviour',
#           'Type of',
#           'BCIO:006039',
#           'perceived norm'): 2,
#          ('BCIO:006095',
#           'normative behaviour',
#           'Type of',
#           'BCIO:050671',
#           'group evaluative behavioural norm'): 2,
#          ('BCIO:050300',
#           'personal attribute',
#           'Influences',
#           'BCIO:050893',
#           'socio-demographic characteristic'): 2,
#          ('BCIO:050893',
#           'socio-demographic characteristic',
#           'Part of',
#           'BCIO:015092',
#           'health status attribute'): 2,
#          ('BCIO:050893',
#           'socio-demographic characteristic',
#           'Part of',
#           'MF:0000021',
#           'interpersonal process'): 2,
#          ('ADDICTO:0000399',
#           'self-identity',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 2,
#          ('BCIO:006063',
#           'personal value',
#           'Influences',
#           'BCIO:036089',
#           'political behaviour'): 2,
#          ('BCIO:050635',
#           'economic environmental system',
#           'Influences',
#           'ENVO:01000254',
#           'environmental system'): 2,
#          ('BCIO:050564',
#           'affective attitude acquired through association',
#           'Influences',
#           'BCIO:050590',
#           'belief about emotional consequences of goal attainment'): 1,
#          ('BCIO:050590',
#           'belief about emotional consequences of goal attainment',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:050590',
#           'belief about emotional consequences of goal attainment',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:006034',
#           'belief about choice over a behaviour',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:006034',
#           'belief about choice over a behaviour',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('MFOEM:000075',
#           'appraisal of causal agency',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('MFOEM:000075',
#           'appraisal of causal agency',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:050886',
#           'extent of past behavioural achievement',
#           'Influences',
#           'BCIO:007023',
#           'provide feedback on behaviour BCT'): 1,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Positively influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Positively influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:006042',
#           'normative belief',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:006042',
#           'normative belief',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:006059',
#           'motivation to comply',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:006059',
#           'motivation to comply',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:050328', 'attitude', 'Influences', 'MF:0000045', 'wanting'): 1,
#          ('BCIO:050328',
#           'attitude',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:006096',
#           'goal pursuit process',
#           'Positively influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('BCIO:006034',
#           'belief about choice over a behaviour',
#           'Positively influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('MFOEM:000075',
#           'appraisal of causal agency',
#           'Positively influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('BCIO:006034',
#           'belief about choice over a behaviour',
#           'Positively influences',
#           'BCIO:006096',
#           'goal pursuit process'): 1,
#          ('MFOEM:000075',
#           'appraisal of causal agency',
#           'Positively influences',
#           'BCIO:006096',
#           'goal pursuit process'): 1,
#          ('BCIO:050817',
#           'frequency of past behaviour',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:050817',
#           'frequency of past behaviour',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:006063',
#           'personal value',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:006063',
#           'personal value',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:050775',
#           'social identity process',
#           'Influences',
#           'MF:0000045',
#           'wanting'): 1,
#          ('BCIO:050775',
#           'social identity process',
#           'Influences',
#           'BCIO:050316',
#           'subjective need'): 1,
#          ('BCIO:050775',
#           'social identity process',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('BCIO:050918',
#           'low frequency of past behaviour',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('BCIO:050453',
#           'behaviour end point',
#           'Positively influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('BCIO:050481',
#           'past behaviour',
#           'Positively influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('BCIO:050917',
#           'high frequency of past behaviour',
#           'Influences',
#           'BCIO:050818',
#           'goal-directed behaviour'): 1,
#          ('BCIO:006034',
#           'belief about choice over a behaviour',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('MFOEM:000075',
#           'appraisal of causal agency',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('BCIO:050617',
#           'comparative desirability appraisal',
#           'Influences (*)',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('BCIO:050592',
#           'belief about goal attainment',
#           'Influences (*)',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('MFOEM:000001',
#           'emotion process',
#           'Part of',
#           'BCIO:050564',
#           'affective attitude acquired through association'): 1,
#          ('BCIO:006042',
#           'normative belief',
#           'Influences (*)',
#           'BCIO:006059',
#           'motivation to comply'): 1,
#          ('MF:0000041',
#           'belief',
#           'Influences (*)',
#           'BCIO:050328',
#           'attitude'): 1,
#          ('MF:0000041',
#           'belief',
#           'Influences (*)',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('MF:0000041',
#           'belief',
#           'Influences (*)',
#           'BCIO:006059',
#           'motivation to comply'): 1,
#          ('BCIO:006019',
#           'belief about consequences of behaviour',
#           'Influences (*)',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('BCIO:006019',
#           'belief about consequences of behaviour',
#           'Influences (*)',
#           'BCIO:006059',
#           'motivation to comply'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences (*)',
#           'BCIO:050328',
#           'attitude'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences (*)',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences (*)',
#           'BCIO:006059',
#           'motivation to comply'): 1,
#          ('BCIO:006148',
#           'evaluative belief about the consequences of behaviour',
#           'Influences (*)',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('BCIO:006148',
#           'evaluative belief about the consequences of behaviour',
#           'Influences (*)',
#           'BCIO:006059',
#           'motivation to comply'): 1,
#          ('BCIO:050917',
#           'high frequency of past behaviour',
#           'Part of',
#           'BCIO:050817',
#           'frequency of past behaviour'): 1,
#          ('BCIO:050918',
#           'low frequency of past behaviour',
#           'Part of',
#           'BCIO:050817',
#           'frequency of past behaviour'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:006134',
#           'automatic behavioural motivation',
#           'Influences',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:006001',
#           'social environmental system',
#           'Influences (*)',
#           'BCIO:036072',
#           'antisocial behaviour'): 1,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Influences (*)',
#           'BCIO:036072',
#           'antisocial behaviour'): 1,
#          ('BCIO:006005',
#           'self-regulation capability',
#           'Influences (*)',
#           'BCIO:036072',
#           'antisocial behaviour'): 1,
#          ('ADDICTO:0000399',
#           'self-identity',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:006035',
#           'evaluation of self',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:050890',
#           'protective factor for harmful behaviour',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:050708',
#           'moral personal value',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:006006',
#           'behavioural self-regulation capability',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:006060',
#           'motivational orientation',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:050954',
#           'behavioural substitution capability',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:050580',
#           'behavioural dissonance reduction through mental process',
#           'Part of',
#           'BCIO:006005',
#           'self-regulation capability'): 1,
#          ('BCIO:050656',
#           'extrinsic social motivation',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050656',
#           'extrinsic social motivation',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 1,
#          ('BCIO:050671',
#           'group evaluative behavioural norm',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 1,
#          ('BCIO:050803',
#           'association behaviour with a pro-social group',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050803',
#           'association behaviour with a pro-social group',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 1,
#          ('BCIO:050778',
#           'social reinforcement process for a behaviour',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050778',
#           'social reinforcement process for a behaviour',
#           'Part of',
#           'BCIO:006099',
#           'social influence behaviour'): 1,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Influences',
#           'BCIO:050823',
#           'impact of behaviour on environment'): 1,
#          ('BCIO:050619',
#           'comparison of current situation with a standard',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050823',
#           'impact of behaviour on environment',
#           'Influences',
#           'MF:0000019',
#           'perception'): 1,
#          ('MF:0000019',
#           'perception',
#           'Influences',
#           'BCIO:050619',
#           'comparison of current situation with a standard'): 1,
#          ('MF:0000019',
#           'perception',
#           'Influences',
#           'BCIO:050860',
#           'desired standard for self-identity'): 1,
#          ('BCIO:050860',
#           'desired standard for self-identity',
#           'Influences',
#           'BCIO:050859',
#           'desired self-regulatory standard'): 1,
#          ('BCIO:006079',
#           'desired standard',
#           'Influences',
#           'BCIO:050619',
#           'comparison of current situation with a standard'): 1,
#          ('BCIO:006086',
#           'behavioural opportunity',
#           'Influences',
#           'BCIO:050823',
#           'impact of behaviour on environment'): 1,
#          ('BCIO:050860',
#           'desired standard for self-identity',
#           'Part of',
#           'BCIO:050956',
#           'degree of organisational hierarchie'): 1,
#          ('BCIO:006003',
#           'friendship network',
#           'Influences',
#           'GO:0007612',
#           'learning'): 1,
#          ('BCIO:036084',
#           'association behaviour',
#           'Influences',
#           'GO:0007612',
#           'learning'): 1,
#          ('BCIO:036034',
#           'human communication behaviour',
#           'Influences',
#           'GO:0007612',
#           'learning'): 1,
#          ('GO:0007612',
#           'learning',
#           'Influences',
#           'BCIO:006039',
#           'perceived norm'): 1,
#          ('BCIO:050455',
#           'behavioural duration',
#           'Influences',
#           'BCIO:036084',
#           'association behaviour'): 1,
#          ('BCIO:050893',
#           'socio-demographic characteristic',
#           'Influences',
#           'BCIO:036084',
#           'association behaviour'): 1,
#          ('BCIO:050771',
#           'social embeddedness in a social group',
#           'Influences',
#           'BCIO:036084',
#           'association behaviour'): 1,
#          ('BCIO:050428',
#           'behavioural frequency',
#           'Influences',
#           'BCIO:036084',
#           'association behaviour'): 1,
#          ('BCIO:006039',
#           'perceived norm',
#           'Influences',
#           'BCIO:050810',
#           'criminal behaviour'): 1,
#          ('BCIO:015161',
#           'personal history',
#           'Influences',
#           'BCIO:050810',
#           'criminal behaviour'): 1,
#          ('BCIO:050950',
#           'social learning',
#           'Part of',
#           'GO:0007612',
#           'learning'): 1,
#          ('MF:0000048',
#           'mental capability',
#           'Part of',
#           'GO:0007612',
#           'learning'): 1,
#          ('BCIO:050731',
#           'person’s environmental system',
#           'Influences (*)',
#           'BCIO:015161',
#           'personal history'): 1,
#          ('BCIO:006086',
#           'behavioural opportunity',
#           'Influences (*)',
#           'BCIO:050731',
#           'person’s environmental system'): 1,
#          ('GO:0007612',
#           'learning',
#           'Influences (*)',
#           'BCIO:015161',
#           'personal history'): 1,
#          ('BCIO:036084',
#           'association behaviour',
#           'Influences (*)',
#           'BCIO:015161',
#           'personal history'): 1,
#          ('BCIO:050238',
#           'non-linguistic communication behaviour',
#           'Influences (*)',
#           'BCIO:036034',
#           'human communication behaviour'): 1,
#          ('BCIO:050237',
#           'linguistic communication behaviour',
#           'Influences (*)',
#           'BCIO:036034',
#           'human communication behaviour'): 1,
#          ('BCIO:036034',
#           'human communication behaviour',
#           'Influences',
#           'BCIO:037024',
#           None): 1,
#          ('BCIO:006054',
#           'knowledge regarding an innovation',
#           'Transitions to',
#           'BCIO:050650',
#           'evaluative belief formation'): 1,
#          ('BCIO:050650',
#           'evaluative belief formation',
#           'Transitions to',
#           'BCIO:006048',
#           'behavioural decision'): 1,
#          ('BCIO:006048',
#           'behavioural decision',
#           'Transitions to',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Transitions to',
#           'BCIO:050802',
#           'approval seeking behaviour'): 1,
#          ('BCIO:050798',
#           'willingness to adopt new behaviours',
#           'Influences',
#           'BCIO:050729',
#           'openness-to-change personal value'): 1,
#          ('BCIO:006001',
#           'social environmental system',
#           'Influences',
#           'BCIO:050921',
#           'behaviour change rate'): 1,
#          ('BCIO:006001',
#           'social environmental system',
#           'Negatively influences',
#           'BCIO:050864',
#           'feeling of uncertainty about one’s behaviour'): 1,
#          ('BCIO:050681',
#           'intention for collective behaviour',
#           'Positively influences',
#           'BCIO:050769',
#           'similarity to other people'): 1,
#          ('BCIO:050478',
#           'influencer role',
#           'Influences',
#           'BCIO:050769',
#           'similarity to other people'): 1,
#          ('BCIO:006116',
#           'decision-making',
#           'Influences',
#           'BCIO:050806',
#           'behavioural consequence'): 1,
#          ('BCIO:050806',
#           'behavioural consequence',
#           'Influences',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050773',
#           'social environmental system attribute',
#           'Influences',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050773',
#           'social environmental system attribute',
#           'Influences',
#           'BCIO:050921',
#           'behaviour change rate'): 1,
#          ('BCIO:050769',
#           'similarity to other people',
#           'Type of',
#           'BCIO:036034',
#           'human communication behaviour'): 1,
#          ('BCIO:050842',
#           'role model for a person',
#           'Type of',
#           'BCIO:036034',
#           'human communication behaviour'): 1,
#          ('BCIO:050556',
#           'mass media mode of delivery',
#           'Type of',
#           'BCIO:050384',
#           'communication'): 1,
#          ('BCIO:036034',
#           'human communication behaviour',
#           'Type of',
#           'BCIO:050384',
#           'communication'): 1,
#          ('BCIO:050681',
#           'intention for collective behaviour',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:006095',
#           'normative behaviour',
#           'Part of',
#           'BCIO:006001',
#           'social environmental system'): 1,
#          ('BCIO:050773',
#           'social environmental system attribute',
#           'Type of',
#           'BCIO:006095',
#           'normative behaviour'): 1,
#          ('BCIO:050478',
#           'influencer role',
#           'Type of',
#           'BCIO:050773',
#           'social environmental system attribute'): 1,
#          ('BCIO:006054',
#           'knowledge regarding an innovation',
#           'Part of',
#           'BCIO:006116',
#           'decision-making'): 1,
#          ('BCIO:050650',
#           'evaluative belief formation',
#           'Part of',
#           'BCIO:006116',
#           'decision-making'): 1,
#          ('BCIO:006048',
#           'behavioural decision',
#           'Part of',
#           'BCIO:006116',
#           'decision-making'): 1,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Part of',
#           'BCIO:006116',
#           'decision-making'): 1,
#          ('BCIO:050802',
#           'approval seeking behaviour',
#           'Part of',
#           'BCIO:006116',
#           'decision-making'): 1,
#          ('BCIO:050481',
#           'past behaviour',
#           'Part of',
#           'BCIO:006048',
#           'behavioural decision'): 1,
#          ('BCIO:050799',
#           'appraisal of desirability',
#           'Type of',
#           'BCIO:050806',
#           'behavioural consequence'): 1,
#          ('MFOEM:000060',
#           'appraisal of expectedness',
#           'Type of',
#           'BCIO:050806',
#           'behavioural consequence'): 1,
#          ('BCIO:006074',
#           'social embeddedness',
#           'Type of',
#           'BCIO:050773',
#           'social environmental system attribute'): 1,
#          ('BCIO:036011',
#           'social organisation behaviour',
#           'Type of',
#           'BCIO:050773',
#           'social environmental system attribute'): 1,
#          ('BCIO:050938',
#           'centralisation of decision-making',
#           'Type of',
#           'BCIO:050773',
#           'social environmental system attribute'): 1,
#          ('BCIO:006052',
#           'knowledge',
#           'Influences',
#           'BCIO:050328',
#           'attitude'): 1,
#          ('MF:0000041', 'belief', 'Influences', 'BCIO:050328', 'attitude'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('BCIO:006095',
#           'normative behaviour',
#           'Part of',
#           'ENVO:01000254',
#           'environmental system'): 1,
#          ('ADDICTO:0001273',
#           'public health promotion policy',
#           'Part of',
#           'ENVO:01000254',
#           'environmental system'): 1,
#          ('BCIO:050600',
#           'belief about social support for a behaviour',
#           'Part of',
#           'BCIO:006042',
#           'normative belief'): 1,
#          ('BCIO:050219',
#           'belief about health consequences of behaviour',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 1,
#          ('BCIO:050219',
#           'belief about health consequences of behaviour',
#           'Part of',
#           'MF:0000041',
#           'belief'): 1,
#          ('BCIO:006149',
#           'belief about the personal desirability of consequences of a behaviour',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 1,
#          ('BCIO:006149',
#           'belief about the personal desirability of consequences of a behaviour',
#           'Part of',
#           'MF:0000041',
#           'belief'): 1,
#          ('BCIO:006147',
#           'evaluative belief about a behaviour',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 1,
#          ('BCIO:006147',
#           'evaluative belief about a behaviour',
#           'Part of',
#           'MF:0000041',
#           'belief'): 1,
#          ('BCIO:006031',
#           'belief about personal susceptibility',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 1,
#          ('BCIO:006031',
#           'belief about personal susceptibility',
#           'Part of',
#           'MF:0000041',
#           'belief'): 1,
#          ('BCIO:050597',
#           'belief about severity of health condition',
#           'Part of',
#           'BCIO:006052',
#           'knowledge'): 1,
#          ('BCIO:050597',
#           'belief about severity of health condition',
#           'Part of',
#           'MF:0000041',
#           'belief'): 1,
#          ('BCIO:006306',
#           'belief about threat',
#           'Positively influences',
#           'MFOEM:000026',
#           'fear'): 1,
#          ('MFOEM:000026',
#           'fear',
#           'Influences',
#           'BCIO:006306',
#           'belief about threat'): 1,
#          ('BCIO:050713',
#           'motivation to reduce harm',
#           'Positively influences',
#           'BCIO:050819',
#           'harm preventing behaviour'): 1,
#          ('BCIO:006061',
#           'prevention focused motivational orientation',
#           'Positively influences',
#           'BCIO:050673',
#           'harmful fear reduction mental process'): 1,
#          ('MFOEM:000026',
#           'fear',
#           'Positively influences',
#           'BCIO:006061',
#           'prevention focused motivational orientation'): 1,
#          ('BCIO:006143',
# ...
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050783',
#           'stimulus',
#           'Influences',
#           'BCIO:050760',
#           'schedule of reinforcement'): 1,
#          ('BCIO:036000',
#           'individual human behaviour',
#           'Influences',
#           'BCIO:050756',
#           'reinforcer'): 1,
#          ('BCIO:050756',
#           'reinforcer',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050666',
#           'generalised reinforcer',
#           'Influences',
#           'BCIO:050756',
#           'reinforcer'): 1,
#          ('BCIO:050739',
#           'positive reinforcer',
#           'Type of',
#           'BCIO:050756',
#           'reinforcer'): 1,
#          ('BCIO:050720',
#           'negative punishing stimulus',
#           'Type of',
#           'BCIO:050756',
#           'reinforcer'): 1,
#          ('BCIO:050628',
#           'differential reinforcement',
#           'Type of',
#           'BCIO:050760',
#           'schedule of reinforcement'): 1,
#          ('BCIO:050684',
#           'intermittent schedule of reinforcement',
#           'Type of',
#           'BCIO:050760',
#           'schedule of reinforcement'): 1,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BCIO:050923',
#           'behaviour intender'): 1,
#          ('BCIO:050922',
#           'behaviour enacter',
#           'Transitions to',
#           'BCIO:050923',
#           'behaviour intender'): 1,
#          ('BFO:0000038',
#           'one-dimensional temporal region',
#           'Transitions to',
#           'BCIO:050923',
#           'behaviour intender'): 1,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BCIO:050493',
#           'undecidedness about enacting a behaviour'): 1,
#          ('BCIO:050805',
#           'behaviour pattern maintenance',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050477',
#           'having enacted a behaviour',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050477',
#           'having enacted a behaviour',
#           'Transitions to',
#           'BCIO:050683',
#           'intention to enact a behaviour'): 1,
#          ('BCIO:050477',
#           'having enacted a behaviour',
#           'Transitions to',
#           'BCIO:050493',
#           'undecidedness about enacting a behaviour'): 1,
#          ('BCIO:050923',
#           'behaviour intender',
#           'Transitions to',
#           'BCIO:050683',
#           'intention to enact a behaviour'): 1,
#          ('BCIO:050683',
#           'intention to enact a behaviour',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050923',
#           'behaviour intender',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050493',
#           'undecidedness about enacting a behaviour',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050493',
#           'undecidedness about enacting a behaviour',
#           'Transitions to',
#           'BCIO:050924',
#           'behaviour non-intender'): 1,
#          ('BCIO:050493',
#           'undecidedness about enacting a behaviour',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 1,
#          ('BCIO:050924',
#           'behaviour non-intender',
#           'Transitions to',
#           'BCIO:050492',
#           'unawareness of a behaviour'): 1,
#          ('BCIO:050924',
#           'behaviour non-intender',
#           'Transitions to',
#           'BFO:0000038',
#           'one-dimensional temporal region'): 1,
#          ('BCIO:050209',
#           'individual human behaviour change',
#           'Influences',
#           'BCIO:006035',
#           'evaluation of self'): 1,
#          ('BCIO:050209',
#           'individual human behaviour change',
#           'Influences',
#           'BCIO:050898',
#           'self-efficacy belief'): 1,
#          ('BCIO:006035',
#           'evaluation of self',
#           'Influences',
#           'BCIO:050588',
#           'belief about control over valued outcomes'): 1,
#          ('BCIO:050898',
#           'self-efficacy belief',
#           'Influences',
#           'BCIO:050588',
#           'belief about control over valued outcomes'): 1,
#          ('BCIO:050716',
#           'motivational disposition to change behaviour',
#           'Influences (*)',
#           'BCIO:050209',
#           'individual human behaviour change'): 1,
#          ('BCIO:050597',
#           'belief about severity of health condition',
#           'Part of',
#           'BCIO:050716',
#           'motivational disposition to change behaviour'): 1,
#          ('BCIO:006306',
#           'belief about threat',
#           'Part of',
#           'BCIO:050716',
#           'motivational disposition to change behaviour'): 1,
#          ('BCIO:050219',
#           'belief about health consequences of behaviour',
#           'Part of',
#           'BCIO:050716',
#           'motivational disposition to change behaviour'): 1,
#          ('BCIO:050577',
#           'behavioural barrier',
#           'Part of',
#           'BCIO:050715',
#           'motivational disposition not to change behaviour'): 1,
#          ('BCIO:050577',
#           'behavioural barrier',
#           'Part of',
#           'BCIO:050698',
#           'low opportunity to enact a behaviour'): 1,
#          ('BCIO:006064',
#           'psychological need',
#           'Influences',
#           'BCIO:050234',
#           'impulse'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences',
#           'BCIO:006064',
#           'psychological need'): 1,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('BCIO:050228',
#           'mental plan',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences',
#           'BCIO:050228',
#           'mental plan'): 1,
#          ('BCIO:006064',
#           'psychological need',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:006016',
#           'behavioural intention'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:050228',
#           'mental plan'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:006064',
#           'psychological need'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:050234',
#           'impulse'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:050234',
#           'impulse',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050234',
#           'impulse',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:006064',
#           'psychological need',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:006016',
#           'behavioural intention',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:050228',
#           'mental plan',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:050638',
#           'emotion about self',
#           'Part of',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:050638',
#           'emotion about self',
#           'Part of',
#           'ADDICTO:0000399',
#           'self-identity'): 1,
#          ('BCIO:006035',
#           'evaluation of self',
#           'Part of',
#           'ADDICTO:0000399',
#           'self-identity'): 1,
#          ('BCIO:006035',
#           'evaluation of self',
#           'Type of',
#           'ADDICTO:0000399',
#           'self-identity'): 1,
#          ('BCIO:006035',
#           'evaluation of self',
#           'Type of',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('MFOEM:000006',
#           'subjective emotional feeling',
#           'Type of',
#           'BCIO:006064',
#           'psychological need'): 1,
#          ('ADDICTO:0000377',
#           'feeling of need satisfaction',
#           'Type of',
#           'BCIO:006064',
#           'psychological need'): 1,
#          ('MFOEM:000006',
#           'subjective emotional feeling',
#           'Influences',
#           'ADDICTO:0000377',
#           'feeling of need satisfaction'): 1,
#          ('ADDICTO:0000377',
#           'feeling of need satisfaction',
#           'Influences',
#           'MFOEM:000006',
#           'subjective emotional feeling'): 1,
#          ('BCIO:006064',
#           'psychological need',
#           'Influences',
#           'BCIO:050582',
#           'behavioural inhibition'): 1,
#          ('BCIO:050582',
#           'behavioural inhibition',
#           'Influences',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('MF:0000032',
#           'bodily disposition',
#           'Influences',
#           'BCIO:050582',
#           'behavioural inhibition'): 1,
#          ('BCIO:050582',
#           'behavioural inhibition',
#           'Influences',
#           'MF:0000032',
#           'bodily disposition'): 1,
#          ('BCIO:050890',
#           'protective factor for harmful behaviour',
#           'Influences',
#           'BCIO:050821',
#           'health-promoting behaviour'): 1,
#          ('BCIO:050890',
#           'protective factor for harmful behaviour',
#           'Influences',
#           'BCIO:036066',
#           'pro-social behaviour'): 1,
#          ('BCIO:050890',
#           'protective factor for harmful behaviour',
#           'Negatively influences',
#           'BCIO:036072',
#           'antisocial behaviour'): 1,
#          ('BCIO:050489',
#           'personal vulnerability to harmful behaviour',
#           'Influences',
#           'BCIO:036066',
#           'pro-social behaviour'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:036066',
#           'pro-social behaviour'): 1,
#          ('BCIO:050489',
#           'personal vulnerability to harmful behaviour',
#           'Influences',
#           'BCIO:050821',
#           'health-promoting behaviour'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Influences',
#           'BCIO:050821',
#           'health-promoting behaviour'): 1,
#          ('BCIO:050842',
#           'role model for a person',
#           'Type of',
#           'BCIO:050890',
#           'protective factor for harmful behaviour'): 1,
#          ('BCIO:050698',
#           'low opportunity to enact a behaviour',
#           'Type of',
#           'BCIO:050890',
#           'protective factor for harmful behaviour'): 1,
#          ('BCIO:050842',
#           'role model for a person',
#           'Type of',
#           'BCIO:050489',
#           'personal vulnerability to harmful behaviour'): 1,
#          ('BCIO:050842',
#           'role model for a person',
#           'Type of',
#           'ENVO:01000254',
#           'environmental system'): 1,
#          ('BCIO:036075',
#           'harmful behaviour',
#           'Type of',
#           'BCIO:050489',
#           'personal vulnerability to harmful behaviour'): 1,
#          ('BCIO:036075',
#           'harmful behaviour',
#           'Type of',
#           'ENVO:01000254',
#           'environmental system'): 1,
#          ('BCIO:006086',
#           'behavioural opportunity',
#           'Type of',
#           'BCIO:050489',
#           'personal vulnerability to harmful behaviour'): 1,
#          ('BCIO:036066',
#           'pro-social behaviour',
#           'Type of',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050821',
#           'health-promoting behaviour',
#           'Type of',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:036072',
#           'antisocial behaviour',
#           'Type of',
#           'BCIO:036000',
#           'individual human behaviour'): 1,
#          ('BCIO:050849',
#           'certainty bias',
#           'Influences',
#           'BCIO:006024',
#           'belief about likelihood of consequences of behaviour'): 1,
#          ('BCIO:006026',
#           'belief about likelihood of consequences of an occurrence',
#           'Influences',
#           'BCIO:006024',
#           'belief about likelihood of consequences of behaviour'): 1,
#          ('BCIO:050633',
#           'dissonance reduction through mental process',
#           'Influences',
#           'BCIO:006024',
#           'belief about likelihood of consequences of behaviour'): 1,
#          ('BCIO:006026',
#           'belief about likelihood of consequences of an occurrence',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('BCIO:050633',
#           'dissonance reduction through mental process',
#           'Influences',
#           'BCIO:006038',
#           'evaluative belief'): 1,
#          ('MFOEM:000085',
#           'appraisal of desirability of consequences',
#           'Type of',
#           'BCIO:006026',
#           'belief about likelihood of consequences of an occurrence'): 1,
#          ('MFOEM:000085',
#           'appraisal of desirability of consequences',
#           'Type of',
#           'BCIO:050633',
#           'dissonance reduction through mental process'): 1,
#          ('BCIO:006024',
#           'belief about likelihood of consequences of behaviour',
#           'Influences (*)',
#           'BCIO:006047',
#           'decision'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Influences (*)',
#           'BCIO:006047',
#           'decision'): 1,
#          ('BCIO:006024',
#           'belief about likelihood of consequences of behaviour',
#           'Part of',
#           'MFOEM:000002',
#           'appraisal process'): 1,
#          ('BCIO:006038',
#           'evaluative belief',
#           'Part of',
#           'MFOEM:000002',
#           'appraisal process'): 1,
#          ('BCIO:050783',
#           'stimulus',
#           'Influences',
#           'BCIO:050791',
#           'threat appraisal'): 1,
#          ('BCIO:050783',
#           'stimulus',
#           'Influences',
#           'BCIO:050765',
#           'self-efficacy belief for avoiding a threat'): 1,
#          ('BCIO:050791',
#           'threat appraisal',
#           'Influences',
#           'BCIO:006133',
#           'behavioural motivation'): 1,
#          ('BCIO:050765',
#           'self-efficacy belief for avoiding a threat',
#           'Influences',
#           'BCIO:006133',
#           'behavioural motivation'): 1,
#          ('MFOEM:000026',
#           'fear',
#           'Influences',
#           'BCIO:006030',
#           'belief about severity of an outcome'): 1,
#          ('ENVO:01000254',
#           'environmental system',
#           'Type of',
#           'BCIO:050783',
#           'stimulus'): 1,
#          ('GO:0098597',
#           'observational learning',
#           'Type of',
#           'BCIO:050783',
#           'stimulus'): 1,
#          ('BCIO:006099',
#           'social influence behaviour',
#           'Type of',
#           'BCIO:050783',
#           'stimulus'): 1,
#          ...})

# %%
triples_with_counts = []

for a,c in cnt.most_common():
    (a1,a1l,rel,a2,a2l) = a
    if isinstance(a1,str) and isinstance(a2,str):
        print(a1l, a1, rel, a2l, a2, c)
        triples_with_counts.append({"A1":a1,"A1Label":a1l,"Rel":rel,"A2":a2,"A2Label":a2l,"Count":c })
    else: 
        print(a1,rel,a2, "... some problem with IDs")

df_triple_counts = pd.DataFrame(triples_with_counts)
df_triple_counts.to_csv("triples_with_counts.csv",index=False)
# Out:
# one-dimensional temporal region BFO:0000038 Transitions to behaviour non-intender BCIO:050924 9
# social environmental system BCIO:006001 Part of environmental system ENVO:01000254 8
# behaviour enacter BCIO:050922 Transitions to one-dimensional temporal region BFO:0000038 7
# behaviour enacter BCIO:050922 Transitions to behaviour non-intender BCIO:050924 6
# operant conditioning BCIO:006125 Type of intermittent schedule of reinforcement BCIO:050684 5
# environmental system ENVO:01000254 Influences social influence behaviour BCIO:006099 4
# social behavioural opportunity BCIO:006090 Part of social environmental system BCIO:006001 4
# behavioural decision BCIO:006048 Type of decision-making BCIO:006116 4
# behavioural decision BCIO:006048 Part of social environmental system BCIO:006001 4
# behavioural intention BCIO:006016 Influences individual human behaviour BCIO:036000 4
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Positively influences behavioural intention BCIO:006016 4
# behaviour maintenance self-efficacy BCIO:050576 Influences planning MF:0000027 4
# evaluative belief BCIO:006038 Influences individual human behaviour BCIO:036000 4
# behaviour pattern maintenance BCIO:050805 Transitions to one-dimensional temporal region BFO:0000038 4
# one-dimensional temporal region BFO:0000038 Transitions to intention to enact a behaviour BCIO:050683 4
# one-dimensional temporal region BFO:0000038 Transitions to unawareness of a behaviour BCIO:050492 4
# psychological attachment to conventional society BCIO:050750 Part of psychological attachment formation to conventional society BCIO:050749 4
# group evaluative behavioural norm BCIO:050671 Part of social behavioural opportunity BCIO:006090 4
# evaluative belief about the consequences of behaviour BCIO:006148 Influences (*) attitude BCIO:050328 3
# social behavioural opportunity BCIO:006090 Part of social influence behaviour BCIO:006099 3
# normative belief BCIO:006042 Influences behavioural intention BCIO:006016 3
# school facility OMRSE:00000064 Type of social environmental system BCIO:006001 3
# belief about health consequences of behaviour BCIO:050219 Part of belief about consequences of behaviour BCIO:006019 3
# psychological need BCIO:006064 Part of behavioural motivation BCIO:006133 3
# emotion process MFOEM:000001 Part of affective process MFOEM:000195 3
# behavioural consequence BCIO:050806 Influences behavioural motivation BCIO:006133 3
# social influence behaviour BCIO:006099 Influences belief MF:0000041 3
# perceived norm BCIO:006039 Influences behavioural intention BCIO:006016 3
# self-efficacy belief for a behaviour BCIO:006154 Influences behavioural intention BCIO:006016 3
# behavioural capability BCIO:050215 Part of behavioural opportunity BCIO:006086 3
# behaviour enacter BCIO:050922 Transitions to intention to enact a behaviour BCIO:050683 3
# behaviour pattern maintenance BCIO:050805 Transitions to behaviour non-intender BCIO:050924 3
# having enacted a behaviour BCIO:050477 Transitions to behaviour non-intender BCIO:050924 3
# having enacted a behaviour BCIO:050477 Transitions to one-dimensional temporal region BFO:0000038 3
# individual human behaviour BCIO:036000 Influences environmental system ENVO:01000254 3
# behavioural motivation BCIO:006133 Influences individual human behaviour BCIO:036000 3
# demonstrate the behaviour BCT BCIO:007055 Type of behaviour change intervention BCIO:003000 3
# environmental system ENVO:01000254 Influences capability to imagine future scenarios BCIO:050848 3
# social environmental system BCIO:006001 Influences individual human behaviour BCIO:036000 3
# personal attribute BCIO:050300 Part of bodily disposition MF:0000032 3
# personal attribute BCIO:050300 Part of social environmental system BCIO:006001 3
# environmental system ENVO:01000254 Influences economic behaviour BCIO:036035 3
# motivation to comply BCIO:006059 Influences (*) normative belief BCIO:006042 2
# belief about consequences of behaviour BCIO:006019 Influences (*) attitude BCIO:050328 2
# group evaluative behavioural norm BCIO:050671 Part of social environmental system BCIO:006001 2
# perception MF:0000019 Influences desired self-regulatory standard BCIO:050859 2
# desired self-regulatory standard BCIO:050859 Part of degree of organisational hierarchie BCIO:050956 2
# influencer role BCIO:050478 Influences decision-making BCIO:006116 2
# social environmental system BCIO:006001 Type of human communication behaviour BCIO:036034 2
# leadership role BCIO:050887 Type of human communication behaviour BCIO:036034 2
# person in a social environmental system BCIO:050889 Type of human communication behaviour BCIO:036034 2
# social environmental system BCIO:006001 Type of mass media mode of delivery BCIO:050556 2
# attitude BCIO:050328 Influences behavioural intention BCIO:006016 2
# social influence behaviour BCIO:006099 Part of normative belief BCIO:006042 2
# belief about personal susceptibility BCIO:006031 Part of belief about threat BCIO:006306 2
# belief about the discrepancy between one’s current and target state BCIO:050603 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 2
# personality MF:0000202 Part of environmental system ENVO:01000254 2
# perceived descriptive behavioural norm BCIO:006040 Type of perceived norm BCIO:006039 2
# perceived evaluative behavioural norm BCIO:006041 Type of perceived norm BCIO:006039 2
# promotion focused motivational orientation BCIO:006062 Type of self-regulation capability BCIO:006005 2
# emotion process MFOEM:000001 Influences attitude BCIO:050328 2
# attitude BCIO:050328 Influences reflective behaviour BCIO:050832 2
# schedule of reinforcement BCIO:050760 Type of reinforcer BCIO:050756 2
# behaviour pattern maintenance BCIO:050805 Transitions to intention to enact a behaviour BCIO:050683 2
# behaviour enacter BCIO:050922 Transitions to undecidedness about enacting a behaviour BCIO:050493 2
# one-dimensional temporal region BFO:0000038 Transitions to undecidedness about enacting a behaviour BCIO:050493 2
# behaviour enacter BCIO:050922 Transitions to unawareness of a behaviour BCIO:050492 2
# intention to enact a behaviour BCIO:050683 Transitions to behaviour non-intender BCIO:050924 2
# intention to enact a behaviour BCIO:050683 Transitions to one-dimensional temporal region BFO:0000038 2
# behaviour intender BCIO:050923 Transitions to behaviour non-intender BCIO:050924 2
# behaviour intender BCIO:050923 Transitions to one-dimensional temporal region BFO:0000038 2
# self-identity ADDICTO:0000399 Influences emotion about self BCIO:050638 2
# behavioural intention BCIO:006016 Part of self-identity ADDICTO:0000399 2
# mental plan BCIO:050228 Part of self-identity ADDICTO:0000399 2
# self-identity ADDICTO:0000399 Part of bodily disposition MF:0000032 2
# emotion about self BCIO:050638 Influences self-identity ADDICTO:0000399 2
# harm preventing behaviour BCIO:050819 Type of protective factor for harmful behaviour BCIO:050890 2
# personal vulnerability to harmful behaviour BCIO:050489 Type of environmental system ENVO:01000254 2
# behavioural opportunity BCIO:006086 Type of environmental system ENVO:01000254 2
# social influence behaviour BCIO:006099 Type of environmental system ENVO:01000254 2
# environmental system ENVO:01000254 Part of behavioural opportunity BCIO:006086 2
# temporal orientation to the present BCIO:050231 Influences addiction ADDICTO:0000349 2
# goal BCIO:006049 Type of goal-directed behaviour BCIO:050818 2
# extrinsic motivation BCIO:006307 Type of behavioural motivation BCIO:006133 2
# low motivational disposition to change behaviour BCIO:050697 Type of behavioural motivation BCIO:006133 2
# environmental system ENVO:01000254 Type of behavioural motivation BCIO:006133 2
# practise behaviour BCT BCIO:007094 Influences extent of past behavioural achievement BCIO:050886 2
# demonstrate the behaviour BCT BCIO:007055 Influences observational learning GO:0098597 2
# practise behaviour BCT BCIO:007094 Type of behaviour change intervention BCIO:003000 2
# systematically desensitise BCT BCIO:007089 Type of behaviour change intervention BCIO:003000 2
# belief about control over behaviour BCIO:006152 Part of social influence behaviour BCIO:006099 2
# belief about control over behaviour BCIO:006152 Part of positive evaluative belief about a behaviour BCIO:050735 2
# behavioural capability BCIO:050215 Part of environmental system ENVO:01000254 2
# social environmental system BCIO:006001 Influences group evaluative behavioural norm BCIO:050671 2
# behavioural capability BCIO:050215 Influences individual human behaviour BCIO:036000 2
# individual human behaviour BCIO:036000 Influences behavioural capability BCIO:050215 2
# self-regulation capability BCIO:006005 Type of behavioural capability BCIO:050215 2
# traditional personal value BCIO:050792 Part of psychological attachment formation to conventional society BCIO:050749 2
# behavioural capability BCIO:050215 Influences (*) inter-personal behaviour BCIO:036025 2
# family environmental system BCIO:006002 Type of social environmental system BCIO:006001 2
# peer BCIO:010104 Type of social environmental system BCIO:006001 2
# social identity process BCIO:050775 Part of social behavioural opportunity BCIO:006090 2
# high frequency of past behaviour BCIO:050917 Influences goal-directed behaviour BCIO:050818 1
# belief about choice over a behaviour BCIO:006034 Influences behavioural intention BCIO:006016 1
# appraisal of causal agency MFOEM:000075 Influences behavioural intention BCIO:006016 1
# comparative desirability appraisal BCIO:050617 Influences (*) behavioural intention BCIO:006016 1
# belief about goal attainment BCIO:050592 Influences (*) behavioural intention BCIO:006016 1
# emotion process MFOEM:000001 Part of affective attitude acquired through association BCIO:050564 1
# normative belief BCIO:006042 Influences (*) motivation to comply BCIO:006059 1
# belief MF:0000041 Influences (*) attitude BCIO:050328 1
# belief MF:0000041 Influences (*) normative belief BCIO:006042 1
# belief MF:0000041 Influences (*) motivation to comply BCIO:006059 1
# belief about consequences of behaviour BCIO:006019 Influences (*) normative belief BCIO:006042 1
# belief about consequences of behaviour BCIO:006019 Influences (*) motivation to comply BCIO:006059 1
# evaluative belief BCIO:006038 Influences (*) attitude BCIO:050328 1
# evaluative belief BCIO:006038 Influences (*) normative belief BCIO:006042 1
# evaluative belief BCIO:006038 Influences (*) motivation to comply BCIO:006059 1
# evaluative belief about the consequences of behaviour BCIO:006148 Influences (*) normative belief BCIO:006042 1
# evaluative belief about the consequences of behaviour BCIO:006148 Influences (*) motivation to comply BCIO:006059 1
# high frequency of past behaviour BCIO:050917 Part of frequency of past behaviour BCIO:050817 1
# low frequency of past behaviour BCIO:050918 Part of frequency of past behaviour BCIO:050817 1
# environmental system ENVO:01000254 Influences social environmental system BCIO:006001 1
# automatic behavioural motivation BCIO:006134 Influences self-regulation capability BCIO:006005 1
# social environmental system BCIO:006001 Influences (*) antisocial behaviour BCIO:036072 1
# social influence behaviour BCIO:006099 Influences (*) antisocial behaviour BCIO:036072 1
# self-regulation capability BCIO:006005 Influences (*) antisocial behaviour BCIO:036072 1
# self-identity ADDICTO:0000399 Part of self-regulation capability BCIO:006005 1
# evaluation of self BCIO:006035 Part of self-regulation capability BCIO:006005 1
# protective factor for harmful behaviour BCIO:050890 Part of self-regulation capability BCIO:006005 1
# moral personal value BCIO:050708 Part of self-regulation capability BCIO:006005 1
# behavioural self-regulation capability BCIO:006006 Part of self-regulation capability BCIO:006005 1
# motivational orientation BCIO:006060 Part of self-regulation capability BCIO:006005 1
# behavioural substitution capability BCIO:050954 Part of self-regulation capability BCIO:006005 1
# behavioural dissonance reduction through mental process BCIO:050580 Part of self-regulation capability BCIO:006005 1
# extrinsic social motivation BCIO:050656 Part of social environmental system BCIO:006001 1
# extrinsic social motivation BCIO:050656 Part of social influence behaviour BCIO:006099 1
# group evaluative behavioural norm BCIO:050671 Part of social influence behaviour BCIO:006099 1
# association behaviour with a pro-social group BCIO:050803 Part of social environmental system BCIO:006001 1
# association behaviour with a pro-social group BCIO:050803 Part of social influence behaviour BCIO:006099 1
# social reinforcement process for a behaviour BCIO:050778 Part of social environmental system BCIO:006001 1
# social reinforcement process for a behaviour BCIO:050778 Part of social influence behaviour BCIO:006099 1
# individual human behaviour BCIO:036000 Influences impact of behaviour on environment BCIO:050823 1
# comparison of current situation with a standard BCIO:050619 Influences individual human behaviour BCIO:036000 1
# impact of behaviour on environment BCIO:050823 Influences perception MF:0000019 1
# perception MF:0000019 Influences comparison of current situation with a standard BCIO:050619 1
# perception MF:0000019 Influences desired standard for self-identity BCIO:050860 1
# desired standard for self-identity BCIO:050860 Influences desired self-regulatory standard BCIO:050859 1
# desired standard BCIO:006079 Influences comparison of current situation with a standard BCIO:050619 1
# behavioural opportunity BCIO:006086 Influences impact of behaviour on environment BCIO:050823 1
# desired standard for self-identity BCIO:050860 Part of degree of organisational hierarchie BCIO:050956 1
# friendship network BCIO:006003 Influences learning GO:0007612 1
# association behaviour BCIO:036084 Influences learning GO:0007612 1
# human communication behaviour BCIO:036034 Influences learning GO:0007612 1
# learning GO:0007612 Influences perceived norm BCIO:006039 1
# behavioural duration BCIO:050455 Influences association behaviour BCIO:036084 1
# socio-demographic characteristic BCIO:050893 Influences association behaviour BCIO:036084 1
# social embeddedness in a social group BCIO:050771 Influences association behaviour BCIO:036084 1
# behavioural frequency BCIO:050428 Influences association behaviour BCIO:036084 1
# perceived norm BCIO:006039 Influences criminal behaviour BCIO:050810 1
# personal history BCIO:015161 Influences criminal behaviour BCIO:050810 1
# social learning BCIO:050950 Part of learning GO:0007612 1
# mental capability MF:0000048 Part of learning GO:0007612 1
# person’s environmental system BCIO:050731 Influences (*) personal history BCIO:015161 1
# behavioural opportunity BCIO:006086 Influences (*) person’s environmental system BCIO:050731 1
# learning GO:0007612 Influences (*) personal history BCIO:015161 1
# association behaviour BCIO:036084 Influences (*) personal history BCIO:015161 1
# non-linguistic communication behaviour BCIO:050238 Influences (*) human communication behaviour BCIO:036034 1
# linguistic communication behaviour BCIO:050237 Influences (*) human communication behaviour BCIO:036034 1
# human communication behaviour BCIO:036034 Influences None BCIO:037024 1
# knowledge regarding an innovation BCIO:006054 Transitions to evaluative belief formation BCIO:050650 1
# evaluative belief formation BCIO:050650 Transitions to behavioural decision BCIO:006048 1
# behavioural decision BCIO:006048 Transitions to individual human behaviour BCIO:036000 1
# individual human behaviour BCIO:036000 Transitions to approval seeking behaviour BCIO:050802 1
# willingness to adopt new behaviours BCIO:050798 Influences openness-to-change personal value BCIO:050729 1
# social environmental system BCIO:006001 Influences behaviour change rate BCIO:050921 1
# social environmental system BCIO:006001 Negatively influences feeling of uncertainty about one’s behaviour BCIO:050864 1
# intention for collective behaviour BCIO:050681 Positively influences similarity to other people BCIO:050769 1
# influencer role BCIO:050478 Influences similarity to other people BCIO:050769 1
# decision-making BCIO:006116 Influences behavioural consequence BCIO:050806 1
# behavioural consequence BCIO:050806 Influences social environmental system BCIO:006001 1
# social environmental system attribute BCIO:050773 Influences social environmental system BCIO:006001 1
# social environmental system attribute BCIO:050773 Influences behaviour change rate BCIO:050921 1
# similarity to other people BCIO:050769 Type of human communication behaviour BCIO:036034 1
# role model for a person BCIO:050842 Type of human communication behaviour BCIO:036034 1
# mass media mode of delivery BCIO:050556 Type of communication BCIO:050384 1
-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Part of inform about negative consequences BCT BCIO:050559 1
# belief about the positive health consequences of a behaviour BCIO:050607 Influences (*) belief about message trustworthiness BCIO:006143 1
# belief about the positive health consequences of a behaviour BCIO:050607 Influences (*) fear MFOEM:000026 1
# belief about threat BCIO:006306 Influences (*) belief about message trustworthiness BCIO:006143 1
# belief about threat BCIO:006306 Influences (*) fear MFOEM:000026 1
# belief about likelihood of consequences of behaviour BCIO:006024 Part of belief about the positive health consequences of a behaviour BCIO:050607 1
# self-efficacy belief for a behaviour BCIO:006154 Part of belief about the positive health consequences of a behaviour BCIO:050607 1
# belief about severity of an outcome BCIO:006030 Part of belief about threat BCIO:006306 1
# motivation to reduce harm BCIO:050713 Part of threat-reducing behaviour BCIO:050840 1
# harm preventing behaviour BCIO:050819 Part of threat-reducing behaviour BCIO:050840 1
# prevention focused motivational orientation BCIO:006061 Part of fear reduction mental process BCIO:050660 1
# harmful fear reduction mental process BCIO:050673 Part of fear reduction mental process BCIO:050660 1
# belief about severity of an outcome BCIO:006030 Type of communication message BCIO:050555 1
# evaluative belief about the positive consequences of a behaviour BCIO:050648 Type of communication message BCIO:050555 1
# belief about personal susceptibility BCIO:006031 Type of communication message BCIO:050555 1
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Type of communication message BCIO:050555 1
# belief about the discrepancy between one’s current and target state BCIO:050603 Influences goal-directed behaviour BCIO:050818 1
# low mental capability to enact a behaviour BCIO:050869 Influences goal-directed behaviour BCIO:050818 1
# dissonance reduction process for a behaviour BCIO:050631 Influences goal-directed behaviour BCIO:050818 1
# emotion process MFOEM:000001 Influences belief about the discrepancy between one’s current and target state BCIO:050603 1
# provide feedback BCT BCIO:007022 Influences attending to a goal BCIO:050570 1
# feedback process related to identity BCIO:050662 Influences low mental capability to enact a behaviour BCIO:050869 1
# feedback process related to identity BCIO:050662 Influences emotion process MFOEM:000001 1
# provide feedback BCT BCIO:007022 Influences feedback process related to identity BCIO:050662 1
# environmental system ENVO:01000254 Influences provide feedback on outcome of behaviour BCT BCIO:007027 1
# provide feedback on outcome of behaviour BCT BCIO:007027 Influences environmental system ENVO:01000254 1
# feedback process related to identity BCIO:050662 Influences (*) attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# belief about the discrepancy between one’s current and target state BCIO:050603 Influences (*) attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# self-regulation through behavioural feedback BCIO:050768 Influences (*) attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# attending to a goal BCIO:050570 Influences (*) attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# provide feedback BCT BCIO:007022 Part of belief about the discrepancy between one’s current and target state BCIO:050603 1
# goal BCIO:006049 Part of belief about the discrepancy between one’s current and target state BCIO:050603 1
# provide feedback BCT BCIO:007022 Influences (*) attending to a goal BCIO:050570 1
# provide feedback BCT BCIO:007022 Influences (*) feedback process related to identity BCIO:050662 1
# provide feedback BCT BCIO:007022 Influences (*) belief about the discrepancy between one’s current and target state BCIO:050603 1
# goal BCIO:006049 Influences (*) attending to a goal BCIO:050570 1
# goal BCIO:006049 Influences (*) feedback process related to identity BCIO:050662 1
# goal BCIO:006049 Influences (*) belief about the discrepancy between one’s current and target state BCIO:050603 1
# information devaluing BCIO:050678 Part of dissonance reduction process for a behaviour BCIO:050631 1
# goal setting process BCIO:006114 Part of dissonance reduction process for a behaviour BCIO:050631 1
# low motivational disposition to change behaviour BCIO:050697 Part of dissonance reduction process for a behaviour BCIO:050631 1
# change behaviour goal BCT BCIO:050445 Part of dissonance reduction process for a behaviour BCIO:050631 1
# attending to a goal BCIO:050570 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# goal-directed behaviour BCIO:050818 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# dissonance reduction process for a behaviour BCIO:050631 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# emotion process MFOEM:000001 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# low mental capability to enact a behaviour BCIO:050869 Part of attend to discrepancy between current behaviour and goal BCT BCIO:007012 1
# arousal MF:0000012 Type of emotion process MFOEM:000001 1
# pleasure (emotion) MFOEM:000035 Type of emotion process MFOEM:000001 1
# goal pursuit process BCIO:006096 Type of feedback process related to identity BCIO:050662 1
# low mental capability to enact a behaviour BCIO:050869 Type of feedback process related to identity BCIO:050662 1
# emotion process MFOEM:000001 Type of feedback process related to identity BCIO:050662 1
# disposition to attend to one’s goals BCIO:050630 Type of feedback process related to identity BCIO:050662 1
# self-efficacy belief for a behaviour BCIO:006154 Type of goal pursuit process BCIO:006096 1
# anxiety MFOEM:000028 Type of goal pursuit process BCIO:006096 1
# mental feedback process BCIO:050705 Type of goal pursuit process BCIO:006096 1
# goal BCIO:006049 Type of belief about the discrepancy between one’s current and target state BCIO:050603 1
# social environmental system BCIO:006001 Influences self-regulation capability BCIO:006005 1
# parenting behaviour BCIO:050826 Influences self-regulation capability BCIO:006005 1
# self-regulation capability BCIO:006005 Negatively influences cue management behaviour BCIO:050811 1
# impulsive disposition BCIO:050677 Type of self-regulation capability BCIO:006005 1
# temporal orientation BCIO:050790 Type of self-regulation capability BCIO:006005 1
# carer monitoring of child behaviour BCIO:050807 Type of parenting behaviour BCIO:050826 1
# evaluative belief about a behaviour BCIO:006147 Type of parenting behaviour BCIO:050826 1
# None MF:00000006 Type of parenting behaviour BCIO:050826 1
# provide aversive consequence for behaviour BCT BCIO:007241 Type of parenting behaviour BCIO:050826 1
# attachment to a caregiver BCIO:050955 Type of parenting behaviour BCIO:050826 1
# environmental system ENVO:01000254 Influences emotion process MFOEM:000001 1
# negative social environmental system BCIO:050723 Influences None ADDICTO:0001377 1
# motivation to comply BCIO:006059 Influences cognitive representation of an alternative behaviour BCIO:050614 1
# motivation to deviate BCIO:050947 Influences cognitive representation of an alternative behaviour BCIO:050614 1
# evaluative belief about the positive consequences of a behaviour BCIO:050648 Influences None ADDICTO:0001377 1
# antisocial behaviour BCIO:036072 Influences evaluative belief about the positive consequences of a behaviour BCIO:050648 1
# group evaluative behavioural norm BCIO:050671 Influences goal about one’s resources BCIO:050668 1
# group evaluative behavioural norm BCIO:050671 Influences normative goal BCIO:050726 1
# knowledge regarding goal attainment BCIO:050691 Influences belief about the discrepancy between one’s current and target state BCIO:050603 1
# behavioural capability BCIO:050215 Influences belief about the discrepancy between one’s current and target state BCIO:050603 1
# positive reinforcer BCIO:050739 Influences self-initiated goal BCIO:050766 1
# positive reinforcer BCIO:050739 Influences self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 1
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Influences goal BCIO:006049 1
# provide feedback BCT BCIO:007022 Influences self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 1
# belief about the discrepancy between one’s current and target state BCIO:050603 Influences extent of past behavioural achievement BCIO:050886 1
# extent of past behavioural achievement BCIO:050886 Influences satisfaction MFOEM:000169 1
# low opportunity to enact a goal-directed behaviour BCIO:050699 Part of goal BCIO:006049 1
# well-specified goal BCIO:050796 Part of goal BCIO:006049 1
# provide feedback BCT BCIO:007022 Influences (*) goal BCIO:006049 1
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Influences (*) goal BCIO:006049 1
# assigned goal BCIO:050569 Type of positive reinforcer BCIO:050739 1
# self-initiated goal BCIO:050766 Type of goal BCIO:006049 1
# collaborative goal BCIO:050939 Type of goal BCIO:006049 1
# proximal goal BCIO:050746 Type of goal BCIO:006049 1
# distal goal BCIO:050941 Type of goal BCIO:006049 1
# assigned goal BCIO:050569 Type of goal BCIO:006049 1
# learning goal BCIO:050945 Type of goal BCIO:006049 1
# behavioural goal BCIO:050937 Type of goal BCIO:006049 1
# provide feedback BCT BCIO:007022 Influences (*) attending MF:0000018 1
# provide feedback BCT BCIO:007022 Influences (*) belief about barriers to a behaviour BCIO:006017 1
# provide feedback BCT BCIO:007022 Influences (*) persistent goal pursuit process BCIO:050871 1
# personal value BCIO:006063 Positively influences behavioural intention BCIO:006016 1
# belief about threat BCIO:006306 Positively influences behavioural intention BCIO:006016 1
# behavioural recovery self-efficacy BCIO:050584 Positively influences individual human behaviour BCIO:036000 1
# belief about social support BCIO:006146 Influences behavioural intention BCIO:006016 1
# behavioural recovery self-efficacy BCIO:050584 Positively influences self-regulation of behaviour BCIO:006103 1
# behavioural intention BCIO:006016 Positively influences self-regulation of behaviour BCIO:006103 1
# self-regulation of behaviour BCIO:006103 Positively influences individual human behaviour BCIO:036000 1
# physical behavioural opportunity BCIO:006089 Type of belief about consequences of behaviour BCIO:006019 1
# emotion process MFOEM:000001 Type of belief about consequences of behaviour BCIO:006019 1
# normative belief BCIO:006042 Type of belief about consequences of behaviour BCIO:006019 1
# belief about susceptibility to a threat BCIO:006305 Influences (*) belief about threat BCIO:006306 1
# belief about severity of an outcome BCIO:006030 Influences (*) belief about threat BCIO:006306 1
# awareness of standards BCIO:050936 Part of self-regulation of behaviour BCIO:006103 1
# self-monitoring BCIO:006137 Part of self-regulation of behaviour BCIO:006103 1
# self-regulation process BCIO:050268 Part of self-regulation of behaviour BCIO:006103 1
# behaviour non-intender BCIO:050924 Part of behavioural intention BCIO:006016 1
# belief about threat BCIO:006306 Part of behavioural intention BCIO:006016 1
# belief about consequences of behaviour BCIO:006019 Part of behavioural intention BCIO:006016 1
# behaviour intender BCIO:050923 Part of individual human behaviour BCIO:036000 1
# behaviour enacter BCIO:050922 Part of individual human behaviour BCIO:036000 1
# self-regulation of behaviour BCIO:006103 Part of individual human behaviour BCIO:036000 1
# behavioural recovery self-efficacy BCIO:050584 Part of individual human behaviour BCIO:036000 1
# behavioural recovery self-efficacy BCIO:050584 Type of self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 1
# belief about health consequences of behaviour BCIO:050219 Correlates with belief about emotional consequences of behaviour BCIO:050218 1
# belief about emotional consequences of behaviour BCIO:050218 Correlates with belief about social consequences of behaviour BCIO:006020 1
# belief about social consequences of behaviour BCIO:006020 Correlates with self-efficacy belief for a behaviour BCIO:006154 1
# self-efficacy belief for a behaviour BCIO:006154 Correlates with belief about emotional consequences of behaviour BCIO:050218 1
# belief about consequences of behaviour BCIO:006019 Influences goal BCIO:006049 1
# goal BCIO:006049 Correlates with belief about consequences of behaviour BCIO:006019 1
# belief about threat BCIO:006306 Influences goal BCIO:006049 1
# behavioural opportunity BCIO:006086 Influences belief about threat BCIO:006306 1
# personal attribute BCIO:050300 Influences belief about threat BCIO:006306 1
# behavioural opportunity BCIO:006086 Influences belief about consequences of behaviour BCIO:006019 1
# personal attribute BCIO:050300 Influences belief about consequences of behaviour BCIO:006019 1
# self-regulation capability BCIO:006005 Part of self-regulation process BCIO:050268 1
# self-regulation through behavioural feedback BCIO:050768 Part of self-regulation process BCIO:050268 1
# belief about consequences of behaviour BCIO:006019 Part of self-regulation process BCIO:050268 1
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043 Part of self-regulation process BCIO:050268 1
# belief about emotional consequences of behaviour BCIO:050218 Part of belief about consequences of behaviour BCIO:006019 1
# belief about social consequences of behaviour BCIO:006020 Part of belief about consequences of behaviour BCIO:006019 1
# extrinsic motivation BCIO:006307 Influences introjected self-regulation BCIO:006105 1
# introjected self-regulation BCIO:006105 Transitions to extrinsic motivation BCIO:006307 1
# introjected self-regulation BCIO:006105 Negatively influences behaviour pattern maintenance BCIO:050805 1
# extrinsic motivation BCIO:006307 Negatively influences behaviour pattern maintenance BCIO:050805 1
# value-congruent self-regulation BCIO:006107 Positively influences behaviour pattern maintenance BCIO:050805 1
# introjected self-regulation BCIO:006105 Transitions to value-congruent self-regulation BCIO:006107 1
# behavioural motivation BCIO:006133 Influences feeling social pressure BCIO:050665 1
# belief about choice over a behaviour BCIO:006034 Influences extrinsic motivation BCIO:006307 1
# feeling social pressure BCIO:050665 Influences extrinsic motivation BCIO:006307 1
# belief about choice over a behaviour BCIO:006034 Influences introjected self-regulation BCIO:006105 1
# feeling social pressure BCIO:050665 Influences introjected self-regulation BCIO:006105 1
# belief about choice over a behaviour BCIO:006034 Influences value-congruent self-regulation BCIO:006107 1
# belief about social support BCIO:006146 Influences value-congruent self-regulation BCIO:006107 1
# behavioural motivation BCIO:006133 Influences belief about social support BCIO:006146 1
# need for autonomy BCIO:006065 Part of self-motive BCIO:050767 1
# need for a sense of safety BCIO:006067 Part of self-motive BCIO:050767 1
# self-identity ADDICTO:0000399 Part of self-motive BCIO:050767 1
# need to feel competent BCIO:006069 Part of behavioural motivation BCIO:006133 1
# self-efficacy belief for a behaviour and its associated outcomes BCIO:006043
# affective process MFOEM:000195 Positively influences behavioural intention BCIO:006016 1
# affective process MFOEM:000195 Positively influences planning MF:0000027 1
# affective process MFOEM:000195 Influences health-promoting behaviour BCIO:050821 1
# belief about ones social environment BCIO:006145 Influences health-promoting behaviour BCIO:050821 1
# evaluative belief about the positive consequences of a behaviour BCIO:050648 Part of cognitive process MF:0000008 1
# ...
# control over behaviour BCIO:050927 Positively influences belief about control over behaviour BCIO:006152 1
# behavioural opportunity BCIO:006086 Influences individual human behaviour BCIO:036000 1
# individual human behaviour BCIO:036000 Influences behavioural opportunity BCIO:006086 1
# individual human behaviour BCIO:036000 Influences behavioural motivation BCIO:006133 1
# behavioural opportunity BCIO:006086 Influences behavioural motivation BCIO:006133 1
# physical behavioural capability BCIO:006009 Type of behavioural capability BCIO:050215 1
# reflective behavioural motivation BCIO:050318 Type of behavioural motivation BCIO:006133 1
# automatic behavioural motivation BCIO:006134 Type of behavioural motivation BCIO:006133 1
# physical behavioural opportunity BCIO:006089 Type of behavioural opportunity BCIO:006086 1
# social behavioural opportunity BCIO:006090 Type of behavioural opportunity BCIO:006086 1
# self-efficacy belief for a behaviour BCIO:006154 Influences decision BCIO:006047 1
# health-related behaviour BCIO:050437 Influences past occurrence of a target behaviour BCIO:050827 1
# family environmental system BCIO:006002 Influences observational learning GO:0098597 1
# friendship network BCIO:006003 Influences observational learning GO:0098597 1
# professional network BCIO:050213 Influences observational learning GO:0098597 1
# family environmental system BCIO:006002 Influences psychological attachment formation BCIO:050748 1
# friendship network BCIO:006003 Influences psychological attachment formation BCIO:050748 1
# professional network BCIO:050213 Influences psychological attachment formation BCIO:050748 1
# behavioural intention BCIO:006016 Influences health-related behaviour BCIO:050437 1
# decision BCIO:006047 Influences health-related behaviour BCIO:050437 1
# social environmental system BCIO:006001 Influences egoistic personal health value BCIO:050636 1
# social environmental system BCIO:006001 Influences knowledge about threat avoidance BCIO:050690 1
# attitude BCIO:050328 Influences decision BCIO:006047 1
# internal influence on behaviour BCIO:050868 Influences social influence behaviour BCIO:006099 1
# past occurrence of a target behaviour BCIO:050827 Influences egoistic personal health value BCIO:050636 1
# past occurrence of a target behaviour BCIO:050827 Influences belief about health consequences of behaviour BCIO:050219 1
# past occurrence of a target behaviour BCIO:050827 Influences belief about the financial consequences of a behaviour BCIO:050604 1
# past occurrence of a target behaviour BCIO:050827 Influences motivation to comply BCIO:006059 1
# past occurrence of a target behaviour BCIO:050827 Influences perceived norm BCIO:006039 1
# past occurrence of a target behaviour BCIO:050827 Influences mental skill BCIO:006004 1
# past occurrence of a target behaviour BCIO:050827 Influences self-regulatory skill BCIO:050222 1
# past occurrence of a target behaviour BCIO:050827 Influences physical skill BCIO:006010 1
# past occurrence of a target behaviour BCIO:050827 Influences belief about control over behaviour BCIO:006152 1
# attitude BCIO:050328 Influences social influence behaviour BCIO:006099 1
# social influence behaviour BCIO:006099 Influences internal influence on behaviour BCIO:050868 1
# social influence behaviour BCIO:006099 Influences attitude BCIO:050328 1
# environmental system ENVO:01000254 Influences economic environmental system BCIO:050635 1
# economic environmental system BCIO:050635 Influences economic behaviour BCIO:036035 1
# group evaluative behavioural norm BCIO:050671 Influences economic behaviour BCIO:036035 1
# temporal behavioural opportunity BCIO:006091 Influences economic behaviour BCIO:036035 1
# technology availability BCIO:050789 Influences economic behaviour BCIO:036035 1
# individual human behaviour pattern BCIO:036100 Influences economic behaviour BCIO:036035 1
# self-identity ADDICTO:0000399 Influences economic behaviour BCIO:036035 1
# economic behaviour BCIO:036035 Part of individual human behaviour pattern BCIO:036100 1
# economic behaviour BCIO:036035 Part of self-identity ADDICTO:0000399 1
# knowledge BCIO:006052 Part of individual human behaviour pattern BCIO:036100 1
# knowledge BCIO:006052 Part of self-identity ADDICTO:0000399 1
# consciousness MF:0000017 Part of individual human behaviour pattern BCIO:036100 1
# consciousness MF:0000017 Part of self-identity ADDICTO:0000399 1
# temporal behavioural opportunity BCIO:006091 Part of environmental system ENVO:01000254 1
# individual human behaviour pattern BCIO:036100 Part of social group BCIO:050891 1
# self-identity ADDICTO:0000399 Part of social group BCIO:050891 1
# knowledge BCIO:006052 Part of social group BCIO:050891 1
# consciousness MF:0000017 Part of social group BCIO:050891 1

# %% [markdown]
# #### Generate a diagram for an integrated set of theory expressions
#
# We generate a diagram representing an "overarching" integrated set of theory expressions

# %%
! pip install networkx
! pip install pydot
! pip install graphviz
# Out:
# Requirement already satisfied: networkx in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (3.3)
# Collecting pydot
#   Downloading pydot-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyparsing>=3.0.9 in c:\users\mabraun\appdata\local\anaconda3\lib\site-packages (from pydot) (3.1.2)
# Downloading pydot-3.0.4-py3-none-any.whl (35 kB)
# Installing collected packages: pydot
# Successfully installed pydot-3.0.4
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3

# %%
import networkx as nx

def wrap_if_needed(string_val):
    if ":" in string_val:
        return( f'"{string_val}"')
    return(string_val)

G=nx.DiGraph()

for (a1,a1l,rel,a2,a2l) in annotated_triples:
    if cnt[(a1,a1l,rel,a2,a2l)]>1 and isinstance(a1,str) and isinstance(a2,str):    
        if a1l is None or a2l is None:   # Exclude those for which we didn't yet find a label
            continue
        G.add_node(wrap_if_needed(a1l))
        G.add_node(wrap_if_needed(a2l))
        G.add_edge(wrap_if_needed(a1l),wrap_if_needed(a2l),label=rel,penwidth=str(cnt[(a1,a1l,rel,a2,a2l)]))
    
pdot = nx.drawing.nx_pydot.to_pydot(G)

for i, node in enumerate(pdot.get_nodes()):
    node_name = str(node).replace("\"","").replace(";","")
    node.set_shape('box')
    node.set_fontcolor('black')
    node.set_fillcolor('white')
    node.set_style('rounded, filled')
    node.set_color('black')

png_path = "merged-large.png"
pdot.write_png(png_path)
# Out:
# "dot" with args ['-Tpng', 'C:\\Users\\mabraun\\AppData\\Local\\Temp\\tmpae4xt57k\\tmpgi0taz7f'] returned code: 3221225781
#
# stdout, stderr:
#  b''
# b''
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 29
#      26     node.set_color('black')
#      28 png_path = "merged-large.png"
# ---> 29 pdot.write_png(png_path)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:166, in __generate_format_methods.<locals>.__write_method(self, path, f, prog, encoding)
#     164 def __write_method(self, path, f=frmt, prog=None, encoding=None):
#     165     """Refer to docstring of method `write`."""
# --> 166     self.write(path, format=f, prog=prog, encoding=encoding)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:1762, in Dot.write(self, path, prog, format, encoding)
#    1760         f.write(s)
#    1761 else:
# -> 1762     s = self.create(prog, format, encoding=encoding)
#    1763     with open(path, mode="wb") as f:
#    1764         f.write(s)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:1871, in Dot.create(self, prog, format, encoding)
#    1865     code = process.returncode
#    1866     print(
#    1867         f'"{prog}" with args {arguments} returned code: {code}\n\n'
#    1868         f"stdout, stderr:\n {stdout_data}\n{stderr_data}\n"
#    1869     )
# -> 1871 assert process.returncode == 0, (
#    1872     f'"{prog}" with args {arguments} '
#    1873     f"returned code: {process.returncode}"
#    1874 )
#    1876 return stdout_data
#
# AssertionError: "dot" with args ['-Tpng', 'C:\\Users\\mabraun\\AppData\\Local\\Temp\\tmpae4xt57k\\tmpgi0taz7f'] returned code: 3221225781

# %%
# A smaller file with just a selected set of nodes

important_nodes = ["MF:0000008","BCIO:036000","BCIO:006086","MFOEM:000195","BCIO:006016","BCIO:006099","ENVO:01000254","BCIO:006133","BCIO:006154","BCIO:006047"]

G=nx.DiGraph()

for (a1,a1l,rel,a2,a2l) in annotated_triples:
    if cnt[(a1,a1l,rel,a2,a2l)]>1 and isinstance(a1,str) and isinstance(a2,str):    
        if a1l is None or a2l is None:   # Exclude those for which we didn't yet find a label
            continue
        if a1 in important_nodes and a2 in important_nodes: 
            G.add_node(wrap_if_needed(a1l))
            G.add_node(wrap_if_needed(a2l))
            G.add_edge(wrap_if_needed(a1l),wrap_if_needed(a2l),label=rel,penwidth=str(cnt[(a1,a1l,rel,a2,a2l)]))
    
pdot = nx.drawing.nx_pydot.to_pydot(G)

for i, node in enumerate(pdot.get_nodes()):
    node_name = str(node).replace("\"","").replace(";","")
    node.set_shape('box')
    node.set_fontcolor('black')
    node.set_fillcolor('white')
    node.set_style('rounded, filled')
    node.set_color('black')

png_path = "merged-medium.png"
pdot.write_png(png_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:1851, in Dot.create(self, prog, format, encoding)
#    1850 try:
# -> 1851     stdout_data, stderr_data, process = call_graphviz(
#    1852         program=prog,
#    1853         arguments=arguments,
#    1854         working_dir=tmp_dir,
#    1855     )
#    1856 except OSError as e:
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:211, in call_graphviz(program, arguments, working_dir, **kwargs)
#     209 program_with_args = [program] + arguments
# --> 211 process = subprocess.Popen(
#     212     program_with_args,
#     213     env=env,
#     214     cwd=working_dir,
#     215     shell=False,
#     216     stderr=subprocess.PIPE,
#     217     stdout=subprocess.PIPE,
#     218     **kwargs,
#     219 )
#     220 stdout_data, stderr_data = process.communicate()
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[95], line 27
#      24     node.set_color('black')
#      26 png_path = "merged-medium.png"
# ---> 27 pdot.write_png(png_path)
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:166, in __generate_format_methods.<locals>.__write_method(self, path, f, prog, encoding)
#     164 def __write_method(self, path, f=frmt, prog=None, encoding=None):
#     165     """Refer to docstring of method `write`."""
# --> 166     self.write(path, format=f, prog=prog, encoding=encoding)
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:1762, in Dot.write(self, path, prog, format, encoding)
#    1760         f.write(s)
#    1761 else:
# -> 1762     s = self.create(prog, format, encoding=encoding)
#    1763     with open(path, mode="wb") as f:
#    1764         f.write(s)
#
# File c:\Users\maybra\AppData\Local\anaconda3\Lib\site-packages\pydot\core.py:1860, in Dot.create(self, prog, format, encoding)
#    1858     args = list(e.args)
#    1859     args[1] = f'"{prog}" not found in path.'
# -> 1860     raise OSError(*args)
#    1861 else:
#    1862     raise
#
# FileNotFoundError: [WinError 2] "dot" not found in path.

# %% [markdown]
# ### Using AI to integrate theories
#
# - Training a knowledge graph encoder and then using it to predict the most likely links... can also visualise the embedding etc. See e.g. https://github.com/mims-harvard/graphml-tutorials/blob/master/04-link-prediction/link-prediction.ipynb

# %%
# Build a graph with all three components: theories and ontology annotations and ontology
G=nx.DiGraph()

for theory_num, theory in theories.items():
    if theory_num and theory.name:
        G.add_node(theory_num,label=theory.name)
        
        for triple in theory.triples:
            if triple.reified_rel is None: # Ignore the reified rels - too complex for this process now
                construct1 = triple.const1.name
                construct2 = triple.const2.name
                if construct1 and construct2 and 'relationship' not in construct1 and 'relationship' not in construct2:
                    G.add_node(construct1,label=construct1)
                    G.add_edge(theory_num,construct1,label="has construct")
                    G.add_node(construct2,label=construct2)
                    G.add_edge(theory_num,construct2,label="has construct")
                    relationship = triple.relStr
                    if not relationship:
                        relationship = "relationship"
                    G.add_edge(construct1,construct2,label=relationship)
        
                    # Ontology annotations of constructs
                    c1annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct1.lower().replace("'","").replace("\n","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                    c2annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct2.lower().replace("'","").replace("\n","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                    constr1_annots = [c for c in c1annots.values.flatten().tolist() if c]
                    constr2_annots = [c for c in c2annots.values.flatten().tolist() if c]
                    for annot1 in constr1_annots:         
                        a1iri = onto.get_iri_for_id(annot1)
                        a1label = onto.get_annotation(a1iri, RDFSLABEL)  if a1iri else annot1
                        G.add_node(annot1,label=a1label)
                        G.add_edge(construct1,annot1,label="has annotation")
                    for annot2 in constr2_annots:
                        a2iri = onto.get_iri_for_id(annot2)
                        a2label = onto.get_annotation(a2iri, RDFSLABEL) if a2iri else annot2
                        G.add_node(annot2,label=a2label)
                        G.add_edge(construct2,annot2,label="has annotation")

# Ontology
for c in onto.get_classes():
    cid = onto.get_id_for_iri(c)
    if not cid: 
        cid = c
    clabel = onto.get_annotation(c, RDFSLABEL)
    if not clabel: 
        clabel = cid
    G.add_node(cid,label=clabel)
    for sc in onto.get_subclasses(c):
        scid = onto.get_id_for_iri(sc)
        if not scid: 
            scid = sc
        sclabel = onto.get_annotation(sc, RDFSLABEL)
        if not sclabel: 
            sclabel = scid
        G.add_node(scid,label=sclabel)
        G.add_edge(scid,cid,label="subClassOf")

# %%
nx.write_gml(G,'merged-theories.xml')

# %%
# PyKeen- embedding for knowledge graphs

! pip install pykeen
# Out:
# Collecting pykeen
#   Downloading pykeen-1.11.0-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting dataclasses-json (from pykeen)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (1.14.0)
# Requirement already satisfied: click in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (8.1.8)
# Collecting click-default-group (from pykeen)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: scikit-learn in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (1.5.2)
# Requirement already satisfied: torch>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (2.5.1)
# Requirement already satisfied: tqdm in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (4.65.0)
# Requirement already satisfied: requests in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (2.31.0)
# Collecting optuna>=2.0.0 (from pykeen)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas>=1.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (2.2.2)
# Collecting tabulate (from pykeen)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting more-click (from pykeen)
#   Downloading more_click-0.1.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from pykeen)
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting pystow>=0.4.3 (from pykeen)
#   Downloading pystow-0.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting docdata (from pykeen)
#   Downloading docdata-0.0.4-py3-none-any.whl.metadata (13 kB)
# Collecting class-resolver>=0.5.1 (from pykeen)
#   Downloading class_resolver-0.5.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pyyaml in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (6.0.2)
# Collecting torch-max-mem>=0.1.1 (from pykeen)
#   Downloading torch_max_mem-0.1.3-py3-none-any.whl.metadata (7.4 kB)
# Collecting torch-ppr>=0.0.7 (from pykeen)
#   Downloading torch_ppr-0.0.8-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/lib/python3.12/site-packages (from pykeen) (4.12.2)
# Collecting alembic>=1.5.0 (from optuna>=2.0.0->pykeen)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna>=2.0.0->pykeen)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.12/site-packages (from optuna>=2.0.0->pykeen) (23.1)
# Collecting sqlalchemy>=1.4.2 (from optuna>=2.0.0->pykeen)
#   Downloading SQLAlchemy-2.0.38-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.0.0->pykeen) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.0.0->pykeen) (2024.1)
# Requirement already satisfied: filelock in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (3.16.1)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (3.1.5)
# Requirement already satisfied: fsspec in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (2024.10.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (68.2.2)
# Requirement already satisfied: sympy==1.13.1 in /opt/miniconda3/lib/python3.12/site-packages (from torch>=2.0->pykeen) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0->pykeen) (1.3.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->pykeen)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->pykeen)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pykeen) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pykeen) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pykeen) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pykeen) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from scikit-learn->pykeen) (3.5.0)
# Collecting Mako (from alembic>=1.5.0->optuna>=2.0.0->pykeen)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from jinja2->torch>=2.0->pykeen) (3.0.2)
# Downloading pykeen-1.11.0-py3-none-any.whl (718 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.4/718.4 kB 11.6 MB/s eta 0:00:00 0:00:01
# Downloading class_resolver-0.5.4-py3-none-any.whl (29 kB)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 31.3 MB/s eta 0:00:00
# Downloading pystow-0.7.0-py3-none-any.whl (38 kB)
# Downloading torch_max_mem-0.1.3-py3-none-any.whl (10 kB)
# Downloading torch_ppr-0.0.8-py3-none-any.whl (12 kB)
# Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docdata-0.0.4-py3-none-any.whl (9.1 kB)
# Downloading more_click-0.1.2-py3-none-any.whl (6.7 kB)
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 4.9 MB/s eta 0:00:00
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 23.7 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.38-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 41.2 MB/s eta 0:00:00a 0:00:01
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: tabulate, sqlalchemy, mypy-extensions, more-itertools, more-click, marshmallow, Mako, docdata, colorlog, click-default-group, class-resolver, typing-inspect, pystow, alembic, torch-max-mem, optuna, dataclasses-json, torch-ppr, pykeen
# Successfully installed Mako-1.3.9 alembic-1.14.1 class-resolver-0.5.4 click-default-group-1.2.4 colorlog-6.9.0 dataclasses-json-0.6.7 docdata-0.0.4 marshmallow-3.26.1 more-click-0.1.2 more-itertools-10.6.0 mypy-extensions-1.0.0 optuna-4.2.1 pykeen-1.11.0 pystow-0.7.0 sqlalchemy-2.0.38 tabulate-0.9.0 torch-max-mem-0.1.3 torch-ppr-0.0.8 typing-inspect-0.9.0

# %%
import pandas as pd

# Define the subjects, predicates, and objects - the entire graph structure
subjects =   []
predicates = []
objects =    []

for theory_num, theory in theories.items():
    for triple in theory.triples:
        if triple.reified_rel is None: # Ignore the reified rels - too complex for this process now
            construct1 = triple.const1.name
            construct2 = triple.const2.name
            if 'relationship' not in construct1 and 'relationship' not in construct2:
                subjects.append(theory_num+'---'+theory.name)
                predicates.append("has construct")
                objects.append(construct1)
                
                subjects.append(theory_num+'---'+theory.name)
                predicates.append("has construct")
                objects.append(construct2)
                
                subjects.append(construct1)
                predicates.append(triple.relStr)
                objects.append(construct2)
    
                # Ontology annotations of constructs
                c1annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct1.lower().replace("'","").replace("\n","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                c2annots = resultdata.query(f"Theory_ID == {theory_num} and Construct.str.lower() == '{construct2.lower().replace("'","").replace("\n","")}'")[['Ontology_ID','Alt_Ontology_ID','Alt_Ontology_ID_2','Alt_Ontology_ID_3']]
                constr1_annots = [c for c in c1annots.values.flatten().tolist() if c]
                constr2_annots = [c for c in c2annots.values.flatten().tolist() if c]
                for annot1 in constr1_annots:         
                    a1iri = onto.get_iri_for_id(annot1)
                    a1label = onto.get_annotation(a1iri, RDFSLABEL)  if a1iri else annot1

                    subjects.append(construct1)
                    predicates.append("has annotation")
                    objects.append(str(annot1)+'---'+str(a1label))
                    
                for annot2 in constr2_annots:
                    a2iri = onto.get_iri_for_id(annot2)
                    a2label = onto.get_annotation(a2iri, RDFSLABEL) if a2iri else annot2

                    subjects.append(construct2)
                    predicates.append("has annotation")
                    objects.append(str(annot2)+'---'+str(a2label))

# Ontology
for c in onto.get_classes():
    cid = onto.get_id_for_iri(c)
    if not cid: 
        cid = c

    for sc in onto.get_subclasses(c):
        scid = onto.get_id_for_iri(sc)
        if not scid: 
            scid = sc
        
        subjects.append(cid+'---'+onto.get_annotation(c, RDFSLABEL))
        predicates.append("subClassOf") # Todo add other relationships aside from the hierarhcy
        objects.append(scid+'---'+onto.get_annotation(sc, RDFSLABEL))  


# Create a dataframe
df = pd.DataFrame({'subject': subjects, 'predicate': predicates, 'object': objects})
df.to_csv('theorydataset.tsv', sep='\t', index=False, header=False)

df
# Out:
#                                                  subject       predicate  \
# 0                            42---Norm Activation Theory   has construct
# 1                            42---Norm Activation Theory   has construct
# 2           Recognition of own ability to provide relief      Influences
# 3           Recognition of own ability to provide relief  has annotation
# 4                            42---Norm Activation Theory   has construct
# ...                                                  ...             ...
# 12687                         BCIO:006004---mental skill      subClassOf
# 12688                       MFOEM:000080---feeling tired      subClassOf
# 12689      BCIO:010122---pre-existing knowledge or skill      subClassOf
# 12690  BCIO:007196---promise to remove aversive conse...      subClassOf
# 12691  BCIO:007196---promise to remove aversive conse...      subClassOf
#
#                                                   object
# 0           Recognition of own ability to provide relief
# 1      Arousal of some sense of responsibility to res...
# 2      Arousal of some sense of responsibility to res...
# 3      BCIO:006043---self-efficacy belief for a behav...
# 4                Assessment, evaluation and reassessment
# ...                                                  ...
# 12687              BCIO:050788---symbol processing skill
# 12688                   MFOEM:000112---feeling exhausted
# 12689  BCIO:010127---affiliation to a formal group or...
# 12690  BCIO:007232---promise to remove aversive mater...
# 12691  BCIO:007234---promise to remove aversive socia...
#
# [12692 rows x 3 columns]

# %%
from pykeen.triples import TriplesFactory
from pykeen.nn import TextRepresentation
from pykeen.models import ERModel
from pykeen.datasets import Dataset


# Assuming your dataframe has columns 'subject', 'predicate', 'object'
triples_factory = TriplesFactory.from_labeled_triples(
    triples=df[['subject', 'predicate', 'object']].values,
)

dataset = Dataset.from_tf(triples_factory)
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=1429071821
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [2573, 724, 725]

# %%
#entity_representations = TextRepresentation.from_triples_factory(
#    triples_factory=dataset,
#    encoder="transformer",
#)
#result = pipeline(
#    dataset=dataset,
#    model=ERModel,
#    model_kwargs=dict(
#        interaction="ermlpe",
#        interaction_kwargs=dict(
#            embedding_dim=entity_representations.shape[0],
#        ),
#        entity_representations=entity_representations,
#        relation_representations_kwargs=dict(
#            shape=entity_representations.shape,
#        ),
#    ),
#    training_kwargs=dict(
#        num_epochs=1,
#    ),
#)
#model = result.model

# %%
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline

# Generate triples from the graph data
tf = TriplesFactory.from_labeled_triples(df.values)

# split triples into train and test
training, testing = tf.split([0.8, 0.2], random_state=42)

# generate embeddings using PyKEEN's pipeline method
result = pipeline(
        training=training,
        testing=testing,
        model = "TransR",
        model_kwargs=dict(embedding_dim=128),
        training_kwargs=dict(num_epochs=200),
        random_seed=42)
# Out:
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [2573, 1449]
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu:   0%|                                                                                            | 0/200 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 60.72batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 63.05batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 65.03batch/s]
# Training epochs on cpu:   0%|▎                                                        | 1/200 [00:00<01:49,  1.81epoch/s, loss=0.977, prev_loss=nan]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 65.48batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 64.80batch/s]
# Training batches on cpu:  96%|███████████████████████████████████████████████████████████████████████████████▍   | 22/23 [00:00<00:00, 68.40batch/s]
# Training epochs on cpu:   1%|▌                                                      | 2/200 [00:01<01:48,  1.83epoch/s, loss=0.843, prev_loss=0.977]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 66.75batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 51.24batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 57.14batch/s]
# Training epochs on cpu:   2%|▊                                                      | 3/200 [00:01<01:53,  1.73epoch/s, loss=0.746, prev_loss=0.843]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  26%|█████████████████████▉                                                              | 6/23 [00:00<00:00, 53.07batch/s]
# Training batches on cpu:  57%|██████████████████████████████████████████████▉                                    | 13/23 [00:00<00:00, 61.46batch/s]
# Training batches on cpu:  87%|████████████████████████████████████████████████████████████████████████▏          | 20/23 [00:00<00:00, 64.77batch/s]
# Training epochs on cpu:   2%|█                                                      | 4/200 [00:02<01:51,  1.76epoch/s, loss=0.726, prev_loss=0.746]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 68.37batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 63.25batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 62.85batch/s]
# Training epochs on cpu:   2%|█▍                                                     | 5/200 [00:02<01:50,  1.76epoch/s, loss=0.703, prev_loss=0.726]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 62.91batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 63.27batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 64.96batch/s]
# Training epochs on cpu:   3%|█▋                                                     | 6/200 [00:03<01:49,  1.77epoch/s, loss=0.695, prev_loss=0.703]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 67.42batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 68.70batch/s]
# Training batches on cpu:  96%|███████████████████████████████████████████████████████████████████████████████▍   | 22/23 [00:00<00:00, 70.17batch/s]
# Training epochs on cpu:   4%|█▉                                                     | 7/200 [00:03<01:46,  1.81epoch/s, loss=0.685, prev_loss=0.695]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 62.85batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 64.90batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 62.15batch/s]
# Training epochs on cpu:   4%|██▏                                                    | 8/200 [00:04<01:46,  1.80epoch/s, loss=0.677, prev_loss=0.685]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 65.88batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 62.89batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 64.48batch/s]
# Training epochs on cpu:   4%|██▍                                                    | 9/200 [00:05<01:46,  1.80epoch/s, loss=0.668, prev_loss=0.677]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 66.55batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 67.34batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 68.13batch/s]
# Training epochs on cpu:   5%|██▋                                                   | 10/200 [00:05<01:44,  1.82epoch/s, loss=0.672, prev_loss=0.668]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  22%|██████████████████▎                                                                 | 5/23 [00:00<00:00, 49.37batch/s]
# Training batches on cpu:  52%|███████████████████████████████████████████▎                                       | 12/23 [00:00<00:00, 61.41batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████████████████████████████████▌              | 19/23 [00:00<00:00, 63.55batch/s]
# Training epochs on cpu:   6%|██▉                                                   | 11/200 [00:06<01:48,  1.74epoch/s, loss=0.673, prev_loss=0.672]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:   9%|███████▎                                                                            | 2/23 [00:00<00:01, 17.72batch/s]
# Training batches on cpu:  39%|████████████████████████████████▊                                                   | 9/23 [00:00<00:00, 46.39batch/s]
# Training batches on cpu:  70%|█████████████████████████████████████████████████████████▋                         | 16/23 [00:00<00:00, 56.62batch/s]
# Training batches on cpu: 100%|███████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 61.47batch/s]
# Training epochs on cpu:   6%|███▏                                                  | 12/200 [00:06<01:50,  1.71epoch/s, loss=0.666, prev_loss=0.673]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 49.42batch/s]
# Training batches on cpu:  57%|██████████████████████████████████████████████▉                                    | 13/23 [00:00<00:00, 51.00batch/s]
# Training batches on cpu:  87%|████████████████████████████████████████████████████████████████████████▏          | 20/23 [00:00<00:00, 58.10batch/s]
# Training epochs on cpu:   6%|███▌                                                  | 13/200 [00:07<01:50,  1.69epoch/s, loss=0.665, prev_loss=0.666]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 61.51batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 61.36batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 55.19batch/s]
# Training epochs on cpu:   7%|███▊                                                  | 14/200 [00:08<01:50,  1.69epoch/s, loss=0.659, prev_loss=0.665]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 66.90batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 66.04batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 60.98batch/s]
# Training epochs on cpu:   8%|████                                                  | 15/200 [00:08<01:52,  1.65epoch/s, loss=0.662, prev_loss=0.659]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 62.84batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 62.99batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 62.67batch/s]
# Training epochs on cpu:   8%|████▎                                                 | 16/200 [00:09<01:52,  1.64epoch/s, loss=0.646, prev_loss=0.662]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 63.21batch/s]
# Training batches on cpu:  61%|██████████████████████████████████████████████████▌                                | 14/23 [00:00<00:00, 61.91batch/s]
# Training batches on cpu:  91%|███████████████████████████████████████████████████████████████████████████▊       | 21/23 [00:00<00:00, 61.53batch/s]
# Training epochs on cpu:   8%|████▌                                                 | 17/200 [00:09<01:50,  1.65epoch/s, loss=0.637, prev_loss=0.646]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  26%|█████████████████████▉                                                              | 6/23 [00:00<00:00, 52.91batch/s]
# Training batches on cpu:  57%|██████████████████████████████████████████████▉                                    | 13/23 [00:00<00:00, 55.34batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████████████████████████████████▌              | 19/23 [00:00<00:00, 50.94batch/s]
# Training epochs on cpu:   9%|████▊                                                 | 18/200 [00:10<01:51,  1.63epoch/s, loss=0.642, prev_loss=0.637]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:  26%|█████████████████████▉                                                              | 6/23 [00:00<00:00, 55.68batch/s]
# Training batches on cpu:  57%|██████████████████████████████████████████████▉                                    | 13/23 [00:00<00:00, 61.66batch/s]
# Training batches on cpu:  87%|████████████████████████████████████████████████████████████████████████▏          | 20/23 [00:00<00:00, 63.04batch/s]
# Training epochs on cpu:  10%|█████▏                                                | 19/200 [00:11<01:48,  1.66epoch/s, loss=0.634, prev_loss=0.642]
# Training batches on cpu:   0%|                                                                                            | 0/23 [00:00<?, ?batch/s]
# Training batches on cpu:
[00:00<?, ?batch/s]
# Training batches on cpu:  30%|█████████████████████████▌                                                          | 7/23 [00:00<00:00, 68.07batch/s]
# Training batches on cpu:  65%|██████████████████████████████████████████████████████▏                            | 15/23 [00:00<00:00, 71.28batch/s]
# Training batches on cpu: 100%|███████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 71.98batch/s]
# Training epochs on cpu: 100%|█████████████████████████████████████████████████████| 200/200 [01:49<00:00,  1.82epoch/s, loss=0.226, prev_loss=0.225]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|                                                                                           | 0.00/1.45k [00:00<?, ?triple/s]WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# Evaluating on cpu: 100%|████████████████████████████████████████████████████████████████████████████████████| 1.45k/1.45k [00:05<00:00, 279triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 5.22s seconds

# %%
#plot loss
result.plot_losses()
# Out:
# <Axes: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
import torch

# get entity labels from training set
entity_labels = training.entity_labeling.all_labels()
# convert entities to ids
entity_ids = torch.as_tensor(training.entities_to_ids(entity_labels))
# retrieve the embeddings using entity ids
entity_embeddings = result.model.entity_representations[0](indices=entity_ids)
# create a dictionary of entity labels and embeddings
entity_embeddings_dict = dict(zip(entity_labels, entity_embeddings.detach()))
#entity_embeddings_dict.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 11
#       9 # create a dictionary of entity labels and embeddings
#      10 entity_embeddings_dict = dict(zip(entity_labels, entity_embeddings.detach()))
# ---> 11 float(entity_embeddings_dict.values())
#
# TypeError: float() argument must be a string or a real number, not 'dict_values'

# %%
entity_embeds = []

for i, (k, v) in enumerate(entity_embeddings_dict.items()):
    entity_embeds.append({"Eindex":i,"Elabel":k,"Embedding":v.numpy()})

df_entity_embeddings = pd.DataFrame(entity_embeds)
df_entity_embeddings
# Out:
#       Eindex                                             Elabel  \
# 0          0             1---Action Theory Model of Consumption
# 1          1                            10---Containment Theory
# 2          2                                11---Control Theory
# 3          3               12---Differential Association Theory
# 4          4                      13---Diffusion of Innovations
# ...      ...                                                ...
# 3813    3813                                 Years of education
# 3814    3814  http://purl.unep.org/sdg/SDGIO_00010001---educ...
# 3815    3815  http://purl.unep.org/sdg/SDGIO_00010026---unem...
# 3816    3816    http://purl.unep.org/sdg/SDGIO_00010028---owner
# 3817    3817  http://purl.unep.org/sdg/SDGIO_00010029---empl...
#
#                                               Embedding
# 0     [0.00049105345, -0.0028100312, -0.0013627395, ...
# 1     [-0.0058986153, -0.004461048, 0.0061651943, 4....
# 2     [-0.004493709, -0.0034436474, -0.0023325619, -...
# 3     [-0.0052005476, -0.0039788582, 0.00084355543, ...
# 4     [0.0069536543, -0.002756022, 0.009156003, 0.00...
# ...                                                 ...
# 3813  [0.00045777985, 0.007830234, 0.0041789985, -0....
# 3814  [0.0055826744, -0.004799756, -0.006946931, 0.0...
# 3815  [0.01431392, -0.014834208, -0.0069461283, -0.0...
# 3816  [0.017361442, -0.015281262, 0.002354118, -0.00...
# 3817  [0.005381153, -0.0029692852, 0.004311535, -1.5...
#
# [3818 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
entity_embeddings = [ d for d in df_entity_embeddings['Embedding'] ]
#print(entity_embeddings)
m = pca.fit(entity_embeddings)

eu = m.transform(entity_embeddings)
eu
# Out:
# array([[-0.01958126, -0.02019823],
#        [-0.00457073, -0.01254784],
#        [ 0.01107526, -0.03028097],
#        ...,
#        [ 0.03143694, -0.01845173],
#        [ 0.01743125, -0.04933429],
#        [ 0.0688588 , -0.02314741]])

# %%
# plt.plot(eu[:, 0], eu[:, 1],'.b')

# Plot theories: 

plt.figure(figsize=(12, 10))

for index,row in df_entity_embeddings.iterrows():
    entity_num = row['Eindex']
    entity = row['Elabel']
    if entity_num < 76:
        plt.annotate(
            text=entity,
            xy=(eu[entity_num, 0], eu[entity_num, 1]),
            color="tab:blue",
            ha="center", va="center"
        )

plt.xlim([-.2, .2])
plt.ylim([-.1, .1])
# Out:
# (-0.1, 0.1)

# %%
# Plot constructs

plt.figure(figsize=(12, 10))

for index,row in df_entity_embeddings.iterrows():
    entity_num = row['Eindex']
    entity = row['Elabel']
    if ":" not in entity and "Theory" not in entity:
        plt.annotate(
            text=entity,
            xy=(eu[entity_num, 0], eu[entity_num, 1]),
            color="tab:blue",
            ha="center", va="center"
        )

plt.xlim([-.2, .2])
plt.ylim([-.1, .1])


#    elif ":" in id_to_entity[entity]:
#        plt.annotate(
#            text=id_to_entity[entity][0:10],
#            xy=(eu[i, 0], eu[i, 1]),
#            color="tab:green",
#            ha="center", va="center"
#        )
#    else: 
#        plt.annotate(
#            text=id_to_entity[entity][0:10],
#            xy=(eu[i, 0], eu[i, 1]),
#            color="tab:grey",
#            ha="center", va="center"
#        )
#    
### NEED A DYNAMIC INTERACTIVE VISUALISATION SO WE CAN CHOOSE CONSTRUCTS ETC AND VISUALISE THEM 
### ALSO SEE THE DIFFERENCES IN EMBEDDING SPACE
# Out:
# (-0.1, 0.1)

# %%
# get relation labels from training set
relation_labels = training.relation_labeling.all_labels()
# convert relations to ids
relation_ids = torch.as_tensor(training.relations_to_ids(relation_labels))
# retrieve the embeddings using relation ids
relation_embeddings = result.model.relation_representations[0](indices=relation_ids)
# create a dictionary of relation labels and embeddings
relation_embeddings_dict = dict(zip(relation_labels, relation_embeddings.detach().numpy()))

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage([d for d in df_entity_embeddings['Embedding'].head(76)], method='ward')

# %%
len(Z)
# Out:
# 75

# %%
import numpy as np
import matplotlib.pyplot as plt
# Plot the dendrogram
print(df_entity_embeddings['Elabel'].head(76))

plt.figure(figsize=(10, 7))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample index or (cluster size)')
plt.ylabel('Distance')
dendrogram(Z, labels=[l for l in df_entity_embeddings['Elabel'].head(76)])
plt.show()
# Out:
# 0              1---Action Theory Model of Consumption
# 1                             10---Containment Theory
# 2                                 11---Control Theory
# 3                12---Differential Association Theory
# 4                       13---Diffusion of Innovations
#                            ...
# 71                   80---Theory of Triadic Influence
# 72       81---The Transcontextual Model of Motivation
# 73    82---Transtheoretical Model of Behaviour Change
# 74                      83---Value Belief Norm Theory
# 75                9---Consumption as social practices
# Name: Elabel, Length: 76, dtype: object

# %% [markdown]
# ### Can we use the method of knowledge graph link prediction to predict relationships?
#
# As a way to test the integrated theories

# %%
from pykeen import predict

# tail prediction
predict.predict_target(model=result.model,
                       head="mexico",
                       relation="neighbor",
                       triples_factory=result.training).df.head(20)

# %%
from pykeen.evaluation import RankBasedEvaluator

# Create an evaluator
evaluator = RankBasedEvaluator()

# Evaluate the model
metrics = evaluator.evaluate(result.model, testing.mapped_triples, additional_filter_triples=[training.mapped_triples, validation.mapped_triples])

# Print the metrics
print(f"Hits@1: {metrics.get_metric('hits@1')}")
print(f"Hits@3: {metrics.get_metric('hits@3')}")
print(f"Hits@5: {metrics.get_metric('hits@5')}")
print(f"Hits@10: {metrics.get_metric('hits@10')}")
print(f"Mean Reciprocal Rank: {metrics.get_metric('mean_reciprocal_rank')}")
# Out:
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|                                                                                                           | 0.00/7.25k [00:00<?, ?triple/s]WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# Evaluating on cpu: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 7.25k/7.25k [00:10<00:00, 687triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 10.61s seconds
# Hits@1: 0.004342431761786601
# Hits@3: 0.011993382961124897
# Hits@5: 0.020057899090157153
# Hits@10: 0.03825475599669148
# Mean Reciprocal Rank: 0.02005874551832676

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

plt.figure(figsize=(12, 10))
pca = PCA(n_components=2)
entity_embeddings = result.model.entity_representations[0](indices=None).detach().numpy()
m = pca.fit(entity_embeddings)

eu = m.transform(entity_embeddings)
# plt.plot(eu[:, 0], eu[:, 1],'.b')
for i, entity in enumerate(triples_factory.entity_id_to_label):
    if "Theory" in id_to_entity[entity]:
        plt.annotate(
            text=id_to_entity[entity][0:10],
            xy=(eu[i, 0], eu[i, 1]),
            color="tab:blue",
            ha="center", va="center"
        )
    elif ":" in id_to_entity[entity]:
        plt.annotate(
            text=id_to_entity[entity][0:10],
            xy=(eu[i, 0], eu[i, 1]),
            color="tab:green",
            ha="center", va="center"
        )
    else: 
        plt.annotate(
            text=id_to_entity[entity][0:10],
            xy=(eu[i, 0], eu[i, 1]),
            color="tab:grey",
            ha="center", va="center"
        )
    


#relation_embeddings = model.relation_representations[0](indices=None).detach().numpy()
#ru = pca.transform(relation_embeddings)
#for i, relation in enumerate(triples_factory.relation_id_to_label):
#    plt.annotate(
#        text=id_to_relation[relation],
#        xy=(0,0), xytext=(ru[i, 0], ru[i, 1]),
#        arrowprops=dict(
#            arrowstyle="<-",
#            color="tab:red",
#            shrinkA=5,
#            shrinkB=5,
#            patchA=None,
#            patchB=None,
#            connectionstyle="arc3,rad=0."
#        )
#    )

plt.xlim([-2, 2])
plt.ylim([-2, 2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 12
#      10 eu = m.transform(entity_embeddings)
#      11 # plt.plot(eu[:, 0], eu[:, 1],'.b')
# ---> 12 for i, entity in enumerate(triples_factory.entity_id_to_label):
#      13     if "Theory" in id_to_entity[entity]:
#      14         plt.annotate(
#      15             text=id_to_entity[entity][0:10],
#      16             xy=(eu[i, 0], eu[i, 1]),
#      17             color="tab:blue",
#      18             ha="center", va="center"
#      19         )
#
# NameError: name 'triples_factory' is not defined

# %% [markdown]
# ### Using the class hierarchy to integrate theories
#
# We aim to use the ontology class hierarchy to expand the annotations and use the expanded annotations to integrate across the theories to form an overarching "integrated" theory.
#
# Some ideas:
# - Looking for contradictions using a logical reasoner (but do we have sufficient disjointness axioms to use for this?)
# - Some kind of enrichment analysis algorithm?
