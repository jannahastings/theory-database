# %%
import os
import csv
import codecs
import copy

import ontoutils
from ontoutils.lucid_chart import Relation

os.chdir('C:/Users/mabraun/OneDrive - Universität Zürich UZH/git/theory-database')

# %%
junctions = []
containers = []
theory_row_dicts = {}

directory = "theories_2025"

theory_files = [file for file in os.listdir(directory) if file.endswith(".csv")]
model_filenames = {}

for f in theory_files:
    with codecs.open(directory+"/"+str(f), mode='r', encoding="utf-8") as csv_file:
        model_num = str(f).split('.')[0]
        model_filenames[model_num] = str(f)
        model_name = str(f).split('.')[1]

        theory_row_dicts[model_num] = {}
        
        csv_reader = csv.DictReader(csv_file)
        
        for row in csv_reader:
            id = row['Id']
            type = row['Name']
            label = str(row['Text Area 1']).strip()
            line_source = row['Line Source']
            line_dest = row['Line Destination']
            source_arrow = row['Source Arrow']
            dest_arrow = row['Destination Arrow']
            
            theory_row_dicts[model_num][id] = row
            #print(theory_row_dicts[model_num][id])
            if type in ['Process','Text','Rectangle','TerminatorBlock', 'Block','Terminator']:
                
                if type == 'Text' and label.startswith(model_num): # model name. Ignore
                    continue
                
                if type in ['Text','Rectangle','Terminator','Block', 'TerminatorBlock']:
                    print ("In model",model_num,"updating construct entity",id,"of type",type,"to Process")
                    theory_row_dicts[model_num][id]['Name']='Process'
                    theory_row_dicts[model_num][id]['Shape Library']='Flowchart Shapes'

            elif type == 'Line':
                #if len(label)>0: print("Relation label: ",label)
                # Some CSVs may contain lines for which the line source and line destination are the wrong way around. If ‘Source Arrow’ field contains Arrow and ‘Destination Arrow’ field contains None then ‘Line Source’ and ‘Line Destination’ need to be reversed. ‘Source Arrow’ and ‘Destination Arrow’ also need to be reversed. It is permissible that ‘Source Arrow’ and ‘Destination Arrow’ both contain Arrow. It is an error if ‘Source Arrow’ and ‘Destination Arrow’ both contain None; this should be flagged so a researcher can check the diagram. 
                if source_arrow == 'Arrow' and dest_arrow == 'None': 
                    print("In model",model_num,"Reversing direction of arrow id",id)
                    theory_row_dicts[model_num][id]['Line Source']=line_dest
                    theory_row_dicts[model_num][id]['Line Destination']=line_source
                    theory_row_dicts[model_num][id]['Source Arrow']='None'
                    theory_row_dicts[model_num][id]['Destination Arrow']='Arrow'
                if source_arrow == 'None' and dest_arrow == 'None':
                    print("Model:",model_num,"ERROR: NO-DIRECTION ARROW")
            elif type in ['Summing Junction', 'Summing junction', 'Connector', 'Or','Merge','Isosceles Triangle', 'Isosceles triangle', 'Circle']:
                # Replace the circle and triangle
                if type == 'Circle':
                    #print("In model:",model_num," updating Circle with id",id,"to Connector")
                    theory_row_dicts[model_num][id]['Name']='Connector'
                    theory_row_dicts[model_num][id]['Shape Library']='Flowchart Shapes'
                if type in ['Isosceles Triangle', 'Isosceles triangle']:
                    #print("In model:",model_num," updating Isosceles Triangle with id",id,"to Merge")
                    theory_row_dicts[model_num][id]['Name']='Merge'
                    theory_row_dicts[model_num][id]['Shape Library']='Flowchart Shapes'
                junctions.append(str(model_num)+":"+id+":"+type)
            elif type == 'Rectangle Container':
                # A few CSVs may include Container Rectangles which contain other constructs. In these cases there will be data in the ‘Contained By’ field. Any constructs ‘contained by’ another construct should inherit the relationships of the container and the container should be deleted. 
                containers.append(str(model_num)+":"+id)
                #print("Got container: ",id)
            elif type in ['Document','Page']: # ignore
                continue
            else:
                print("ERROR: UNKNOWN TYPE: ",type, "in model", model_num)
# Out:
# In model 1 updating construct entity 3 of type Block to Process
# In model 1 updating construct entity 4 of type Block to Process
# In model 1 updating construct entity 6 of type Block to Process
# In model 1 updating construct entity 7 of type Block to Process
# In model 1 updating construct entity 8 of type Block to Process
# In model 1 updating construct entity 10 of type Block to Process
# In model 1 updating construct entity 11 of type Block to Process
# In model 1 updating construct entity 12 of type Block to Process
# In model 1 updating construct entity 14 of type Block to Process
# In model 1 updating construct entity 15 of type Block to Process
# In model 1 updating construct entity 16 of type Block to Process
# In model 1 updating construct entity 18 of type Block to Process
# In model 1 updating construct entity 19 of type Block to Process
# In model 1 updating construct entity 20 of type Block to Process
# In model 1 updating construct entity 21 of type Block to Process
# In model 1 updating construct entity 22 of type Block to Process
# In model 1 updating construct entity 23 of type Block to Process
# In model 1 updating construct entity 24 of type Block to Process
# In model 1 updating construct entity 26 of type Block to Process
# In model 1 updating construct entity 27 of type Block to Process
# In model 1 updating construct entity 28 of type Block to Process
# In model 1 updating construct entity 29 of type Block to Process
# In model 1 updating construct entity 30 of type Block to Process
# In model 1 updating construct entity 31 of type Block to Process
# In model 1 updating construct entity 32 of type Block to Process
# In model 1 updating construct entity 33 of type Block to Process
# In model 1 updating construct entity 34 of type Block to Process
# In model 1 updating construct entity 36 of type Rectangle to Process
# In model 1 updating construct entity 37 of type Rectangle to Process
# In model 1 updating construct entity 38 of type Rectangle to Process
# In model 1 updating construct entity 39 of type Rectangle to Process
# In model 1 updating construct entity 40 of type Rectangle to Process
# In model 10 updating construct entity 22 of type Block to Process
# In model 10 updating construct entity 23 of type Block to Process
# In model 14 updating construct entity 3 of type Text to Process
# In model 14 updating construct entity 13 of type Block to Process
# In model 14 updating construct entity 15 of type Block to Process
# In model 14 updating construct entity 19 of type Block to Process
# In model 14 updating construct entity 20 of type Block to Process
# In model 16 updating construct entity 3 of type Block to Process
# In model 16 updating construct entity 4 of type Block to Process
# In model 16 updating construct entity 5 of type Block to Process
# In model 16 updating construct entity 6 of type Block to Process
# In model 16 updating construct entity 19 of type Block to Process
# In model 16 updating construct entity 22 of type Block to Process
# In model 16 updating construct entity 23 of type Block to Process
# In model 16 updating construct entity 26 of type Block to Process
# In model 16 updating construct entity 27 of type Block to Process
# In model 16 updating construct entity 30 of type Block to Process
# In model 17 updating construct entity 3 of type Block to Process
# In model 17 updating construct entity 4 of type Block to Process
# In model 17 updating construct entity 5 of type Block to Process
# In model 17 updating construct entity 6 of type Block to Process
# In model 17 updating construct entity 7 of type Block to Process
# In model 17 updating construct entity 8 of type Block to Process
# In model 17 updating construct entity 9 of type Block to Process
# In model 17 updating construct entity 10 of type Block to Process
# In model 17 updating construct entity 11 of type Block to Process
# In model 17 updating construct entity 12 of type Block to Process
# In model 17 updating construct entity 13 of type Block to Process
# In model 17 updating construct entity 14 of type Block to Process
# In model 17 updating construct entity 15 of type Block to Process
# In model 17 updating construct entity 16 of type Block to Process
# In model 17 updating construct entity 17 of type Block to Process
# In model 17 updating construct entity 18 of type Block to Process
# In model 17 updating construct entity 22 of type Block to Process
# In model 17 updating construct entity 23 of type Block to Process
# In model 17 updating construct entity 27 of type Block to Process
# In model 17 updating construct entity 28 of type Block to Process
# In model 17 updating construct entity 29 of type Block to Process
# In model 17 updating construct entity 30 of type Block to Process
# In model 17 updating construct entity 31 of type Block to Process
# In model 17 updating construct entity 32 of type Block to Process
# In model 17 updating construct entity 35 of type Block to Process
# In model 17 updating construct entity 36 of type Block to Process
# In model 17 updating construct entity 38 of type Block to Process
# In model 17 updating construct entity 39 of type Block to Process
# In model 17 updating construct entity 40 of type Block to Process
# In model 17 updating construct entity 42 of type Block to Process
# In model 17 updating construct entity 44 of type Block to Process
# In model 23 Reversing direction of arrow id 52
# In model 23 Reversing direction of arrow id 62
# In model 24 updating construct entity 3 of type Block to Process
# In model 24 updating construct entity 4 of type Block to Process
# In model 24 updating construct entity 5 of type Block to Process
# In model 24 updating construct entity 6 of type Block to Process
# In model 24 updating construct entity 7 of type Block to Process
# In model 24 updating construct entity 8 of type Block to Process
# In model 24 updating construct entity 9 of type Block to Process
# In model 24 updating construct entity 10 of type Block to Process
# In model 24 updating construct entity 11 of type Block to Process
# In model 24 updating construct entity 12 of type Block to Process
# In model 24 updating construct entity 13 of type Block to Process
# In model 24 updating construct entity 14 of type Block to Process
# In model 24 updating construct entity 17 of type Block to Process
# In model 24 updating construct entity 18 of type Block to Process
# In model 24 updating construct entity 19 of type Block to Process
# In model 24 updating construct entity 20 of type Block to Process
# In model 24 updating construct entity 21 of type Block to Process
# In model 24 updating construct entity 22 of type Block to Process
# In model 24 updating construct entity 23 of type Block to Process
# In model 24 updating construct entity 24 of type Block to Process
# In model 24 updating construct entity 26 of type Block to Process
# In model 24 updating construct entity 27 of type Block to Process
# In model 24 updating construct entity 28 of type Block to Process
# In model 24 updating construct entity 32 of type Block to Process
# In model 24 updating construct entity 33 of type Block to Process
# In model 24 updating construct entity 34 of type Block to Process
# In model 25 updating construct entity 8 of type Block to Process
# In model 26 updating construct entity 3 of type Block to Process
# In model 26 updating construct entity 14 of type Block to Process
# In model 29 updating construct entity 9 of type Block to Process
# In model 29 updating construct entity 14 of type Block to Process
# In model 29 updating construct entity 19 of type Block to Process
# In model 29 updating construct entity 41 of type Block to Process
# In model 30 Reversing direction of arrow id 32
# In model 33 updating construct entity 29 of type Block to Process
# In model 34 updating construct entity 3 of type Block to Process
# In model 34 updating construct entity 4 of type Block to Process
# In model 34 updating construct entity 5 of type Block to Process
# In model 34 updating construct entity 6 of type Block to Process
# In model 34 updating construct entity 7 of type Block to Process
# In model 34 updating construct entity 8 of type Block to Process
# In model 34 updating construct entity 9 of type Block to Process
# In model 34 updating construct entity 10 of type Block to Process
# In model 34 updating construct entity 11 of type Block to Process
# In model 34 updating construct entity 12 of type Block to Process
# In model 34 updating construct entity 13 of type Block to Process
# In model 34 updating construct entity 14 of type Block to Process
# In model 34 updating construct entity 15 of type Block to Process
# In model 34 updating construct entity 16 of type Block to Process
# In model 34 updating construct entity 17 of type Block to Process
# In model 34 updating construct entity 18 of type Block to Process
# In model 34 updating construct entity 19 of type Block to Process
# In model 34 updating construct entity 20 of type Block to Process
# In model 39 updating construct entity 21 of type Block to Process
# In model 39 updating construct entity 23 of type Block to Process
# In model 39 updating construct entity 26 of type Block to Process
# In model 39 updating construct entity 28 of type Block to Process
# In model 41 updating construct entity 3 of type Block to Process
# In model 41 updating construct entity 10 of type Block to Process
# In model 41 updating construct entity 27 of type Block to Process
# In model 41 updating construct entity 32 of type Block to Process
# In model 45 Reversing direction of arrow id 28
# In model 45 Reversing direction of arrow id 32
# In model 45 Reversing direction of arrow id 36
# In model 46 Reversing direction of arrow id 43
# In model 47 updating construct entity 11 of type Block to Process
# In model 47 updating construct entity 12 of type Block to Process
# In model 49 Reversing direction of arrow id 46
# In model 49 Reversing direction of arrow id 55
# In model 49 Reversing direction of arrow id 59
# In model 49 Reversing direction of arrow id 60
# In model 49 Reversing direction of arrow id 61
# In model 51 Reversing direction of arrow id 56
# In model 51 Reversing direction of arrow id 59
# In model 53 updating construct entity 3 of type Block to Process
# In model 53 updating construct entity 4 of type Block to Process
# In model 53 updating construct entity 5 of type Block to Process
# In model 53 updating construct entity 6 of type Block to Process
# In model 53 updating construct entity 7 of type Block to Process
# In model 53 updating construct entity 8 of type Block to Process
# In model 53 updating construct entity 9 of type Block to Process
# In model 53 updating construct entity 10 of type Block to Process
# In model 53 updating construct entity 11 of type Block to Process
# In model 53 updating construct entity 12 of type Block to Process
# In model 53 updating construct entity 13 of type Block to Process
# In model 53 updating construct entity 14 of type Block to Process
# In model 53 updating construct entity 15 of type Block to Process
# In model 53 updating construct entity 19 of type Block to Process
# In model 58 updating construct entity 3 of type Block to Process
# In model 58 updating construct entity 4 of type Block to Process
# In model 58 updating construct entity 5 of type Block to Process
# In model 58 updating construct entity 6 of type Block to Process
# In model 58 updating construct entity 7 of type Block to Process
# In model 58 updating construct entity 8 of type Block to Process
# In model 58 updating construct entity 9 of type Block to Process
# In model 58 updating construct entity 10 of type Block to Process
# In model 58 updating construct entity 11 of type Block to Process
# In model 58 updating construct entity 12 of type Block to Process
# In model 58 updating construct entity 13 of type Block to Process
# In model 58 updating construct entity 14 of type Block to Process
# In model 58 updating construct entity 15 of type Block to Process
# In model 58 updating construct entity 16 of type Block to Process
# In model 58 updating construct entity 17 of type Block to Process
# In model 58 updating construct entity 18 of type Block to Process
# In model 58 updating construct entity 19 of type Block to Process
# In model 58 updating construct entity 20 of type Block to Process
# In model 58 updating construct entity 21 of type Block to Process
# In model 58 updating construct entity 22 of type Block to Process
# In model 59 updating construct entity 18 of type Block to Process
# In model 59 updating construct entity 19 of type Block to Process
# In model 63 Reversing direction of arrow id 18
# In model 64 updating construct entity 13 of type Text to Process
# In model 66 Reversing direction of arrow id 72
# In model 68 updating construct entity 18 of type Text to Process
# In model 68 Reversing direction of arrow id 29
# In model 68 Reversing direction of arrow id 45
# In model 68 Reversing direction of arrow id 46
# In model 69 Reversing direction of arrow id 40
# In model 69 Reversing direction of arrow id 59
# In model 69 Reversing direction of arrow id 60
# In model 72 Reversing direction of arrow id 41
# In model 72 Reversing direction of arrow id 42
# In model 72 Reversing direction of arrow id 47
# In model 72 Reversing direction of arrow id 62
# In model 72 Reversing direction of arrow id 66
# In model 72 Reversing direction of arrow id 90
# In model 72 Reversing direction of arrow id 105
# In model 74 updating construct entity 3 of type Block to Process
# In model 74 updating construct entity 4 of type Block to Process
# In model 74 updating construct entity 5 of type Block to Process
# In model 74 updating construct entity 6 of type Block to Process
# In model 74 updating construct entity 7 of type Block to Process
# In model 74 updating construct entity 8 of type Block to Process
# In model 74 updating construct entity 9 of type Block to Process
# In model 74 updating construct entity 10 of type Block to Process
# In model 74 updating construct entity 11 of type Block to Process
# In model 77 updating construct entity 3 of type Block to Process
# In model 77 updating construct entity 4 of type Block to Process
# In model 77 updating construct entity 5 of type Block to Process
# In model 77 updating construct entity 6 of type Block to Process
# In model 77 updating construct entity 7 of type Block to Process
# In model 77 updating construct entity 8 of type Block to Process
# In model 77 updating construct entity 9 of type Block to Process
# In model 77 updating construct entity 10 of type Block to Process
# In model 77 updating construct entity 11 of type Block to Process
# In model 77 updating construct entity 12 of type Block to Process
# In model 77 updating construct entity 13 of type Block to Process
# In model 77 updating construct entity 14 of type Block to Process
# In model 77 updating construct entity 15 of type Block to Process
# In model 77 updating construct entity 16 of type Block to Process
# In model 77 updating construct entity 17 of type Block to Process
# In model 77 updating construct entity 18 of type Block to Process
# In model 77 updating construct entity 19 of type Block to Process
# In model 8 updating construct entity 10 of type Block to Process
# In model 8 updating construct entity 11 of type Block to Process
# In model 8 updating construct entity 12 of type Block to Process
# In model 80 Reversing direction of arrow id 53
# In model 80 Reversing direction of arrow id 55
# In model 80 Reversing direction of arrow id 57
# In model 80 Reversing direction of arrow id 60
# In model 80 Reversing direction of arrow id 66
# In model 80 Reversing direction of arrow id 70
# In model 80 Reversing direction of arrow id 79
# In model 82 updating construct entity 9 of type TerminatorBlock to Process
# In model 82 updating construct entity 10 of type TerminatorBlock to Process
# In model 82 updating construct entity 11 of type TerminatorBlock to Process
# In model 82 updating construct entity 12 of type TerminatorBlock to Process
# In model 9 updating construct entity 15 of type Block to Process

# %%
# Process the junctions and containers out of the relations list by connecting all sources to all targets. Assign the relations the type corresponding to the type of the junction. 

ids_to_remove = {}

for strId in junctions: 
    [model_num,conn_id,type] = strId.split(":")
    if model_num not in ids_to_remove.keys():
        ids_to_remove[model_num] = []
    ids_to_remove[model_num].append(conn_id)  # Remove the connector
    print (f"Processing theory {model_num}")
    maxTheoryId = max( map(int, theory_row_dicts[model_num].keys()) )
    nextId = maxTheoryId+1
    
    if type == 'Merge':
        type_str = 'Type of'
    if type == 'Summing junction':
        type_str = '*'
    if type == 'Connector':
        type_str = 'Part of'
    if type == 'Or':
        type_str = '+'
    
    jnc_srcs = []
    map_srcs = {}
    jnc_tars = []
    map_tars = {}
    
    # This works per model
    all_dests = {id:theory_row_dicts[model_num][id]['Line Destination'] for id in theory_row_dicts[model_num] if len(theory_row_dicts[model_num][id]['Line Destination'])>0 }
    
    for id in theory_row_dicts[model_num]:
        if theory_row_dicts[model_num][id]['Name'] == 'Line':
            line_to_copy = theory_row_dicts[model_num][id]
            source_id = theory_row_dicts[model_num][id]['Line Source']
            target_id = theory_row_dicts[model_num][id]['Line Destination']
            if source_id == conn_id:
                jnc_tars.append(target_id)
                ids_to_remove[model_num].append(id)
                # Check if any rels end on this rel
                if id in set(all_dests.values()): 
                    map_tars[target_id]=id
            if target_id == conn_id:
                jnc_srcs.append(source_id)
                ids_to_remove[model_num].append(id)
                if id in set(all_dests.values()):
                    map_srcs[source_id]=id
    
    if len(map_srcs)>0: 
        print ("Sources to be mapped: ",map_srcs)
    if len(map_tars)>0:
        print ("Targets to be mapped: ",map_tars)
            
    rels_to_add = []
    for s in jnc_srcs:
        for t in jnc_tars:
            rels_to_add.append((s,t))
            
    for (s,t) in rels_to_add:
        rel = copy.deepcopy(line_to_copy)
        rel['Id']=str(nextId)
        rel['Line Source'] = s
        rel['Line Destination'] = t
        rel['Text Area 1'] = type_str
        theory_row_dicts[model_num][str(nextId)] = rel
        if s in map_srcs.keys(): 
            oldId = map_srcs[s]
            for arrowToOldId in  [k for (k,v) in all_dests.items() if v==oldId ]:
                if arrowToOldId not in theory_row_dicts[model_num]:
                    print("ERROR! Can't find original arrow",arrowToOldId,"In model ",model_num)
                else: 
                    theory_row_dicts[model_num][arrowToOldId]['Line Destination'] = str(nextId)
                print ("In model",model_num,"Mapped arrow",arrowToOldId," that ended on ",oldId,"to end on",str(nextId))
        if t in map_tars.keys(): 
            oldId = map_tars[t]
            for arrowToOldId in [k for (k,v) in all_dests.items() if v==oldId ]:
                theory_row_dicts[model_num][arrowToOldId]['Line Destination'] = str(nextId)
                print ("In model",model_num,"Mapped arrow",arrowToOldId," that ended on ",oldId,"to end on",str(nextId))
        nextId = nextId+1
        print("Added expanded arrow ",rel['Id'],"to model",model_num,"relating",s,"to",t)
# Out:
# Processing theory 1
# Added expanded arrow  106 to model 1 relating 3 to 6
# Added expanded arrow  107 to model 1 relating 3 to 25
# Added expanded arrow  108 to model 1 relating 4 to 6
# Added expanded arrow  109 to model 1 relating 4 to 25
# Processing theory 1
# Added expanded arrow  110 to model 1 relating 8 to 7
# Processing theory 1
# Added expanded arrow  111 to model 1 relating 10 to 25
# Added expanded arrow  112 to model 1 relating 10 to 12
# Added expanded arrow  113 to model 1 relating 11 to 25
# Added expanded arrow  114 to model 1 relating 11 to 12
# Processing theory 1
# Added expanded arrow  115 to model 1 relating 14 to 16
# Added expanded arrow  116 to model 1 relating 14 to 25
# Added expanded arrow  117 to model 1 relating 14 to 12
# Added expanded arrow  118 to model 1 relating 15 to 16
# Added expanded arrow  119 to model 1 relating 15 to 25
# Added expanded arrow  120 to model 1 relating 15 to 12
# Processing theory 1
# Added expanded arrow  121 to model 1 relating 12 to 26
# Added expanded arrow  122 to model 1 relating 23 to 26
# Added expanded arrow  123 to model 1 relating 20 to 26
# Added expanded arrow  124 to model 1 relating 5 to 26
# Added expanded arrow  125 to model 1 relating 13 to 26
# Added expanded arrow  126 to model 1 relating 17 to 26
# Added expanded arrow  127 to model 1 relating 7 to 26
# Added expanded arrow  128 to model 1 relating 6 to 26
# Added expanded arrow  129 to model 1 relating 16 to 26
# Added expanded arrow  130 to model 1 relating 22 to 26
# Added expanded arrow  131 to model 1 relating 19 to 26
# Added expanded arrow  132 to model 1 relating 32 to 26
# Added expanded arrow  133 to model 1 relating 18 to 26
# Added expanded arrow  134 to model 1 relating 21 to 26
# Added expanded arrow  135 to model 1 relating 24 to 26
# Added expanded arrow  136 to model 1 relating 31 to 26
# Added expanded arrow  137 to model 1 relating 3 to 26
# Added expanded arrow  138 to model 1 relating 4 to 26
# Added expanded arrow  139 to model 1 relating 10 to 26
# Added expanded arrow  140 to model 1 relating 11 to 26
# Added expanded arrow  141 to model 1 relating 14 to 26
# Added expanded arrow  142 to model 1 relating 15 to 26
# Processing theory 1
# Added expanded arrow  143 to model 1 relating 34 to 32
# Added expanded arrow  144 to model 1 relating 33 to 32
# Processing theory 10
# Added expanded arrow  50 to model 10 relating 23 to 5
# Added expanded arrow  51 to model 10 relating 22 to 5
# Processing theory 10
# Added expanded arrow  52 to model 10 relating 6 to 22
# Added expanded arrow  53 to model 10 relating 7 to 22
# Added expanded arrow  54 to model 10 relating 8 to 22
# Added expanded arrow  55 to model 10 relating 9 to 22
# Added expanded arrow  56 to model 10 relating 10 to 22
# Added expanded arrow  57 to model 10 relating 11 to 22
# Added expanded arrow  58 to model 10 relating 12 to 22
# Added expanded arrow  59 to model 10 relating 13 to 22
# Added expanded arrow  60 to model 10 relating 14 to 22
# Processing theory 10
# Added expanded arrow  61 to model 10 relating 15 to 23
# Added expanded arrow  62 to model 10 relating 16 to 23
# Added expanded arrow  63 to model 10 relating 17 to 23
# Added expanded arrow  64 to model 10 relating 18 to 23
# Added expanded arrow  65 to model 10 relating 19 to 23
# Added expanded arrow  66 to model 10 relating 20 to 23
# Added expanded arrow  67 to model 10 relating 21 to 23
# Processing theory 11
# Added expanded arrow  35 to model 11 relating 7 to 13
# Added expanded arrow  36 to model 11 relating 8 to 13
# Added expanded arrow  37 to model 11 relating 9 to 13
# Added expanded arrow  38 to model 11 relating 10 to 13
# Processing theory 12
# Added expanded arrow  52 to model 12 relating 14 to 4
# Added expanded arrow  53 to model 12 relating 13 to 4
# Processing theory 12
# Added expanded arrow  54 to model 12 relating 19 to 16
# Added expanded arrow  55 to model 12 relating 18 to 16
# Processing theory 12
# Added expanded arrow  56 to model 12 relating 21 to 19
# Processing theory 12
# Added expanded arrow  57 to model 12 relating 4 to 18
# Added expanded arrow  58 to model 12 relating 3 to 18
# Processing theory 12
# Added expanded arrow  59 to model 12 relating 24 to 12
# Added expanded arrow  60 to model 12 relating 25 to 12
# Processing theory 13
# Added expanded arrow  209 to model 13 relating 7 to 5
# Processing theory 13
# Added expanded arrow  210 to model 13 relating 10 to 7
# Added expanded arrow  211 to model 13 relating 9 to 7
# Added expanded arrow  212 to model 13 relating 13 to 7
# Processing theory 13
# Added expanded arrow  213 to model 13 relating 15 to 5
# Added expanded arrow  214 to model 13 relating 18 to 5
# Processing theory 13
# Added expanded arrow  215 to model 13 relating 20 to 18
# Added expanded arrow  216 to model 13 relating 23 to 18
# Added expanded arrow  217 to model 13 relating 21 to 18
# Added expanded arrow  218 to model 13 relating 22 to 18
# Added expanded arrow  219 to model 13 relating 19 to 18
# Added expanded arrow  220 to model 13 relating 24 to 18
# Added expanded arrow  221 to model 13 relating 74 to 18
# Added expanded arrow  222 to model 13 relating 73 to 18
# Processing theory 13
# Added expanded arrow  223 to model 13 relating 31 to 27
# Added expanded arrow  224 to model 13 relating 33 to 27
# Added expanded arrow  225 to model 13 relating 34 to 27
# Added expanded arrow  226 to model 13 relating 28 to 27
# Added expanded arrow  227 to model 13 relating 75 to 27
# Added expanded arrow  228 to model 13 relating 75 to 27
# Processing theory 13
# Added expanded arrow  229 to model 13 relating 26 to 6
# Added expanded arrow  230 to model 13 relating 27 to 6
# Processing theory 13
# Added expanded arrow  231 to model 13 relating 33 to 26
# Added expanded arrow  232 to model 13 relating 34 to 26
# Processing theory 13
# Added expanded arrow  233 to model 13 relating 61 to 36
# Added expanded arrow  234 to model 13 relating 62 to 36
# Added expanded arrow  235 to model 13 relating 63 to 36
# Added expanded arrow  236 to model 13 relating 64 to 36
# Processing theory 13
# Added expanded arrow  237 to model 13 relating 50 to 17
# Processing theory 13
# Added expanded arrow  238 to model 13 relating 52 to 4
# Added expanded arrow  239 to model 13 relating 53 to 4
# Added expanded arrow  240 to model 13 relating 55 to 4
# Added expanded arrow  241 to model 13 relating 61 to 4
# Added expanded arrow  242 to model 13 relating 62 to 4
# Added expanded arrow  243 to model 13 relating 63 to 4
# Added expanded arrow  244 to model 13 relating 64 to 4
# Processing theory 13
# Added expanded arrow  245 to model 13 relating 86 to 55
# Processing theory 13
# Added expanded arrow  246 to model 13 relating 58 to 86
# Processing theory 13
# Added expanded arrow  247 to model 13 relating 37 to 36
# Added expanded arrow  248 to model 13 relating 38 to 36
# Added expanded arrow  249 to model 13 relating 39 to 36
# Added expanded arrow  250 to model 13 relating 40 to 36
# Added expanded arrow  251 to model 13 relating 41 to 36
# Processing theory 13
# Added expanded arrow  252 to model 13 relating 66 to 64
# Processing theory 13
# Added expanded arrow  253 to model 13 relating 70 to 68
# Added expanded arrow  254 to model 13 relating 71 to 68
# Added expanded arrow  255 to model 13 relating 72 to 68
# Processing theory 13
# Added expanded arrow  256 to model 13 relating 44 to 43
# Added expanded arrow  257 to model 13 relating 46 to 43
# Added expanded arrow  258 to model 13 relating 47 to 43
# Added expanded arrow  259 to model 13 relating 48 to 43
# Added expanded arrow  260 to model 13 relating 49 to 43
# Processing theory 13
# Added expanded arrow  261 to model 13 relating 82 to 84
# Added expanded arrow  262 to model 13 relating 81 to 84
# Added expanded arrow  263 to model 13 relating 79 to 84
# Added expanded arrow  264 to model 13 relating 80 to 84
# Processing theory 13
# Added expanded arrow  265 to model 13 relating 76 to 86
# Added expanded arrow  266 to model 13 relating 77 to 86
# Added expanded arrow  267 to model 13 relating 78 to 86
# Processing theory 13
# Processing theory 13
# Processing theory 14
# Added expanded arrow  57 to model 14 relating 10 to 13
# Added expanded arrow  58 to model 14 relating 11 to 13
# Added expanded arrow  59 to model 14 relating 12 to 13
# Processing theory 14
# Added expanded arrow  60 to model 14 relating 18 to 15
# Added expanded arrow  61 to model 14 relating 17 to 15
# Added expanded arrow  62 to model 14 relating 16 to 15
# Processing theory 14
# Added expanded arrow  63 to model 14 relating 5 to 9
# Added expanded arrow  64 to model 14 relating 7 to 9
# Added expanded arrow  65 to model 14 relating 4 to 9
# Added expanded arrow  66 to model 14 relating 6 to 9
# Added expanded arrow  67 to model 14 relating 8 to 9
# Processing theory 14
# Added expanded arrow  68 to model 14 relating 9 to 19
# Added expanded arrow  69 to model 14 relating 14 to 19
# Processing theory 14
# Added expanded arrow  70 to model 14 relating 13 to 20
# Added expanded arrow  71 to model 14 relating 15 to 20
# Processing theory 16
# Added expanded arrow  71 to model 16 relating 3 to 19
# Added expanded arrow  72 to model 16 relating 5 to 19
# Added expanded arrow  73 to model 16 relating 4 to 19
# Added expanded arrow  74 to model 16 relating 6 to 19
# Processing theory 16
# Targets to be mapped:  {'17': '56', '11': '57'}
# In model 16 Mapped arrow 39  that ended on  56 to end on 75
# Added expanded arrow  75 to model 16 relating 22 to 17
# In model 16 Mapped arrow 40  that ended on  57 to end on 76
# Added expanded arrow  76 to model 16 relating 22 to 11
# In model 16 Mapped arrow 39  that ended on  56 to end on 77
# Added expanded arrow  77 to model 16 relating 23 to 17
# In model 16 Mapped arrow 40  that ended on  57 to end on 78
# Added expanded arrow  78 to model 16 relating 23 to 11
# In model 16 Mapped arrow 39  that ended on  56 to end on 79
# Added expanded arrow  79 to model 16 relating 14 to 17
# In model 16 Mapped arrow 40  that ended on  57 to end on 80
# Added expanded arrow  80 to model 16 relating 14 to 11
# Processing theory 16
# Added expanded arrow  81 to model 16 relating 9 to 22
# Added expanded arrow  82 to model 16 relating 10 to 22
# Processing theory 16
# Added expanded arrow  83 to model 16 relating 7 to 23
# Added expanded arrow  84 to model 16 relating 8 to 23
# Processing theory 16
# Added expanded arrow  85 to model 16 relating 12 to 26
# Added expanded arrow  86 to model 16 relating 15 to 26
# Processing theory 16
# Added expanded arrow  87 to model 16 relating 13 to 27
# Added expanded arrow  88 to model 16 relating 16 to 27
# Processing theory 16
# Added expanded arrow  89 to model 16 relating 3 to 30
# Added expanded arrow  90 to model 16 relating 5 to 30
# Added expanded arrow  91 to model 16 relating 4 to 30
# Added expanded arrow  92 to model 16 relating 6 to 30
# Processing theory 17
# Added expanded arrow  111 to model 17 relating 4 to 9
# Added expanded arrow  112 to model 17 relating 4 to 57
# Added expanded arrow  113 to model 17 relating 8 to 9
# Added expanded arrow  114 to model 17 relating 8 to 57
# Added expanded arrow  115 to model 17 relating 7 to 9
# Added expanded arrow  116 to model 17 relating 7 to 57
# Added expanded arrow  117 to model 17 relating 6 to 9
# Added expanded arrow  118 to model 17 relating 6 to 57
# Processing theory 17
# Added expanded arrow  119 to model 17 relating 17 to 18
# Added expanded arrow  120 to model 17 relating 16 to 18
# Added expanded arrow  121 to model 17 relating 14 to 18
# Processing theory 17
# Added expanded arrow  122 to model 17 relating 17 to 6
# Added expanded arrow  123 to model 17 relating 17 to 4
# Added expanded arrow  124 to model 17 relating 17 to 18
# Added expanded arrow  125 to model 17 relating 16 to 6
# Added expanded arrow  126 to model 17 relating 16 to 4
# Added expanded arrow  127 to model 17 relating 16 to 18
# Processing theory 17
# Added expanded arrow  128 to model 17 relating 23 to 11
# Added expanded arrow  129 to model 17 relating 10 to 11
# Added expanded arrow  130 to model 17 relating 5 to 11
# Added expanded arrow  131 to model 17 relating 22 to 11
# Processing theory 17
# Added expanded arrow  132 to model 17 relating 6 to 9
# Added expanded arrow  133 to model 17 relating 18 to 9
# Added expanded arrow  134 to model 17 relating 14 to 9
# Added expanded arrow  135 to model 17 relating 13 to 9
# Added expanded arrow  136 to model 17 relating 11 to 9
# Added expanded arrow  137 to model 17 relating 15 to 9
# Added expanded arrow  138 to model 17 relating 12 to 9
# Processing theory 17
# Added expanded arrow  139 to model 17 relating 9 to 3
# Added expanded arrow  140 to model 17 relating 4 to 3
# Added expanded arrow  141 to model 17 relating 8 to 3
# Added expanded arrow  142 to model 17 relating 7 to 3
# Added expanded arrow  143 to model 17 relating 27 to 3
# Added expanded arrow  144 to model 17 relating 28 to 3
# Processing theory 17
# Added expanded arrow  145 to model 17 relating 30 to 29
# Processing theory 17
# Added expanded arrow  146 to model 17 relating 31 to 35
# Added expanded arrow  147 to model 17 relating 32 to 35
# Processing theory 17
# Added expanded arrow  148 to model 17 relating 36 to 4
# Added expanded arrow  149 to model 17 relating 12 to 4
# Added expanded arrow  150 to model 17 relating 35 to 4
# Added expanded arrow  151 to model 17 relating 44 to 4
# Processing theory 17
# Added expanded arrow  152 to model 17 relating 38 to 36
# Added expanded arrow  153 to model 17 relating 39 to 36
# Added expanded arrow  154 to model 17 relating 40 to 36
# Processing theory 17
# Added expanded arrow  155 to model 17 relating 42 to 8
# Processing theory 18
# Added expanded arrow  20 to model 18 relating 4 to 9
# Added expanded arrow  21 to model 18 relating 3 to 9
# Added expanded arrow  22 to model 18 relating 5 to 9
# Processing theory 19
# Added expanded arrow  36 to model 19 relating 3 to 8
# Added expanded arrow  37 to model 19 relating 4 to 8
# Added expanded arrow  38 to model 19 relating 5 to 8
# Added expanded arrow  39 to model 19 relating 6 to 8
# Added expanded arrow  40 to model 19 relating 7 to 8
# Processing theory 19
# Added expanded arrow  41 to model 19 relating 11 to 10
# Added expanded arrow  42 to model 19 relating 12 to 10
# Added expanded arrow  43 to model 19 relating 13 to 10
# Added expanded arrow  44 to model 19 relating 14 to 10
# Processing theory 19
# Added expanded arrow  45 to model 19 relating 17 to 16
# Processing theory 22
# Added expanded arrow  53 to model 22 relating 4 to 8
# Added expanded arrow  54 to model 22 relating 4 to 9
# Added expanded arrow  55 to model 22 relating 9 to 8
# Added expanded arrow  56 to model 22 relating 9 to 9
# Added expanded arrow  57 to model 22 relating 5 to 8
# Added expanded arrow  58 to model 22 relating 5 to 9
# Added expanded arrow  59 to model 22 relating 6 to 8
# Added expanded arrow  60 to model 22 relating 6 to 9
# Processing theory 22
# Added expanded arrow  61 to model 22 relating 13 to 11
# Added expanded arrow  62 to model 22 relating 14 to 11
# Processing theory 22
# Added expanded arrow  63 to model 22 relating 16 to 13
# Added expanded arrow  64 to model 22 relating 17 to 13
# Processing theory 22
# Added expanded arrow  65 to model 22 relating 19 to 14
# Added expanded arrow  66 to model 22 relating 20 to 14
# Processing theory 22
# Added expanded arrow  67 to model 22 relating 23 to 12
# Added expanded arrow  68 to model 22 relating 22 to 12
# Processing theory 22
# Added expanded arrow  69 to model 22 relating 11 to 8
# Added expanded arrow  70 to model 22 relating 12 to 8
# Processing theory 23
# Added expanded arrow  88 to model 23 relating 4 to 3
# Added expanded arrow  89 to model 23 relating 5 to 3
# Processing theory 23
# Added expanded arrow  90 to model 23 relating 16 to 40
# Added expanded arrow  91 to model 23 relating 16 to 39
# Added expanded arrow  92 to model 23 relating 16 to 43
# Added expanded arrow  93 to model 23 relating 16 to 45
# Added expanded arrow  94 to model 23 relating 4 to 40
# Added expanded arrow  95 to model 23 relating 4 to 39
# Added expanded arrow  96 to model 23 relating 4 to 43
# Added expanded arrow  97 to model 23 relating 4 to 45
# Processing theory 23
# Added expanded arrow  98 to model 23 relating 18 to 45
# Added expanded arrow  99 to model 23 relating 3 to 45
# Processing theory 23
# Added expanded arrow  100 to model 23 relating 17 to 3
# Added expanded arrow  101 to model 23 relating 15 to 3
# Processing theory 23
# Added expanded arrow  102 to model 23 relating 9 to 23
# Processing theory 23
# Added expanded arrow  103 to model 23 relating 7 to 3
# Added expanded arrow  104 to model 23 relating 8 to 3
# Added expanded arrow  105 to model 23 relating 10 to 3
# Added expanded arrow  106 to model 23 relating 25 to 3
# Added expanded arrow  107 to model 23 relating 9 to 3
# Added expanded arrow  108 to model 23 relating 29 to 3
# Added expanded arrow  109 to model 23 relating 28 to 3
# Processing theory 23
# Targets to be mapped:  {'11': '39', '12': '40', '19': '43'}
# In model 23 Mapped arrow 49  that ended on  39 to end on 110
# In model 23 Mapped arrow 82  that ended on  39 to end on 110
# In model 23 Mapped arrow 91  that ended on  39 to end on 110
# In model 23 Mapped arrow 95  that ended on  39 to end on 110
# Added expanded arrow  110 to model 23 relating 17 to 11
# In model 23 Mapped arrow 48  that ended on  40 to end on 111
# In model 23 Mapped arrow 81  that ended on  40 to end on 111
# In model 23 Mapped arrow 90  that ended on  40 to end on 111
# In model 23 Mapped arrow 94  that ended on  40 to end on 111
# Added expanded arrow  111 to model 23 relating 17 to 12
# In model 23 Mapped arrow 50  that ended on  43 to end on 112
# In model 23 Mapped arrow 73  that ended on  43 to end on 112
# In model 23 Mapped arrow 92  that ended on  43 to end on 112
# In model 23 Mapped arrow 96  that ended on  43 to end on 112
# Added expanded arrow  112 to model 23 relating 17 to 19
# In model 23 Mapped arrow 49  that ended on  39 to end on 113
# In model 23 Mapped arrow 82  that ended on  39 to end on 113
# In model 23 Mapped arrow 91  that ended on  39 to end on 113
# In model 23 Mapped arrow 95  that ended on  39 to end on 113
# Added expanded arrow  113 to model 23 relating 3 to 11
# In model 23 Mapped arrow 48  that ended on  40 to end on 114
# In model 23 Mapped arrow 81  that ended on  40 to end on 114
# In model 23 Mapped arrow 90  that ended on  40 to end on 114
# In model 23 Mapped arrow 94  that ended on  40 to end on 114
# Added expanded arrow  114 to model 23 relating 3 to 12
# In model 23 Mapped arrow 50  that ended on  43 to end on 115
# In model 23 Mapped arrow 73  that ended on  43 to end on 115
# In model 23 Mapped arrow 92  that ended on  43 to end on 115
# In model 23 Mapped arrow 96  that ended on  43 to end on 115
# Added expanded arrow  115 to model 23 relating 3 to 19
# Processing theory 23
# Added expanded arrow  116 to model 23 relating 14 to 16
# Added expanded arrow  117 to model 23 relating 15 to 16
# Processing theory 24
# Added expanded arrow  90 to model 24 relating 14 to 7
# Added expanded arrow  91 to model 24 relating 13 to 7
# Added expanded arrow  92 to model 24 relating 12 to 7
# Processing theory 24
# Added expanded arrow  93 to model 24 relating 10 to 6
# Added expanded arrow  94 to model 24 relating 9 to 6
# Processing theory 24
# Added expanded arrow  95 to model 24 relating 23 to 24
# Added expanded arrow  96 to model 24 relating 22 to 24
# Added expanded arrow  97 to model 24 relating 21 to 24
# Processing theory 24
# Added expanded arrow  98 to model 24 relating 32 to 27
# Added expanded arrow  99 to model 24 relating 11 to 27
# Added expanded arrow  100 to model 24 relating 6 to 27
# Added expanded arrow  101 to model 24 relating 7 to 27
# Processing theory 24
# Added expanded arrow  102 to model 24 relating 19 to 18
# Added expanded arrow  103 to model 24 relating 26 to 18
# Processing theory 24
# Added expanded arrow  104 to model 24 relating 33 to 28
# Added expanded arrow  105 to model 24 relating 34 to 28
# Added expanded arrow  106 to model 24 relating 24 to 28
# Added expanded arrow  107 to model 24 relating 18 to 28
# Added expanded arrow  108 to model 24 relating 5 to 28
# Added expanded arrow  109 to model 24 relating 8 to 28
# Processing theory 24
# Added expanded arrow  110 to model 24 relating 11 to 3
# Added expanded arrow  111 to model 24 relating 8 to 3
# Added expanded arrow  112 to model 24 relating 5 to 3
# Processing theory 25
# Added expanded arrow  80 to model 25 relating 9 to 8
# Added expanded arrow  81 to model 25 relating 10 to 8
# Processing theory 25
# Added expanded arrow  82 to model 25 relating 13 to 53
# Added expanded arrow  83 to model 25 relating 13 to 54
# Added expanded arrow  84 to model 25 relating 13 to 50
# Added expanded arrow  85 to model 25 relating 13 to 51
# Added expanded arrow  86 to model 25 relating 13 to 52
# Added expanded arrow  87 to model 25 relating 13 to 55
# Added expanded arrow  88 to model 25 relating 8 to 53
# Added expanded arrow  89 to model 25 relating 8 to 54
# Added expanded arrow  90 to model 25 relating 8 to 50
# Added expanded arrow  91 to model 25 relating 8 to 51
# Added expanded arrow  92 to model 25 relating 8 to 52
# Added expanded arrow  93 to model 25 relating 8 to 55
# Processing theory 25
# Added expanded arrow  94 to model 25 relating 25 to 21
# Added expanded arrow  95 to model 25 relating 23 to 21
# Added expanded arrow  96 to model 25 relating 24 to 21
# Processing theory 25
# Added expanded arrow  97 to model 25 relating 4 to 3
# Added expanded arrow  98 to model 25 relating 5 to 3
# Added expanded arrow  99 to model 25 relating 7 to 3
# Added expanded arrow  100 to model 25 relating 6 to 3
# Processing theory 26
# Added expanded arrow  51 to model 26 relating 4 to 3
# Added expanded arrow  52 to model 26 relating 5 to 3
# Added expanded arrow  53 to model 26 relating 6 to 3
# Added expanded arrow  54 to model 26 relating 7 to 3
# Processing theory 26
# Added expanded arrow  55 to model 26 relating 10 to 9
# Added expanded arrow  56 to model 26 relating 13 to 9
# Added expanded arrow  57 to model 26 relating 12 to 9
# Added expanded arrow  58 to model 26 relating 11 to 9
# Processing theory 26
# Added expanded arrow  59 to model 26 relating 14 to 13
# Processing theory 26
# Added expanded arrow  60 to model 26 relating 9 to 21
# Added expanded arrow  61 to model 26 relating 3 to 21
# Processing theory 28
# Added expanded arrow  68 to model 28 relating 13 to 3
# Added expanded arrow  69 to model 28 relating 15 to 3
# Added expanded arrow  70 to model 28 relating 14 to 3
# Processing theory 28
# Added expanded arrow  71 to model 28 relating 4 to 20
# Added expanded arrow  72 to model 28 relating 5 to 20
# Added expanded arrow  73 to model 28 relating 6 to 20
# Added expanded arrow  74 to model 28 relating 10 to 20
# Added expanded arrow  75 to model 28 relating 7 to 20
# Added expanded arrow  76 to model 28 relating 8 to 20
# Added expanded arrow  77 to model 28 relating 9 to 20
# Processing theory 28
# Added expanded arrow  78 to model 28 relating 17 to 10
# Added expanded arrow  79 to model 28 relating 18 to 10
# Added expanded arrow  80 to model 28 relating 19 to 10
# Processing theory 28
# Added expanded arrow  81 to model 28 relating 23 to 7
# Added expanded arrow  82 to model 28 relating 22 to 7
# Added expanded arrow  83 to model 28 relating 24 to 7
# Processing theory 29
# Added expanded arrow  112 to model 29 relating 4 to 3
# Added expanded arrow  113 to model 29 relating 5 to 3
# Added expanded arrow  114 to model 29 relating 6 to 3
# Added expanded arrow  115 to model 29 relating 7 to 3
# Processing theory 29
# Added expanded arrow  116 to model 29 relating 10 to 9
# Added expanded arrow  117 to model 29 relating 11 to 9
# Added expanded arrow  118 to model 29 relating 12 to 9
# Added expanded arrow  119 to model 29 relating 48 to 9
# Processing theory 29
# Added expanded arrow  120 to model 29 relating 15 to 14
# Added expanded arrow  121 to model 29 relating 17 to 14
# Added expanded arrow  122 to model 29 relating 16 to 14
# Added expanded arrow  123 to model 29 relating 47 to 14
# Processing theory 29
# Added expanded arrow  124 to model 29 relating 24 to 21
# Added expanded arrow  125 to model 29 relating 25 to 21
# Added expanded arrow  126 to model 29 relating 26 to 21
# Processing theory 29
# Added expanded arrow  127 to model 29 relating 20 to 19
# Added expanded arrow  128 to model 29 relating 21 to 19
# Added expanded arrow  129 to model 29 relating 22 to 19
# Processing theory 29
# Added expanded arrow  130 to model 29 relating 28 to 20
# Processing theory 29
# Added expanded arrow  131 to model 29 relating 30 to 22
# Added expanded arrow  132 to model 29 relating 31 to 22
# Added expanded arrow  133 to model 29 relating 32 to 22
# Added expanded arrow  134 to model 29 relating 33 to 22
# Processing theory 29
# Added expanded arrow  135 to model 29 relating 38 to 36
# Added expanded arrow  136 to model 29 relating 39 to 36
# Processing theory 29
# Added expanded arrow  137 to model 29 relating 43 to 41
# Added expanded arrow  138 to model 29 relating 44 to 41
# Processing theory 29
# Added expanded arrow  139 to model 29 relating 46 to 43
# Added expanded arrow  140 to model 29 relating 49 to 43
# Added expanded arrow  141 to model 29 relating 50 to 43
# Processing theory 3
# Added expanded arrow  62 to model 3 relating 21 to 20
# Added expanded arrow  63 to model 3 relating 22 to 20
# Processing theory 3
# Added expanded arrow  64 to model 3 relating 8 to 24
# Added expanded arrow  65 to model 3 relating 7 to 24
# Processing theory 3
# Added expanded arrow  66 to model 3 relating 16 to 26
# Added expanded arrow  67 to model 3 relating 14 to 26
# Added expanded arrow  68 to model 3 relating 15 to 26
# Processing theory 31
# Added expanded arrow  75 to model 31 relating 4 to 6
# Added expanded arrow  76 to model 31 relating 3 to 6
# Processing theory 31
# Added expanded arrow  77 to model 31 relating 6 to 7
# Processing theory 31
# Added expanded arrow  78 to model 31 relating 9 to 12
# Added expanded arrow  79 to model 31 relating 10 to 12
# Processing theory 31
# Added expanded arrow  80 to model 31 relating 14 to 34
# Added expanded arrow  81 to model 31 relating 15 to 34
# Processing theory 31
# Added expanded arrow  82 to model 31 relating 32 to 28
# Added expanded arrow  83 to model 31 relating 33 to 28
# Added expanded arrow  84 to model 31 relating 30 to 28
# Added expanded arrow  85 to model 31 relating 31 to 28
# Processing theory 31
# Added expanded arrow  86 to model 31 relating 18 to 23
# Added expanded arrow  87 to model 31 relating 19 to 23
# Added expanded arrow  88 to model 31 relating 20 to 23
# Added expanded arrow  89 to model 31 relating 22 to 23
# Added expanded arrow  90 to model 31 relating 21 to 23
# Processing theory 32
# Added expanded arrow  44 to model 32 relating 8 to 3
# Added expanded arrow  45 to model 32 relating 9 to 3
# Added expanded arrow  46 to model 32 relating 10 to 3
# Processing theory 32
# Added expanded arrow  47 to model 32 relating 18 to 4
# Added expanded arrow  48 to model 32 relating 17 to 4
# Added expanded arrow  49 to model 32 relating 19 to 4
# Processing theory 32
# Added expanded arrow  50 to model 32 relating 14 to 12
# Added expanded arrow  51 to model 32 relating 15 to 12
# Processing theory 33
# Sources to be mapped:  {'12': '71'}
# Added expanded arrow  88 to model 33 relating 8 to 3
# Added expanded arrow  89 to model 33 relating 7 to 3
# Added expanded arrow  90 to model 33 relating 6 to 3
# Added expanded arrow  91 to model 33 relating 15 to 3
# Added expanded arrow  92 to model 33 relating 14 to 3
# Added expanded arrow  93 to model 33 relating 11 to 3
# Added expanded arrow  94 to model 33 relating 10 to 3
# Added expanded arrow  95 to model 33 relating 5 to 3
# In model 33 Mapped arrow 72  that ended on  71 to end on 96
# Added expanded arrow  96 to model 33 relating 12 to 3
# Added expanded arrow  97 to model 33 relating 13 to 3
# Processing theory 33
# Added expanded arrow  98 to model 33 relating 28 to 18
# Added expanded arrow  99 to model 33 relating 16 to 18
# Added expanded arrow  100 to model 33 relating 17 to 18
# Added expanded arrow  101 to model 33 relating 23 to 18
# Processing theory 33
# Added expanded arrow  102 to model 33 relating 20 to 23
# Added expanded arrow  103 to model 33 relating 22 to 23
# Added expanded arrow  104 to model 33 relating 21 to 23
# Processing theory 33
# Added expanded arrow  105 to model 33 relating 25 to 28
# Added expanded arrow  106 to model 33 relating 26 to 28
# Processing theory 34
# Added expanded arrow  50 to model 34 relating 9 to 3
# Added expanded arrow  51 to model 34 relating 8 to 3
# Added expanded arrow  52 to model 34 relating 6 to 3
# Added expanded arrow  53 to model 34 relating 7 to 3
# Processing theory 34
# Added expanded arrow  54 to model 34 relating 19 to 20
# Added expanded arrow  55 to model 34 relating 18 to 20
# Added expanded arrow  56 to model 34 relating 17 to 20
# Added expanded arrow  57 to model 34 relating 16 to 20
# Added expanded arrow  58 to model 34 relating 15 to 20
# Added expanded arrow  59 to model 34 relating 14 to 20
# Processing theory 34
# Added expanded arrow  60 to model 34 relating 12 to 13
# Added expanded arrow  61 to model 34 relating 11 to 13
# Added expanded arrow  62 to model 34 relating 10 to 13
# Processing theory 35
# Added expanded arrow  46 to model 35 relating 4 to 3
# Added expanded arrow  47 to model 35 relating 5 to 3
# Added expanded arrow  48 to model 35 relating 6 to 3
# Added expanded arrow  49 to model 35 relating 7 to 3
# Processing theory 35
# Added expanded arrow  50 to model 35 relating 10 to 9
# Added expanded arrow  51 to model 35 relating 11 to 9
# Added expanded arrow  52 to model 35 relating 12 to 9
# Processing theory 35
# Added expanded arrow  53 to model 35 relating 22 to 15
# Added expanded arrow  54 to model 35 relating 23 to 15
# Processing theory 39
# Added expanded arrow  75 to model 39 relating 3 to 21
# Added expanded arrow  76 to model 39 relating 4 to 21
# Processing theory 39
# Added expanded arrow  77 to model 39 relating 5 to 23
# Added expanded arrow  78 to model 39 relating 6 to 23
# Added expanded arrow  79 to model 39 relating 7 to 23
# Processing theory 39
# Added expanded arrow  80 to model 39 relating 10 to 14
# Added expanded arrow  81 to model 39 relating 11 to 14
# Processing theory 39
# Added expanded arrow  82 to model 39 relating 10 to 26
# Added expanded arrow  83 to model 39 relating 13 to 26
# Added expanded arrow  84 to model 39 relating 12 to 26
# Added expanded arrow  85 to model 39 relating 9 to 26
# Added expanded arrow  86 to model 39 relating 8 to 26
# Processing theory 39
# Added expanded arrow  87 to model 39 relating 26 to 28
# Added expanded arrow  88 to model 39 relating 11 to 28
# Added expanded arrow  89 to model 39 relating 16 to 28
# Added expanded arrow  90 to model 39 relating 17 to 28
# Added expanded arrow  91 to model 39 relating 18 to 28
# Added expanded arrow  92 to model 39 relating 19 to 28
# Processing theory 4
# Added expanded arrow  99 to model 4 relating 15 to 3
# Added expanded arrow  100 to model 4 relating 13 to 3
# Added expanded arrow  101 to model 4 relating 12 to 3
# Added expanded arrow  102 to model 4 relating 9 to 3
# Added expanded arrow  103 to model 4 relating 6 to 3
# Added expanded arrow  104 to model 4 relating 8 to 3
# Added expanded arrow  105 to model 4 relating 11 to 3
# Added expanded arrow  106 to model 4 relating 7 to 3
# Added expanded arrow  107 to model 4 relating 4 to 3
# Added expanded arrow  108 to model 4 relating 5 to 3
# Added expanded arrow  109 to model 4 relating 10 to 3
# Added expanded arrow  110 to model 4 relating 14 to 3
# Processing theory 4
# Added expanded arrow  111 to model 4 relating 22 to 21
# Added expanded arrow  112 to model 4 relating 23 to 21
# Added expanded arrow  113 to model 4 relating 24 to 21
# Added expanded arrow  114 to model 4 relating 25 to 21
# Added expanded arrow  115 to model 4 relating 26 to 21
# Added expanded arrow  116 to model 4 relating 27 to 21
# Added expanded arrow  117 to model 4 relating 28 to 21
# Added expanded arrow  118 to model 4 relating 29 to 21
# Added expanded arrow  119 to model 4 relating 14 to 21
# Processing theory 4
# Added expanded arrow  120 to model 4 relating 30 to 29
# Added expanded arrow  121 to model 4 relating 31 to 29
# Processing theory 4
# Added expanded arrow  122 to model 4 relating 16 to 15
# Added expanded arrow  123 to model 4 relating 18 to 15
# Added expanded arrow  124 to model 4 relating 17 to 15
# Processing theory 40
# Added expanded arrow  18 to model 40 relating 6 to 4
# Added expanded arrow  19 to model 40 relating 7 to 4
# Processing theory 41
# Added expanded arrow  91 to model 41 relating 4 to 3
# Added expanded arrow  92 to model 41 relating 5 to 3
# Added expanded arrow  93 to model 41 relating 6 to 3
# Added expanded arrow  94 to model 41 relating 7 to 3
# Added expanded arrow  95 to model 41 relating 8 to 3
# Processing theory 41
# Added expanded arrow  96 to model 41 relating 20 to 10
# Added expanded arrow  97 to model 41 relating 13 to 10
# Added expanded arrow  98 to model 41 relating 11 to 10
# Added expanded arrow  99 to model 41 relating 12 to 10
# Added expanded arrow  100 to model 41 relating 19 to 10
# Added expanded arrow  101 to model 41 relating 16 to 10
# Added expanded arrow  102 to model 41 relating 14 to 10
# Added expanded arrow  103 to model 41 relating 21 to 10
# Added expanded arrow  104 to model 41 relating 15 to 10
# Added expanded arrow  105 to model 41 relating 17 to 10
# Added expanded arrow  106 to model 41 relating 18 to 10
# Added expanded arrow  107 to model 41 relating 22 to 10
# Added expanded arrow  108 to model 41 relating 23 to 10
# Added expanded arrow  109 to model 41 relating 24 to 10
# Added expanded arrow  110 to model 41 relating 25 to 10
# Processing theory 41
# Added expanded arrow  111 to model 41 relating 28 to 27
# Added expanded arrow  112 to model 41 relating 29 to 27
# Added expanded arrow  113 to model 41 relating 30 to 27
# Processing theory 41
# Added expanded arrow  114 to model 41 relating 38 to 32
# Added expanded arrow  115 to model 41 relating 37 to 32
# Added expanded arrow  116 to model 41 relating 36 to 32
# Added expanded arrow  117 to model 41 relating 35 to 32
# Added expanded arrow  118 to model 41 relating 34 to 32
# Processing theory 42
# Added expanded arrow  73 to model 42 relating 4 to 3
# Added expanded arrow  74 to model 42 relating 5 to 3
# Added expanded arrow  75 to model 42 relating 6 to 3
# Added expanded arrow  76 to model 42 relating 29 to 3
# Processing theory 42
# Added expanded arrow  77 to model 42 relating 13 to 12
# Added expanded arrow  78 to model 42 relating 26 to 12
# Processing theory 42
# Added expanded arrow  79 to model 42 relating 21 to 13
# Processing theory 42
# Added expanded arrow  80 to model 42 relating 25 to 21
# Added expanded arrow  81 to model 42 relating 27 to 21
# Added expanded arrow  82 to model 42 relating 23 to 21
# Added expanded arrow  83 to model 42 relating 24 to 21
# Processing theory 42
# Added expanded arrow  84 to model 42 relating 16 to 26
# Added expanded arrow  85 to model 42 relating 15 to 26
# Added expanded arrow  86 to model 42 relating 14 to 26
# Processing theory 42
# Added expanded arrow  87 to model 42 relating 11 to 30
# Added expanded arrow  88 to model 42 relating 10 to 30
# Processing theory 43
# Added expanded arrow  70 to model 43 relating 10 to 11
# Added expanded arrow  71 to model 43 relating 26 to 11
# Added expanded arrow  72 to model 43 relating 29 to 11
# Added expanded arrow  73 to model 43 relating 32 to 11
# Added expanded arrow  74 to model 43 relating 28 to 11
# Added expanded arrow  75 to model 43 relating 27 to 11
# Processing theory 43
# Added expanded arrow  76 to model 43 relating 12 to 34
# Added expanded arrow  77 to model 43 relating 20 to 34
# Processing theory 43
# Added expanded arrow  78 to model 43 relating 13 to 35
# Added expanded arrow  79 to model 43 relating 23 to 35
# Processing theory 43
# Added expanded arrow  80 to model 43 relating 3 to 10
# Added expanded arrow  81 to model 43 relating 4 to 10
# Processing theory 43
# Added expanded arrow  82 to model 43 relating 9 to 4
# Added expanded arrow  83 to model 43 relating 7 to 4
# Added expanded arrow  84 to model 43 relating 8 to 4
# Added expanded arrow  85 to model 43 relating 6 to 4
# Added expanded arrow  86 to model 43 relating 5 to 4
# Processing theory 45
# Targets to be mapped:  {'6': '28'}
# In model 45 Mapped arrow 34  that ended on  28 to end on 50
# Added expanded arrow  50 to model 45 relating 3 to 6
# In model 45 Mapped arrow 34  that ended on  28 to end on 51
# Added expanded arrow  51 to model 45 relating 4 to 6
# Processing theory 45
# Added expanded arrow  52 to model 45 relating 7 to 3
# Added expanded arrow  53 to model 45 relating 8 to 3
# Added expanded arrow  54 to model 45 relating 9 to 3
# Processing theory 45
# Added expanded arrow  55 to model 45 relating 11 to 51
# Added expanded arrow  56 to model 45 relating 13 to 51
# Processing theory 45
# Added expanded arrow  57 to model 45 relating 15 to 4
# Processing theory 45
# Added expanded arrow  58 to model 45 relating 18 to 16
# Added expanded arrow  59 to model 45 relating 19 to 16
# Added expanded arrow  60 to model 45 relating 20 to 16
# Added expanded arrow  61 to model 45 relating 21 to 16
# Added expanded arrow  62 to model 45 relating 22 to 16
# Processing theory 45
# Added expanded arrow  63 to model 45 relating 16 to 6
# Processing theory 47
# Added expanded arrow  41 to model 47 relating 3 to 11
# Added expanded arrow  42 to model 47 relating 4 to 11
# Added expanded arrow  43 to model 47 relating 5 to 11
# Added expanded arrow  44 to model 47 relating 6 to 11
# Processing theory 47
# Added expanded arrow  45 to model 47 relating 7 to 12
# Added expanded arrow  46 to model 47 relating 8 to 12
# Added expanded arrow  47 to model 47 relating 9 to 12
# Added expanded arrow  48 to model 47 relating 10 to 12
# Processing theory 47
# Added expanded arrow  49 to model 47 relating 17 to 18
# Added expanded arrow  50 to model 47 relating 16 to 18
# Added expanded arrow  51 to model 47 relating 15 to 18
# Processing theory 48
# Added expanded arrow  55 to model 48 relating 20 to 18
# Added expanded arrow  56 to model 48 relating 15 to 18
# Added expanded arrow  57 to model 48 relating 16 to 18
# Processing theory 48
# Added expanded arrow  58 to model 48 relating 14 to 20
# Added expanded arrow  59 to model 48 relating 3 to 20
# Processing theory 48
# Added expanded arrow  60 to model 48 relating 5 to 22
# Added expanded arrow  61 to model 48 relating 9 to 22
# Added expanded arrow  62 to model 48 relating 10 to 22
# Added expanded arrow  63 to model 48 relating 8 to 22
# Added expanded arrow  64 to model 48 relating 7 to 22
# Added expanded arrow  65 to model 48 relating 6 to 22
# Added expanded arrow  66 to model 48 relating 20 to 22
# Added expanded arrow  67 to model 48 relating 4 to 22
# Added expanded arrow  68 to model 48 relating 26 to 22
# Processing theory 48
# Added expanded arrow  69 to model 48 relating 11 to 13
# Added expanded arrow  70 to model 48 relating 12 to 13
# Processing theory 48
# Added expanded arrow  71 to model 48 relating 11 to 24
# Added expanded arrow  72 to model 48 relating 12 to 24
# Processing theory 49
# Added expanded arrow  63 to model 49 relating 5 to 3
# Added expanded arrow  64 to model 49 relating 6 to 3
# Processing theory 49
# Added expanded arrow  65 to model 49 relating 8 to 5
# Added expanded arrow  66 to model 49 relating 9 to 5
# Processing theory 49
# Added expanded arrow  67 to model 49 relating 11 to 6
# Added expanded arrow  68 to model 49 relating 12 to 6
# Added expanded arrow  69 to model 49 relating 13 to 6
# Added expanded arrow  70 to model 49 relating 14 to 6
# Processing theory 49
# Added expanded arrow  71 to model 49 relating 18 to 15
# Added expanded arrow  72 to model 49 relating 17 to 15
# Added expanded arrow  73 to model 49 relating 29 to 15
# Processing theory 49
# Added expanded arrow  74 to model 49 relating 19 to 29
# Added expanded arrow  75 to model 49 relating 20 to 29
# Processing theory 49
# Added expanded arrow  76 to model 49 relating 23 to 21
# Added expanded arrow  77 to model 49 relating 24 to 21
# Processing theory 49
# Added expanded arrow  78 to model 49 relating 21 to 16
# Added expanded arrow  79 to model 49 relating 22 to 16
# Processing theory 50
# Added expanded arrow  39 to model 50 relating 3 to 12
# Added expanded arrow  40 to model 50 relating 4 to 12
# Added expanded arrow  41 to model 50 relating 8 to 12
# Processing theory 50
# Added expanded arrow  42 to model 50 relating 10 to 11
# Added expanded arrow  43 to model 50 relating 5 to 11
# Added expanded arrow  44 to model 50 relating 9 to 11
# Processing theory 51
# Added expanded arrow  67 to model 51 relating 12 to 5
# Added expanded arrow  68 to model 51 relating 13 to 5
# Processing theory 51
# Added expanded arrow  69 to model 51 relating 15 to 20
# Added expanded arrow  70 to model 51 relating 16 to 20
# Processing theory 51
# Added expanded arrow  71 to model 51 relating 6 to 5
# Added expanded arrow  72 to model 51 relating 4 to 5
# Processing theory 51
# Added expanded arrow  73 to model 51 relating 21 to 8
# Processing theory 51
# Added expanded arrow  74 to model 51 relating 20 to 26
# Processing theory 51
# Added expanded arrow  75 to model 51 relating 11 to 30
# Processing theory 51
# Added expanded arrow  76 to model 51 relating 26 to 5
# Added expanded arrow  77 to model 51 relating 30 to 5
# Processing theory 52
# Added expanded arrow  67 to model 52 relating 11 to 28
# Added expanded arrow  68 to model 52 relating 4 to 28
# Processing theory 52
# Added expanded arrow  69 to model 52 relating 9 to 8
# Added expanded arrow  70 to model 52 relating 10 to 8
# Processing theory 52
# Added expanded arrow  71 to model 52 relating 7 to 4
# Added expanded arrow  72 to model 52 relating 7 to 6
# Added expanded arrow  73 to model 52 relating 5 to 4
# Added expanded arrow  74 to model 52 relating 5 to 6
# Added expanded arrow  75 to model 52 relating 3 to 4
# Added expanded arrow  76 to model 52 relating 3 to 6
# Processing theory 52
# Added expanded arrow  77 to model 52 relating 12 to 11
# Added expanded arrow  78 to model 52 relating 17 to 11
# Added expanded arrow  79 to model 52 relating 28 to 11
# Processing theory 53
# Added expanded arrow  50 to model 53 relating 14 to 15
# Added expanded arrow  51 to model 53 relating 13 to 15
# Processing theory 53
# Added expanded arrow  52 to model 53 relating 11 to 12
# Added expanded arrow  53 to model 53 relating 10 to 12
# Processing theory 53
# Added expanded arrow  54 to model 53 relating 15 to 9
# Added expanded arrow  55 to model 53 relating 12 to 9
# Processing theory 53
# Added expanded arrow  56 to model 53 relating 12 to 3
# Added expanded arrow  57 to model 53 relating 15 to 3
# Added expanded arrow  58 to model 53 relating 6 to 3
# Added expanded arrow  59 to model 53 relating 19 to 3
# Added expanded arrow  60 to model 53 relating 5 to 3
# Added expanded arrow  61 to model 53 relating 7 to 3
# Added expanded arrow  62 to model 53 relating 8 to 3
# Added expanded arrow  63 to model 53 relating 9 to 3
# Processing theory 54
# Added expanded arrow  76 to model 54 relating 7 to 4
# Added expanded arrow  77 to model 54 relating 5 to 4
# Added expanded arrow  78 to model 54 relating 6 to 4
# Added expanded arrow  79 to model 54 relating 8 to 4
# Processing theory 54
# Added expanded arrow  80 to model 54 relating 9 to 11
# Added expanded arrow  81 to model 54 relating 7 to 11
# Processing theory 54
# Targets to be mapped:  {'12': '60'}
# In model 54 Mapped arrow 65  that ended on  60 to end on 82
# Added expanded arrow  82 to model 54 relating 11 to 12
# In model 54 Mapped arrow 65  that ended on  60 to end on 83
# Added expanded arrow  83 to model 54 relating 4 to 12
# Processing theory 54
# Added expanded arrow  84 to model 54 relating 15 to 5
# Added expanded arrow  85 to model 54 relating 16 to 5
# Added expanded arrow  86 to model 54 relating 18 to 5
# Added expanded arrow  87 to model 54 relating 17 to 5
# Added expanded arrow  88 to model 54 relating 22 to 5
# Processing theory 54
# Added expanded arrow  89 to model 54 relating 20 to 8
# Added expanded arrow  90 to model 54 relating 21 to 8
# Processing theory 54
# Added expanded arrow  91 to model 54 relating 22 to 23
# Processing theory 54
# Added expanded arrow  92 to model 54 relating 28 to 9
# Added expanded arrow  93 to model 54 relating 26 to 9
# Added expanded arrow  94 to model 54 relating 27 to 9
# Processing theory 55
# Added expanded arrow  28 to model 55 relating 11 to 9
# Added expanded arrow  29 to model 55 relating 13 to 9
# Added expanded arrow  30 to model 55 relating 12 to 9
# Processing theory 55
# Added expanded arrow  31 to model 55 relating 11 to 9
# Added expanded arrow  32 to model 55 relating 13 to 9
# Added expanded arrow  33 to model 55 relating 12 to 9
# Processing theory 56
# Added expanded arrow  71 to model 56 relating 18 to 19
# Added expanded arrow  72 to model 56 relating 21 to 19
# Added expanded arrow  73 to model 56 relating 17 to 19
# Added expanded arrow  74 to model 56 relating 26 to 19
# Added expanded arrow  75 to model 56 relating 27 to 19
# Processing theory 56
# Added expanded arrow  76 to model 56 relating 5 to 3
# Added expanded arrow  77 to model 56 relating 4 to 3
# Added expanded arrow  78 to model 56 relating 6 to 3
# Processing theory 56
# Added expanded arrow  79 to model 56 relating 14 to 26
# Added expanded arrow  80 to model 56 relating 13 to 26
# Added expanded arrow  81 to model 56 relating 12 to 26
# Processing theory 56
# Added expanded arrow  82 to model 56 relating 15 to 27
# Added expanded arrow  83 to model 56 relating 11 to 27
# Processing theory 56
# Added expanded arrow  84 to model 56 relating 7 to 22
# Added expanded arrow  85 to model 56 relating 25 to 22
# Processing theory 57
# Added expanded arrow  98 to model 57 relating 5 to 3
# Added expanded arrow  99 to model 57 relating 6 to 3
# Added expanded arrow  100 to model 57 relating 7 to 3
# Added expanded arrow  101 to model 57 relating 8 to 3
# Processing theory 57
# Added expanded arrow  102 to model 57 relating 11 to 9
# Added expanded arrow  103 to model 57 relating 12 to 9
# Added expanded arrow  104 to model 57 relating 13 to 9
# Added expanded arrow  105 to model 57 relating 14 to 9
# Added expanded arrow  106 to model 57 relating 15 to 9
# Added expanded arrow  107 to model 57 relating 16 to 9
# Added expanded arrow  108 to model 57 relating 17 to 9
# Added expanded arrow  109 to model 57 relating 18 to 9
# Added expanded arrow  110 to model 57 relating 19 to 9
# Added expanded arrow  111 to model 57 relating 20 to 9
# Added expanded arrow  112 to model 57 relating 21 to 9
# Added expanded arrow  113 to model 57 relating 22 to 9
# Added expanded arrow  114 to model 57 relating 23 to 9
# Added expanded arrow  115 to model 57 relating 24 to 9
# Processing theory 57
# Added expanded arrow  116 to model 57 relating 26 to 25
# Added expanded arrow  117 to model 57 relating 27 to 25
# Added expanded arrow  118 to model 57 relating 28 to 25
# Processing theory 57
# Added expanded arrow  119 to model 57 relating 33 to 32
# Added expanded arrow  120 to model 57 relating 34 to 32
# Processing theory 57
# Added expanded arrow  121 to model 57 relating 38 to 37
# Added expanded arrow  122 to model 57 relating 40 to 37
# Added expanded arrow  123 to model 57 relating 39 to 37
# Processing theory 58
# Added expanded arrow  68 to model 58 relating 15 to 16
# Added expanded arrow  69 to model 58 relating 14 to 16
# Processing theory 58
# Added expanded arrow  70 to model 58 relating 15 to 8
# Added expanded arrow  71 to model 58 relating 14 to 8
# Processing theory 58
# Added expanded arrow  72 to model 58 relating 10 to 11
# Added expanded arrow  73 to model 58 relating 9 to 11
# Processing theory 58
# Added expanded arrow  74 to model 58 relating 12 to 13
# Added expanded arrow  75 to model 58 relating 11 to 13
# Processing theory 58
# Added expanded arrow  76 to model 58 relating 19 to 20
# Added expanded arrow  77 to model 58 relating 17 to 20
# Added expanded arrow  78 to model 58 relating 18 to 20
# Added expanded arrow  79 to model 58 relating 16 to 20
# Added expanded arrow  80 to model 58 relating 8 to 20
# Added expanded arrow  81 to model 58 relating 13 to 20
# Processing theory 58
# Added expanded arrow  82 to model 58 relating 20 to 7
# Processing theory 58
# Added expanded arrow  83 to model 58 relating 7 to 5
# Added expanded arrow  84 to model 58 relating 6 to 5
# Processing theory 58
# Added expanded arrow  85 to model 58 relating 5 to 3
# Added expanded arrow  86 to model 58 relating 22 to 3
# Added expanded arrow  87 to model 58 relating 21 to 3
# Processing theory 59
# Added expanded arrow  60 to model 59 relating 21 to 22
# Added expanded arrow  61 to model 59 relating 20 to 22
# Processing theory 59
# Added expanded arrow  62 to model 59 relating 9 to 24
# Added expanded arrow  63 to model 59 relating 17 to 24
# Processing theory 6
# Added expanded arrow  21 to model 6 relating 3 to 11
# Added expanded arrow  22 to model 6 relating 3 to 12
# Added expanded arrow  23 to model 6 relating 3 to 13
# Added expanded arrow  24 to model 6 relating 4 to 11
# Added expanded arrow  25 to model 6 relating 4 to 12
# ...
# Added expanded arrow  56 to model 65 relating 8 to 4
# Added expanded arrow  57 to model 65 relating 6 to 4
# Added expanded arrow  58 to model 65 relating 7 to 4
# Processing theory 65
# Added expanded arrow  59 to model 65 relating 10 to 9
# Added expanded arrow  60 to model 65 relating 11 to 9
# Added expanded arrow  61 to model 65 relating 13 to 9
# Processing theory 65
# Added expanded arrow  62 to model 65 relating 17 to 21
# Added expanded arrow  63 to model 65 relating 18 to 21
# Added expanded arrow  64 to model 65 relating 19 to 21
# Added expanded arrow  65 to model 65 relating 22 to 21
# Processing theory 65
# Added expanded arrow  66 to model 65 relating 14 to 24
# Added expanded arrow  67 to model 65 relating 15 to 24
# Added expanded arrow  68 to model 65 relating 16 to 24
# Processing theory 65
# Added expanded arrow  69 to model 65 relating 8 to 4
# Added expanded arrow  70 to model 65 relating 6 to 4
# Added expanded arrow  71 to model 65 relating 7 to 4
# Processing theory 65
# Added expanded arrow  72 to model 65 relating 10 to 9
# Added expanded arrow  73 to model 65 relating 11 to 9
# Added expanded arrow  74 to model 65 relating 13 to 9
# Processing theory 65
# Added expanded arrow  75 to model 65 relating 17 to 21
# Added expanded arrow  76 to model 65 relating 18 to 21
# Added expanded arrow  77 to model 65 relating 19 to 21
# Added expanded arrow  78 to model 65 relating 22 to 21
# Processing theory 65
# Added expanded arrow  79 to model 65 relating 14 to 24
# Added expanded arrow  80 to model 65 relating 15 to 24
# Added expanded arrow  81 to model 65 relating 16 to 24
# Processing theory 66
# Added expanded arrow  86 to model 66 relating 12 to 11
# Added expanded arrow  87 to model 66 relating 13 to 11
# Added expanded arrow  88 to model 66 relating 14 to 11
# Processing theory 66
# Added expanded arrow  89 to model 66 relating 40 to 28
# Added expanded arrow  90 to model 66 relating 4 to 28
# Added expanded arrow  91 to model 66 relating 5 to 28
# Processing theory 66
# Added expanded arrow  92 to model 66 relating 9 to 29
# Added expanded arrow  93 to model 66 relating 10 to 29
# Added expanded arrow  94 to model 66 relating 25 to 29
# Processing theory 66
# Added expanded arrow  95 to model 66 relating 26 to 32
# Added expanded arrow  96 to model 66 relating 27 to 32
# Processing theory 66
# Added expanded arrow  97 to model 66 relating 6 to 3
# Processing theory 66
# Added expanded arrow  98 to model 66 relating 7 to 4
# Processing theory 66
# Added expanded arrow  99 to model 66 relating 8 to 5
# Processing theory 66
# Added expanded arrow  100 to model 66 relating 18 to 14
# Added expanded arrow  101 to model 66 relating 17 to 14
# Added expanded arrow  102 to model 66 relating 16 to 14
# Added expanded arrow  103 to model 66 relating 15 to 14
# Processing theory 66
# Added expanded arrow  104 to model 66 relating 22 to 13
# Added expanded arrow  105 to model 66 relating 21 to 13
# Added expanded arrow  106 to model 66 relating 20 to 13
# Processing theory 66
# Added expanded arrow  107 to model 66 relating 23 to 12
# Added expanded arrow  108 to model 66 relating 24 to 12
# Processing theory 67
# Added expanded arrow  51 to model 67 relating 17 to 16
# Added expanded arrow  52 to model 67 relating 18 to 16
# Added expanded arrow  53 to model 67 relating 19 to 16
# Processing theory 67
# Added expanded arrow  54 to model 67 relating 4 to 23
# Added expanded arrow  55 to model 67 relating 5 to 23
# Added expanded arrow  56 to model 67 relating 6 to 23
# Added expanded arrow  57 to model 67 relating 7 to 23
# Added expanded arrow  58 to model 67 relating 8 to 23
# Processing theory 67
# Added expanded arrow  59 to model 67 relating 21 to 11
# Added expanded arrow  60 to model 67 relating 20 to 11
# Processing theory 67
# Added expanded arrow  61 to model 67 relating 23 to 10
# Processing theory 68
# Added expanded arrow  47 to model 68 relating 5 to 3
# Added expanded arrow  48 to model 68 relating 6 to 3
# Processing theory 68
# Added expanded arrow  49 to model 68 relating 3 to 20
# Added expanded arrow  50 to model 68 relating 7 to 20
# Processing theory 68
# Added expanded arrow  51 to model 68 relating 9 to 6
# Added expanded arrow  52 to model 68 relating 9 to 5
# Processing theory 69
# Added expanded arrow  90 to model 69 relating 5 to 4
# Added expanded arrow  91 to model 69 relating 6 to 4
# Processing theory 69
# Added expanded arrow  92 to model 69 relating 4 to 22
# Added expanded arrow  93 to model 69 relating 4 to 8
# Added expanded arrow  94 to model 69 relating 10 to 22
# Added expanded arrow  95 to model 69 relating 10 to 8
# Added expanded arrow  96 to model 69 relating 16 to 22
# Added expanded arrow  97 to model 69 relating 16 to 8
# Added expanded arrow  98 to model 69 relating 17 to 22
# Added expanded arrow  99 to model 69 relating 17 to 8
# Added expanded arrow  100 to model 69 relating 15 to 22
# Added expanded arrow  101 to model 69 relating 15 to 8
# Processing theory 69
# Added expanded arrow  102 to model 69 relating 4 to 11
# Added expanded arrow  103 to model 69 relating 10 to 11
# Processing theory 69
# Added expanded arrow  104 to model 69 relating 16 to 13
# Added expanded arrow  105 to model 69 relating 15 to 13
# Processing theory 69
# Added expanded arrow  106 to model 69 relating 18 to 21
# Added expanded arrow  107 to model 69 relating 18 to 21
# Added expanded arrow  108 to model 69 relating 19 to 21
# Added expanded arrow  109 to model 69 relating 19 to 21
# Added expanded arrow  110 to model 69 relating 27 to 21
# Added expanded arrow  111 to model 69 relating 27 to 21
# Added expanded arrow  112 to model 69 relating 28 to 21
# Added expanded arrow  113 to model 69 relating 28 to 21
# Added expanded arrow  114 to model 69 relating 29 to 21
# Added expanded arrow  115 to model 69 relating 29 to 21
# Added expanded arrow  116 to model 69 relating 22 to 21
# Added expanded arrow  117 to model 69 relating 22 to 21
# Processing theory 69
# Added expanded arrow  118 to model 69 relating 23 to 22
# Added expanded arrow  119 to model 69 relating 25 to 22
# Added expanded arrow  120 to model 69 relating 24 to 22
# Processing theory 69
# Added expanded arrow  121 to model 69 relating 3 to 32
# Added expanded arrow  122 to model 69 relating 31 to 32
# Added expanded arrow  123 to model 69 relating 30 to 32
# Processing theory 69
# Added expanded arrow  124 to model 69 relating 35 to 37
# Added expanded arrow  125 to model 69 relating 34 to 37
# Processing theory 70
# Added expanded arrow  54 to model 70 relating 6 to 3
# Added expanded arrow  55 to model 70 relating 7 to 3
# Processing theory 70
# Added expanded arrow  56 to model 70 relating 19 to 17
# Added expanded arrow  57 to model 70 relating 20 to 17
# Processing theory 70
# Added expanded arrow  58 to model 70 relating 8 to 3
# Added expanded arrow  59 to model 70 relating 8 to 8
# Added expanded arrow  60 to model 70 relating 8 to 9
# Added expanded arrow  61 to model 70 relating 8 to 12
# Added expanded arrow  62 to model 70 relating 8 to 11
# Added expanded arrow  63 to model 70 relating 8 to 23
# Added expanded arrow  64 to model 70 relating 17 to 3
# Added expanded arrow  65 to model 70 relating 17 to 8
# Added expanded arrow  66 to model 70 relating 17 to 9
# Added expanded arrow  67 to model 70 relating 17 to 12
# Added expanded arrow  68 to model 70 relating 17 to 11
# Added expanded arrow  69 to model 70 relating 17 to 23
# Processing theory 70
# Added expanded arrow  70 to model 70 relating 15 to 24
# Added expanded arrow  71 to model 70 relating 14 to 24
# Added expanded arrow  72 to model 70 relating 16 to 24
# Processing theory 71
# Added expanded arrow  30 to model 71 relating 3 to 5
# Added expanded arrow  31 to model 71 relating 3 to 7
# Added expanded arrow  32 to model 71 relating 4 to 5
# Added expanded arrow  33 to model 71 relating 4 to 7
# Processing theory 71
# Added expanded arrow  34 to model 71 relating 7 to 8
# Added expanded arrow  35 to model 71 relating 5 to 8
# Processing theory 71
# Added expanded arrow  36 to model 71 relating 9 to 8
# Added expanded arrow  37 to model 71 relating 10 to 8
# Added expanded arrow  38 to model 71 relating 11 to 8
# Processing theory 72
# Added expanded arrow  112 to model 72 relating 8 to 3
# Added expanded arrow  113 to model 72 relating 9 to 3
# Added expanded arrow  114 to model 72 relating 29 to 3
# Added expanded arrow  115 to model 72 relating 27 to 3
# Added expanded arrow  116 to model 72 relating 28 to 3
# Added expanded arrow  117 to model 72 relating 30 to 3
# Processing theory 72
# Added expanded arrow  118 to model 72 relating 10 to 4
# Added expanded arrow  119 to model 72 relating 26 to 4
# Added expanded arrow  120 to model 72 relating 11 to 4
# Added expanded arrow  121 to model 72 relating 31 to 4
# Added expanded arrow  122 to model 72 relating 38 to 4
# Added expanded arrow  123 to model 72 relating 12 to 4
# Processing theory 72
# Added expanded arrow  124 to model 72 relating 13 to 5
# Added expanded arrow  125 to model 72 relating 20 to 5
# Added expanded arrow  126 to model 72 relating 21 to 5
# Added expanded arrow  127 to model 72 relating 14 to 5
# Added expanded arrow  128 to model 72 relating 15 to 5
# Added expanded arrow  129 to model 72 relating 22 to 5
# Added expanded arrow  130 to model 72 relating 16 to 5
# Added expanded arrow  131 to model 72 relating 23 to 5
# Added expanded arrow  132 to model 72 relating 17 to 5
# Added expanded arrow  133 to model 72 relating 35 to 5
# Processing theory 72
# Added expanded arrow  134 to model 72 relating 18 to 6
# Added expanded arrow  135 to model 72 relating 19 to 6
# Processing theory 72
# Added expanded arrow  136 to model 72 relating 27 to 8
# Added expanded arrow  137 to model 72 relating 28 to 8
# Added expanded arrow  138 to model 72 relating 29 to 8
# Processing theory 72
# Processing theory 72
# Added expanded arrow  139 to model 72 relating 24 to 18
# Processing theory 73
# Added expanded arrow  58 to model 73 relating 9 to 7
# Added expanded arrow  59 to model 73 relating 10 to 7
# Processing theory 73
# Added expanded arrow  60 to model 73 relating 16 to 11
# Added expanded arrow  61 to model 73 relating 15 to 11
# Added expanded arrow  62 to model 73 relating 14 to 11
# Added expanded arrow  63 to model 73 relating 13 to 11
# Processing theory 74
# Added expanded arrow  37 to model 74 relating 8 to 9
# Added expanded arrow  38 to model 74 relating 7 to 9
# Processing theory 74
# Added expanded arrow  39 to model 74 relating 8 to 9
# Added expanded arrow  40 to model 74 relating 7 to 9
# Processing theory 74
# Added expanded arrow  41 to model 74 relating 9 to 3
# Added expanded arrow  42 to model 74 relating 11 to 3
# Added expanded arrow  43 to model 74 relating 10 to 3
# Processing theory 75
# Added expanded arrow  19 to model 75 relating 3 to 5
# Added expanded arrow  20 to model 75 relating 4 to 5
# Processing theory 76
# Added expanded arrow  30 to model 76 relating 6 to 4
# Added expanded arrow  31 to model 76 relating 5 to 4
# Processing theory 77
# Added expanded arrow  41 to model 77 relating 15 to 3
# Added expanded arrow  42 to model 77 relating 19 to 3
# Added expanded arrow  43 to model 77 relating 14 to 3
# Added expanded arrow  44 to model 77 relating 18 to 3
# Added expanded arrow  45 to model 77 relating 16 to 3
# Added expanded arrow  46 to model 77 relating 17 to 3
# Processing theory 77
# Added expanded arrow  47 to model 77 relating 11 to 9
# Added expanded arrow  48 to model 77 relating 10 to 9
# Processing theory 78
# Added expanded arrow  45 to model 78 relating 9 to 11
# Added expanded arrow  46 to model 78 relating 10 to 11
# Processing theory 78
# Added expanded arrow  47 to model 78 relating 5 to 4
# Added expanded arrow  48 to model 78 relating 13 to 4
# Added expanded arrow  49 to model 78 relating 9 to 4
# Processing theory 78
# Added expanded arrow  50 to model 78 relating 7 to 13
# Added expanded arrow  51 to model 78 relating 15 to 13
# Added expanded arrow  52 to model 78 relating 16 to 13
# Processing theory 78
# Added expanded arrow  53 to model 78 relating 18 to 5
# Added expanded arrow  54 to model 78 relating 19 to 5
# Processing theory 8
# Added expanded arrow  33 to model 8 relating 3 to 10
# Added expanded arrow  34 to model 8 relating 4 to 10
# Processing theory 8
# Added expanded arrow  35 to model 8 relating 5 to 11
# Added expanded arrow  36 to model 8 relating 6 to 11
# Processing theory 8
# Added expanded arrow  37 to model 8 relating 7 to 12
# Added expanded arrow  38 to model 8 relating 8 to 12
# Processing theory 80
# Added expanded arrow  143 to model 80 relating 21 to 17
# Added expanded arrow  144 to model 80 relating 23 to 17
# Added expanded arrow  145 to model 80 relating 25 to 17
# Processing theory 80
# Added expanded arrow  146 to model 80 relating 37 to 42
# Added expanded arrow  147 to model 80 relating 38 to 42
# Processing theory 80
# Added expanded arrow  148 to model 80 relating 36 to 8
# Added expanded arrow  149 to model 80 relating 7 to 8
# Processing theory 80
# Added expanded arrow  150 to model 80 relating 5 to 21
# Processing theory 80
# Added expanded arrow  151 to model 80 relating 30 to 23
# Processing theory 80
# Added expanded arrow  152 to model 80 relating 29 to 25
# Processing theory 80
# Added expanded arrow  153 to model 80 relating 40 to 45
# Added expanded arrow  154 to model 80 relating 39 to 45
# Processing theory 80
# Added expanded arrow  155 to model 80 relating 10 to 9
# Added expanded arrow  156 to model 80 relating 11 to 9
# Added expanded arrow  157 to model 80 relating 13 to 9
# Added expanded arrow  158 to model 80 relating 14 to 9
# Added expanded arrow  159 to model 80 relating 12 to 9
# Processing theory 80
# Added expanded arrow  160 to model 80 relating 32 to 11
# Added expanded arrow  161 to model 80 relating 33 to 11
# Added expanded arrow  162 to model 80 relating 3 to 11
# Added expanded arrow  163 to model 80 relating 4 to 11
# Added expanded arrow  164 to model 80 relating 6 to 11
# Added expanded arrow  165 to model 80 relating 34 to 11
# Processing theory 80
# Added expanded arrow  166 to model 80 relating 7 to 12
# Added expanded arrow  167 to model 80 relating 36 to 12
# Added expanded arrow  168 to model 80 relating 37 to 12
# Added expanded arrow  169 to model 80 relating 38 to 12
# Added expanded arrow  170 to model 80 relating 39 to 12
# Added expanded arrow  171 to model 80 relating 40 to 12
# Processing theory 80
# Added expanded arrow  172 to model 80 relating 8 to 13
# Added expanded arrow  173 to model 80 relating 42 to 13
# Added expanded arrow  174 to model 80 relating 45 to 13
# Processing theory 80
# Added expanded arrow  175 to model 80 relating 20 to 14
# Processing theory 80
# Added expanded arrow  176 to model 80 relating 5 to 10
# Added expanded arrow  177 to model 80 relating 30 to 10
# Added expanded arrow  178 to model 80 relating 29 to 10
# Processing theory 81
# Added expanded arrow  34 to model 81 relating 6 to 14
# Added expanded arrow  35 to model 81 relating 7 to 14
# Added expanded arrow  36 to model 81 relating 8 to 14
# Added expanded arrow  37 to model 81 relating 9 to 14
# Processing theory 82
# Added expanded arrow  69 to model 82 relating 11 to 3
# Processing theory 82
# Added expanded arrow  70 to model 82 relating 11 to 3
# Added expanded arrow  71 to model 82 relating 9 to 3
# Processing theory 82
# Added expanded arrow  72 to model 82 relating 10 to 3
# Added expanded arrow  73 to model 82 relating 9 to 3
# Processing theory 82
# Added expanded arrow  74 to model 82 relating 12 to 3
# Added expanded arrow  75 to model 82 relating 10 to 3
# Processing theory 82
# Added expanded arrow  76 to model 82 relating 12 to 3
# Processing theory 83
# Added expanded arrow  45 to model 83 relating 3 to 15
# Added expanded arrow  46 to model 83 relating 6 to 15
# Added expanded arrow  47 to model 83 relating 5 to 15
# Added expanded arrow  48 to model 83 relating 4 to 15
# Processing theory 83
# Added expanded arrow  49 to model 83 relating 17 to 3
# Added expanded arrow  50 to model 83 relating 18 to 3
# Processing theory 9
# Added expanded arrow  47 to model 9 relating 3 to 15
# Added expanded arrow  48 to model 9 relating 5 to 15
# Processing theory 9
# Added expanded arrow  49 to model 9 relating 4 to 14
# Added expanded arrow  50 to model 9 relating 7 to 14
# Added expanded arrow  51 to model 9 relating 13 to 14
# Processing theory 9
# Added expanded arrow  52 to model 9 relating 15 to 19
# Added expanded arrow  53 to model 9 relating 5 to 19

# %%
for strId in containers: 
    [model_num,con_id] = strId.split(":")
    if model_num not in ids_to_remove.keys():
        ids_to_remove[model_num] = []
    ids_to_remove[model_num].append(con_id)
    print("Got container",con_id,"in model",model_num)
    
    maxTheoryId = 1
    for id in theory_row_dicts[model_num]:
        if int(id) > maxTheoryId:
            maxTheoryId = int(id)
    nextId = maxTheoryId+1
    
    contained = []
    rel_tars = []
    
    for id in theory_row_dicts[model_num]:
        source_id = theory_row_dicts[model_num][id]['Line Source']
        target_id = theory_row_dicts[model_num][id]['Line Destination']
        contained_by = theory_row_dicts[model_num][id]['Contained By']
            
        if contained_by == con_id:
            contained.append(id)
            theory_row_dicts[model_num][id]['Contained By'] = ''
            
        if source_id == con_id: # only ever this direction
            line_to_copy = theory_row_dicts[model_num][id]
            rel_tars.append(target_id)
            ids_to_remove[model_num].append(id)
                
    rels_to_add = []
    for c in contained:
        for t in rel_tars:
            rels_to_add.append((c,t))
            
    for (s,t) in rels_to_add:
        rel = copy.deepcopy(line_to_copy)
        rel['Id']=str(nextId)
        rel['Line Source'] = s
        rel['Line Destination'] = t
        theory_row_dicts[model_num][str(nextId)] = rel
        nextId = nextId+1
        print("Added expanded arrow ",rel['Id'],"to model",model_num,"relating",s,"to",t)
# Out:
# Got container 15 in model 30
# Added expanded arrow  46 to model 30 relating 7 to 4
# Added expanded arrow  47 to model 30 relating 8 to 4
# Added expanded arrow  48 to model 30 relating 9 to 4
# Added expanded arrow  49 to model 30 relating 10 to 4
# Added expanded arrow  50 to model 30 relating 11 to 4
# Added expanded arrow  51 to model 30 relating 12 to 4
# Added expanded arrow  52 to model 30 relating 13 to 4
# Added expanded arrow  53 to model 30 relating 14 to 4
# Got container 20 in model 30
# Added expanded arrow  54 to model 30 relating 16 to 5
# Added expanded arrow  55 to model 30 relating 17 to 5
# Added expanded arrow  56 to model 30 relating 18 to 5
# Added expanded arrow  57 to model 30 relating 19 to 5
# Got container 11 in model 5
# Added expanded arrow  63 to model 5 relating 7 to 3
# Added expanded arrow  64 to model 5 relating 8 to 3
# Added expanded arrow  65 to model 5 relating 9 to 3
# Added expanded arrow  66 to model 5 relating 10 to 3
# Got container 23 in model 5
# Added expanded arrow  67 to model 5 relating 15 to 5
# Added expanded arrow  68 to model 5 relating 16 to 5
# Added expanded arrow  69 to model 5 relating 17 to 5
# Added expanded arrow  70 to model 5 relating 18 to 5
# Added expanded arrow  71 to model 5 relating 19 to 5
# Added expanded arrow  72 to model 5 relating 20 to 5
# Added expanded arrow  73 to model 5 relating 21 to 5
# Added expanded arrow  74 to model 5 relating 22 to 5

# %%
# Remove the junctions and arrows to the junctions
for model_num in ids_to_remove.keys():
    ids = set(ids_to_remove[model_num])
    print ("Going to remove ",ids," from model ",model_num)
    for id in ids:
        del theory_row_dicts[model_num][id]
# Out:
# Going to remove  {'88', '25', '113', '77', '116', '42', '48', '76', '57', '13', '17', '72', '62', '74', '65', '63', '73', '95', '109', '83', '87', '9', '107', '75', '44', '35', '43', '71', '50', '41', '78', '53', '46', '47', '64', '49', '45', '54', '92', '5', '119', '79', '58', '111'}  from model  1
# Going to remove  {'25', '42', '48', '31', '24', '36', '39', '40', '29', '44', '32', '35', '43', '41', '46', '47', '30', '49', '26', '45', '34', '33', '37', '38'}  from model  10
# Going to remove  {'33', '30', '31', '29', '32', '14'}  from model  11
# Going to remove  {'42', '17', '36', '15', '51', '39', '22', '40', '20', '44', '43', '50', '41', '47', '49', '26', '45', '37', '38'}  from model  12
# Going to remove  {'208', '25', '206', '42', '145', '126', '97', '118', '109', '154', '29', '182', '178', '127', '99', '198', '191', '121', '169', '104', '204', '56', '131', '113', '133', '116', '202', '108', '174', '134', '193', '135', '95', '51', '107', '112', '199', '158', '176', '186', '170', '125', '54', '124', '93', '144', '115', '100', '203', '175', '128', '123', '163', '207', '65', '132', '183', '83', '185', '146', '195', '32', '117', '201', '11', '177', '110', '189', '143', '136', '96', '165', '168', '188', '156', '184', '98', '150', '67', '94', '129', '194', '8', '85', '69', '197', '87', '164', '16', '179', '35', '103', '148', '60', '190', '173', '171', '159', '155', '147', '192', '172', '111'}  from model  13
# Going to remove  {'25', '48', '52', '42', '31', '36', '51', '28', '39', '29', '44', '32', '50', '43', '46', '47', '49', '26', '45', '34', '27', '33', '37', '38', '56'}  from model  14
# Going to remove  {'25', '21', '48', '52', '42', '31', '24', '67', '57', '66', '62', '65', '63', '51', '69', '28', '20', '29', '44', '59', '50', '43', '41', '53', '46', '47', '60', '64', '49', '45', '61', '68', '58', '56'}  from model  16
# Going to remove  {'88', '25', '77', '21', '82', '101', '48', '52', '76', '24', '67', '94', '89', '72', '62', '97', '74', '65', '63', '73', '95', '51', '85', '69', '87', '80', '75', '20', '103', '91', '55', '50', '71', '43', '41', '78', '53', '46', '81', '47', '64', '86', '49', '26', '102', '45', '54', '34', '90', '92', '96', '93', '61', '68', '33', '104', '70', '79', '37', '58', '84', '19'}  from model  17
# Going to remove  {'17', '15', '10', '18', '16'}  from model  18
# Going to remove  {'25', '27', '24', '15', '21', '23', '28', '22', '9', '30', '18', '31', '20', '26', '29', '32'}  from model  19
# Going to remove  {'21', '42', '48', '52', '31', '24', '15', '39', '9', '40', '29', '44', '32', '43', '50', '41', '46', '47', '30', '49', '26', '45', '33', '37', '18', '38'}  from model  22
# Going to remove  {'21', '48', '52', '24', '67', '66', '57', '6', '36', '62', '85', '51', '69', '39', '83', '87', '22', '40', '80', '44', '32', '35', '55', '50', '43', '53', '60', '64', '86', '49', '26', '34', '54', '61', '27', '68', '33', '70', '37', '38', '84'}  from model  23
# Going to remove  {'88', '25', '77', '48', '31', '67', '66', '89', '72', '36', '74', '73', '15', '65', '69', '39', '87', '80', '40', '16', '29', '44', '35', '59', '71', '46', '47', '60', '30', '86', '45', '61', '68', '79', '37', '58', '38'}  from model  24
# Going to remove  {'77', '42', '67', '57', '66', '72', '36', '65', '22', '40', '44', '35', '43', '11', '41', '64', '26', '34', '27', '12', '70', '37', '58', '56'}  from model  25
# Going to remove  {'25', '42', '36', '15', '8', '28', '23', '20', '29', '32', '35', '50', '41', '46', '49', '26', '34', '27', '33'}  from model  26
# Going to remove  {'21', '48', '42', '31', '36', '62', '28', '39', '40', '16', '29', '44', '32', '35', '43', '41', '30', '26', '45', '34', '27', '33', '37', '38'}  from model  28
# Going to remove  {'88', '77', '101', '42', '52', '76', '67', '57', '66', '13', '106', '89', '72', '62', '97', '74', '73', '63', '51', '8', '69', '23', '85', '87', '75', '29', '99', '59', '55', '91', '71', '78', '53', '81', '45', '34', '92', '54', '102', '93', '61', '27', '68', '104', '70', '37', '18', '58', '84', '56'}  from model  29
# Going to remove  {'25', '27', '43', '50', '41', '51', '53', '23', '46', '60', '42', '52', '45'}  from model  3
# Going to remove  {'48', '67', '66', '36', '62', '74', '73', '63', '65', '8', '51', '39', '40', '16', '29', '44', '35', '50', '11', '41', '46', '64', '49', '45', '5', '61', '37', '38'}  from model  31
# Going to remove  {'25', '35', '43', '21', '41', '28', '23', '22', '42', '20', '7', '32', '34', '6'}  from model  32
# Going to remove  {'42', '24', '67', '66', '57', '74', '65', '73', '69', '83', '87', '40', '44', '59', '43', '71', '41', '60', '27', '61', '68', '70', '79', '58', '19', '56', '4'}  from model  33
# Going to remove  {'25', '21', '48', '31', '24', '28', '23', '22', '29', '32', '35', '46', '47', '30', '49', '26', '45', '27', '33'}  from model  34
# Going to remove  {'13', '25', '45', '27', '44', '43', '21', '8', '28', '30', '31', '24', '26', '29', '32'}  from model  35
# Going to remove  {'25', '42', '48', '52', '67', '24', '36', '63', '51', '39', '22', '40', '29', '44', '55', '43', '50', '41', '53', '46', '47', '49', '45', '54', '27', '37', '38', '56'}  from model  39
# Going to remove  {'82', '98', '67', '94', '66', '72', '62', '97', '74', '65', '63', '73', '95', '69', '39', '83', '80', '40', '75', '32', '35', '71', '81', '60', '64', '92', '96', '93', '61', '68', '70', '79', '38', '19'}  from model  4
# Going to remove  {'11', '10', '8', '12'}  from model  40
# Going to remove  {'48', '52', '31', '67', '57', '66', '72', '62', '74', '65', '63', '73', '51', '69', '83', '9', '75', '59', '55', '50', '71', '53', '46', '47', '60', '64', '49', '26', '45', '54', '61', '68', '33', '70', '58', '56'}  from model  41
# Going to remove  {'48', '52', '31', '66', '36', '72', '65', '69', '22', '20', '32', '35', '55', '46', '47', '64', '49', '45', '34', '54', '61', '68', '33', '70', '37', '18', '19', '56'}  from model  42
# Going to remove  {'25', '21', '42', '48', '24', '57', '36', '63', '51', '69', '39', '22', '40', '44', '43', '41', '53', '46', '47', '64', '49', '45', '68', '37', '58', '38', '19'}  from model  43
# Going to remove  {'25', '42', '48', '31', '17', '36', '28', '39', '40', '29', '32', '14', '35', '43', '41', '10', '30', '49', '26', '34', '5', '27', '33', '12', '37', '38'}  from model  45
# Going to remove  {'13', '25', '35', '36', '27', '24', '21', '23', '28', '19', '22', '26', '37', '20', '29', '34', '14'}  from model  47
# Going to remove  {'25', '21', '48', '52', '42', '31', '17', '36', '28', '23', '39', '40', '29', '32', '35', '50', '41', '53', '46', '47', '30', '49', '34', '54', '27', '33', '38', '19'}  from model  48
# Going to remove  {'42', '31', '57', '36', '62', '51', '39', '28', '40', '7', '32', '35', '59', '55', '43', '50', '41', '10', '53', '46', '60', '30', '34', '54', '61', '33', '37', '38', '58', '56', '4'}  from model  49
# Going to remove  {'13', '35', '36', '33', '30', '31', '29', '32', '34', '14'}  from model  50
# Going to remove  {'25', '42', '31', '24', '57', '36', '51', '28', '29', '32', '44', '14', '35', '59', '55', '43', '50', '53', '45', '34', '54', '27', '58', '19', '56'}  from model  51
# Going to remove  {'25', '48', '52', '31', '24', '36', '65', '63', '51', '29', '35', '50', '47', '64', '30', '26', '27', '37', '56'}  from model  52
# Going to remove  {'25', '21', '42', '48', '24', '17', '23', '28', '22', '40', '16', '20', '29', '44', '43', '41', '46', '47', '26', '45', '27', '18'}  from model  53
# Going to remove  {'52', '31', '24', '67', '57', '66', '13', '36', '62', '63', '51', '69', '39', '40', '29', '32', '14', '3', '35', '59', '41', '10', '53', '60', '64', '34', '54', '33', '70', '37', '38', '58', '19'}  from model  54
# Going to remove  {'27', '10', '23', '22', '26'}  from model  55
# Going to remove  {'52', '24', '67', '57', '66', '36', '69', '28', '20', '29', '44', '35', '59', '43', '53', '46', '60', '30', '45', '54', '61', '68', '70', '37', '58'}  from model  56
# Going to remove  {'77', '82', '76', '67', '94', '66', '72', '62', '97', '74', '65', '63', '73', '95', '69', '83', '75', '29', '44', '35', '91', '43', '71', '41', '10', '78', '46', '81', '47', '64', '45', '90', '68', '70', '79', '4'}  from model  57
# Going to remove  {'25', '48', '52', '24', '66', '57', '36', '65', '63', '51', '23', '39', '28', '29', '44', '32', '35', '55', '43', '50', '41', '53', '46', '64', '47', '30', '49', '26', '45', '34', '54', '27', '33', '38', '58', '56'}  from model  58
# Going to remove  {'25', '54', '41', '53', '23', '40', '45', '57'}  from model  59
# Going to remove  {'20', '15', '10', '18', '16', '19', '14'}  from model  6
# Going to remove  {'82', '42', '126', '97', '149', '118', '109', '154', '162', '127', '99', '91', '46', '122', '121', '27', '104', '70', '56', '113', '133', '151', '108', '134', '76', '130', '157', '135', '95', '51', '80', '75', '112', '158', '53', '125', '54', '124', '93', '115', '77', '128', '123', '160', '163', '36', '65', '83', '117', '50', '81', '86', '110', '45', '92', '136', '96', '119', '165', '156', '98', '150', '94', '129', '62', '74', '85', '164', '114', '103', '148', '105', '159', '155', '147', '37', '84', '111'}  from model  60
# Going to remove  {'17', '27', '33', '41', '12', '28', '46', '47', '22', '30', '31', '29', '32', '34'}  from model  62
# Going to remove  {'25', '15', '23', '22', '40', '24', '26'}  from model  64
# Going to remove  {'25', '42', '48', '36', '28', '39', '40', '20', '29', '35', '46', '47', '30', '49', '34', '5', '27', '33', '12', '37', '38'}  from model  65
# Going to remove  {'77', '82', '48', '76', '42', '31', '52', '67', '66', '57', '72', '36', '65', '63', '85', '51', '69', '39', '83', '75', '44', '35', '55', '50', '71', '43', '53', '46', '47', '64', '30', '49', '45', '34', '54', '68', '33', '70', '37', '38', '84', '19', '56'}  from model  66
# Going to remove  {'42', '48', '31', '24', '9', '40', '22', '29', '32', '3', '43', '50', '41', '46', '47', '30', '49', '34', '33'}  from model  67
# Going to remove  {'25', '45', '27', '21', '8', '23', '28', '46', '24', '29', '44', '4'}  from model  68
# Going to remove  {'82', '42', '48', '52', '76', '57', '89', '72', '36', '74', '51', '85', '39', '83', '9', '40', '80', '75', '20', '7', '44', '14', '55', '43', '50', '71', '41', '78', '53', '46', '81', '47', '86', '49', '26', '45', '54', '33', '12', '70', '79', '38', '84'}  from model  69
# Going to remove  {'25', '21', '48', '31', '28', '39', '22', '40', '29', '44', '32', '35', '43', '46', '26', '34', '5', '27', '33', '37', '18', '38'}  from model  70
# Going to remove  {'17', '20', '21', '12', '23', '19', '22', '18', '16', '24', '26', '29', '14', '6'}  from model  71
# Going to remove  {'42', '48', '52', '67', '94', '57', '66', '36', '62', '65', '63', '95', '51', '39', '40', '7', '32', '44', '59', '55', '43', '50', '91', '41', '53', '105', '46', '47', '60', '64', '49', '45', '34', '54', '90', '92', '96', '93', '61', '104', '33', '37', '58', '56'}  from model  72
# Going to remove  {'35', '27', '33', '12', '8', '28', '31', '29', '32', '34'}  from model  73
# Going to remove  {'13', '20', '35', '15', '33', '21', '12', '23', '22', '16', '19', '34', '14'}  from model  74
# Going to remove  {'13', '11', '12', '6'}  from model  75
# Going to remove  {'17', '9', '18', '19'}  from model  76
# Going to remove  {'35', '36', '25', '24', '21', '39', '22', '37', '38', '20', '26', '34'}  from model  77
# Going to remove  {'17', '25', '27', '43', '33', '41', '12', '8', '39', '28', '42', '30', '31', '24', '26', '29', '32', '14'}  from model  78
# Going to remove  {'13', '17', '20', '15', '24', '21', '23', '22', '18', '16', '19', '14'}  from model  8
# Going to remove  {'88', '77', '113', '128', '108', '48', '52', '76', '31', '111', '24', '67', '130', '129', '123', '57', '66', '126', '89', '72', '74', '65', '63', '73', '132', '51', '28', '87', '109', '22', '107', '75', '16', '112', '35', '127', '59', '55', '43', '91', '41', '78', '53', '46', '60', '122', '49', '26', '110', '121', '54', '90', '27', '70', '141', '79', '18', '58', '19', '115', '56', '131'}  from model  80
# Going to remove  {'17', '5', '15', '18', '16', '29'}  from model  81
# Going to remove  {'5', '35', '36', '27', '33', '8', '28', '37', '30', '31', '38', '29', '7', '32', '34', '4', '66', '6'}  from model  82
# Going to remove  {'36', '33', '37', '30', '31', '16', '19', '38', '32', '34'}  from model  83
# Going to remove  {'17', '32', '35', '36', '44', '33', '46', '42', '40', '16', '20', '45', '34'}  from model  9
# Going to remove  {'15', '33', '34', '20'}  from model  30
# Going to remove  {'11', '30', '57', '23'}  from model  5

# %%
# Check for arrows that start on other arrows and correct them
for model_num in theory_row_dicts.keys():
    for row in theory_row_dicts[model_num].keys():
        if theory_row_dicts[model_num][row]['Name'] == 'Line':
            line_source = theory_row_dicts[model_num][row]['Line Source']
            if line_source == '':
                print ("Error! No line source found for line ",row," in theory ",model_num)
                continue
            if line_source not in theory_row_dicts[model_num].keys():
                print ("Error! Line source no longer exists for line ",row,"in theory ",model_num)
                continue
            line_source_type = theory_row_dicts[model_num][line_source]['Name']
            if line_source_type == 'Line':
                orig_source = theory_row_dicts[model_num][line_source]['Line Source']
                print("Arrow starting on arrow: ",row," starts on ",line_source," in theory ",model_num, "...Updating to original source",orig_source)
                theory_row_dicts[model_num][row]['Line Source'] = orig_source
# Out:
# Error! Line source no longer exists for line  124 in theory  1
# Error! Line source no longer exists for line  125 in theory  1
# Error! Line source no longer exists for line  126 in theory  1
# Error! No line source found for line  187  in theory  13
# Error! Line source no longer exists for line  55 in theory  22
# Error! Line source no longer exists for line  56 in theory  22
# Arrow starting on arrow:  79  starts on  65  in theory  29 ...Updating to original source 3
# Arrow starting on arrow:  89  starts on  40  in theory  66 ...Updating to original source 3

# %%
# Check for arrows that end on other arrows and correct them
tofix = {}
for model_num in theory_row_dicts.keys():
    for row in theory_row_dicts[model_num].keys():
        if theory_row_dicts[model_num][row]['Name'] == 'Line':
            line_dest = theory_row_dicts[model_num][row]['Line Destination']
            if line_dest == '':
                print ("Error! No line destination found for line ",row," in theory ",model_num)
                continue
            if line_dest not in theory_row_dicts[model_num].keys():
                print ("Error! Line destination no longer exists for line ",row,"in theory ",model_num)
                continue
            line_dest_type = theory_row_dicts[model_num][line_dest]['Name']
            if line_dest_type == 'Line':
                rel_type = theory_row_dicts[model_num][row]['Text Area 1']
                orig_rel_type = theory_row_dicts[model_num][line_dest]['Text Area 1'].strip()
                #print("Arrow ending on arrow: ",row," ends on ",line_dest," in theory ",model_num,", this rel type: ",rel_type,", orig rel type: ",orig_rel_type)
                if model_num not in tofix.keys():
                    tofix[model_num] = {}
                if line_dest not in tofix[model_num].keys():
                    tofix[model_num][line_dest] = []
                tofix[model_num][line_dest].append(row)
# Out:
# Error! No line destination found for line  24  in theory  11
# Error! No line destination found for line  187  in theory  13
# Error! Line destination no longer exists for line  54 in theory  22
# Error! Line destination no longer exists for line  56 in theory  22
# Error! Line destination no longer exists for line  58 in theory  22
# Error! Line destination no longer exists for line  60 in theory  22
# Error! No line destination found for line  29  in theory  27

# %%
for model_num in tofix.keys():
    dests = tofix[model_num].keys()
    for line_dest in dests: 
        # A list of rows that have to be updated 
        rows = tofix[model_num][line_dest]
        
        maxTheoryId = max( map(int, theory_row_dicts[model_num].keys()) )
        nextId = maxTheoryId+1
        
        # Replace the original arrow with a reified class and two arrows
        # Class name: "the X-Y <type> relationship"
        # Then relate the third arrow to this class
        # 1. Copy the original source to make the new entity: 
        orig_source_id = theory_row_dicts[model_num][line_dest]['Line Source']
        orig_dest_id = theory_row_dicts[model_num][line_dest]['Line Destination']
        print ("Modifying line from ",orig_source_id,"to",orig_dest_id)
        orig_source_name = theory_row_dicts[model_num][orig_source_id]['Text Area 1'].strip()
        orig_dest_name = theory_row_dicts[model_num][orig_dest_id]['Text Area 1'].strip()
        orig_rel_type = theory_row_dicts[model_num][line_dest]['Text Area 1'].strip()
    
        relEntity = copy.deepcopy(theory_row_dicts[model_num][orig_source_id])
        relEntity['Id']=str(nextId)
        relEntity['Name']='Terminator' # rounded box
        relLabel = Relation.getFullLabelForShortLabel(orig_rel_type)
        if relLabel is None:
            relLabel = orig_rel_type
        relEntity['Text Area 1'] = f"the '{orig_source_name}' to '{orig_dest_name}' {relLabel} relationship"
        print(relEntity['Text Area 1'])
        theory_row_dicts[model_num][str(nextId)] = relEntity
        # Map all the arrows that ended on an arrow on to the new entity
        for row in rows: 
            theory_row_dicts[model_num][row]['Line Destination'] = str(nextId)
        # Create one more relation to connnect the new entity to its original dest
        relEntity = copy.deepcopy(theory_row_dicts[model_num][line_dest])
        relEntity['Line Source'] = str(nextId)
        
        # Map the original relation onto this new entity
        theory_row_dicts[model_num][line_dest]['Line Destination'] = str(nextId)
        theory_row_dicts[model_num][line_dest]['Text Area 1'] = "relates through"

        nextId = nextId+1
        relEntity['Id']=str(nextId)
        relEntity['Text Area 1'] = "relates to"
        theory_row_dicts[model_num][str(nextId)] = relEntity
        print ("Fixed ",line_dest,"in",model_num)
# Out:
# Modifying line from  27 to 29
# the 'Performance of goal-directed behaviours' to 'Goal attainment / failure' Influences relationship
# Fixed  89 in 1
# Modifying line from  21 to 24
# the 'Implementation intentions' to 'Trying' Positively influences relationship
# Fixed  56 in 1
# Modifying line from  19 to 21
# the 'Desire' to 'Implementation intentions' Influences relationship
# Fixed  70 in 1
# Modifying line from  21 to 22
# the 'Behavioural intention' to 'Behaviour' Influences relationship
# Fixed  40 in 14
# Modifying line from  14 to 17
# the 'Individual differences' to 'Message acceptance' Influences (*) relationship
# Fixed  79 in 16
# Modifying line from  14 to 11
# the 'Individual differences' to 'Fear' Influences (*) relationship
# Fixed  80 in 16
# Modifying line from  18 to 13
# the 'Feedback-standard discrepancies' to 'Performance / behaviour' Influences relationship
# Fixed  57 in 17
# Modifying line from  9 to 6
# the 'Norms' to 'Behaviour' Influences relationship
# Fixed  11 in 18
# Modifying line from  5 to 8
# the 'Injunctive norms' to 'Intention' Influences relationship
# Fixed  19 in 18
# Modifying line from  4 to 5
# the 'Work events' to 'Affective reactions' Influences relationship
# Fixed  11 in 2
# Modifying line from  10 to 4
# Label not recognised:  ​-
# the 'Negative self-attitudes' to 'Motivation to comply' ​- relationship
# Fixed  13 in 20
# Modifying line from  10 to 5
# Label not recognised:  ​+
# the 'Negative self-attitudes' to 'Motivation to deviate' ​+ relationship
# Fixed  14 in 20
# Modifying line from  7 to 8
# the 'Perceived availability of alternative deviant behaviour' to 'Motivated deviant behaviour' Influences relationship
# Fixed  19 in 20
# Modifying line from  8 to 10
# the 'Goals' to 'Behaviour' Influences relationship
# Fixed  35 in 22
# Modifying line from  3 to 19
# the 'Goals' to 'Persistence' Influences (*) relationship
# Fixed  115 in 23
# Modifying line from  19 to 13
# the 'Persistence' to 'Task performance' Influences relationship
# Fixed  46 in 23
# Modifying line from  12 to 13
# the 'Energising function' to 'Task performance' Influences relationship
# Fixed  42 in 23
# Modifying line from  11 to 13
# the 'Directive function' to 'Task performance' Influences relationship
# Fixed  41 in 23
# Modifying line from  15 to 13
# the 'Self-efficacy' to 'Task performance' Influences relationship
# Fixed  65 in 23
# Modifying line from  23 to 16
# the 'Incentives' to 'Commitment' Influences relationship
# Fixed  78 in 23
# Modifying line from  3 to 12
# the 'Goals' to 'Energising function' Influences (*) relationship
# Fixed  114 in 23
# Modifying line from  3 to 11
# the 'Goals' to 'Directive function' Influences (*) relationship
# Fixed  113 in 23
# Modifying line from  3 to 20
# the 'Goals' to 'Task-relevant knowledge and strategies / ability' Influences relationship
# Fixed  45 in 23
# Modifying line from  17 to 4
# the 'Intention' to 'Action' Influences relationship
# Fixed  54 in 24
# Modifying line from  32 to 33
# the 'Non-intenders' to 'Intenders' Transitions to relationship
# Fixed  70 in 24
# Modifying line from  33 to 34
# the 'Intenders' to 'Actors' Transitions to relationship
# Fixed  64 in 24
# Modifying line from  18 to 20
# Label not recognised:  Transitions to
# the 'Contemplation' to 'Initial behaviour change' Transitions to relationship
# Fixed  52 in 25
# Modifying line from  18 to 17
# Label not recognised:  Transitions to
# the 'Contemplation' to 'Precontemplation' Transitions to relationship
# Fixed  51 in 25
# Modifying line from  20 to 19
# Label not recognised:  Transitions to
# the 'Initial behaviour change' to 'Maintenance' Transitions to relationship
# Fixed  54 in 25
# Modifying line from  20 to 18
# Label not recognised:  Transitions to
# the 'Initial behaviour change' to 'Contemplation' Transitions to relationship
# Fixed  53 in 25
# Modifying line from  17 to 18
# Label not recognised:  Transitions to
# the 'Precontemplation' to 'Contemplation' Transitions to relationship
# Fixed  50 in 25
# Modifying line from  19 to 20
# Label not recognised:  Transitions to
# the 'Maintenance' to 'Initial behaviour change' Transitions to relationship
# Fixed  55 in 25
# Modifying line from  35 to 36
# the 'Motivation / intention state' to 'Behavioural state' Transitions to relationship
# Fixed  107 in 29
# Modifying line from  3 to 4
# the 'Labelling' to 'Commitment' Transitions to relationship
# Fixed  28 in 3
# Modifying line from  4 to 26
# the 'Commitment' to 'Enactment' Transitions to relationship
# Fixed  29 in 3
# Modifying line from  26 to 3
# the 'Enactment' to 'Labelling' Transitions to relationship
# Fixed  38 in 3
# Modifying line from  5 to 3
# Label not recognised:  ​+?
# the 'Information' to 'Enactment of AIDS preventive behaviour' ​+? relationship
# Fixed  36 in 30
# Modifying line from  6 to 3
# Label not recognised:  ​+?
# the 'Motivation' to 'Enactment of AIDS preventive behaviour' ​+? relationship
# Fixed  35 in 30
# Modifying line from  11 to 5
# the 'Motivation to  change' to 'Behaviour change' Influences relationship
# Fixed  29 in 32
# Modifying line from  12 to 3
# the 'Social integration / anomie' to 'Macro / societal level' Part of relationship
# Fixed  96 in 33
# Modifying line from  3 to 9
# the 'Motivation' to 'Behaviour' Influences relationship
# Fixed  13 in 40
# Modifying line from  27 to 41
# the 'Opportunities' to 'Behavioural control' Influences relationship
# Fixed  87 in 41
# Modifying line from  32 to 39
# the 'Abilities' to 'Opportunity search' Influences relationship
# Fixed  84 in 41
# Modifying line from  27 to 40
# the 'Opportunities' to 'Motivation to perform' Influences relationship
# Fixed  86 in 41
# Modifying line from  3 to 30
# Label not recognised:  ​+
# the 'Perception of need and responsibility' to 'Activation of norms' ​+ relationship
# Fixed  62 in 42
# Modifying line from  12 to 13
# Label not recognised:  Transitions to
# the 'Neutral stimuli' to 'Conditioned reinforcer' Transitions to relationship
# Fixed  34 in 43
# Modifying line from  13 to 14
# Label not recognised:  Transitions to
# the 'Conditioned reinforcer' to 'Generalised reinforcer' Transitions to relationship
# Fixed  35 in 43
# Modifying line from  8 to 7
# the 'Undecided about acting' to 'Decided to act' Transitions to relationship
# Fixed  13 in 44
# Modifying line from  6 to 4
# the 'Acting' to 'Maintenance' Transitions to relationship
# Fixed  15 in 44
# Modifying line from  7 to 6
# the 'Decided to act' to 'Acting' Transitions to relationship
# Fixed  14 in 44
# Modifying line from  3 to 9
# the 'Unaware of issue' to 'Unengaged by issue' Transitions to relationship
# Fixed  11 in 44
# Modifying line from  9 to 8
# the 'Unengaged by issue' to 'Undecided about acting' Transitions to relationship
# Fixed  12 in 44
# Modifying line from  8 to 5
# the 'Undecided about acting' to 'Decided not to act' Transitions to relationship
# Fixed  16 in 44
# Modifying line from  4 to 6
# the 'Resistance' to 'Behaviour change' Influences (*) relationship
# Fixed  51 in 45
# Modifying line from  12 to 15
# the 'Risk factors' to 'Problem behaviour' Influences relationship
# Fixed  31 in 47
# Modifying line from  3 to 18
# the 'Prospect' to 'Edited prospects' Transitions to relationship
# Fixed  37 in 48
# Modifying line from  21 to 28
# the 'Intending' to 'Behavioural schemata' Influences relationship
# Fixed  60 in 52
# Modifying line from  4 to 12
# the 'Phasic responses' to 'Substance use behaviour' Part of relationship
# Fixed  83 in 54
# Modifying line from  3 to 25
# the 'Sources of efficacy expectations' to 'Self-efficacy' Influences relationship
# Fixed  80 in 57
# Modifying line from  31 to 32
# the 'Outcome expectancies' to 'Behaviour' Influences relationship
# Fixed  85 in 57
# Modifying line from  16 to 13
# the 'Self-evaluation stage' to 'Self-reinforcement stage' Transitions to relationship
# Fixed  40 in 58
# Modifying line from  19 to 16
# the 'Self-monitoring stage' to 'Self-evaluation stage' Transitions to relationship
# Fixed  31 in 58
# Modifying line from  19 to 15
# the 'Validation' to 'Action' Transitions to relationship
# Fixed  31 in 59
# Modifying line from  4 to 15
# the 'Maintenance' to 'Action' Transitions to relationship
# Fixed  34 in 59
# Modifying line from  18 to 19
# the 'Preparation' to 'Validation' Transitions to relationship
# Fixed  30 in 59
# Modifying line from  8 to 18
# the 'Contemplation' to 'Preparation' Transitions to relationship
# Fixed  33 in 59
# Modifying line from  3 to 8
# the 'Pre-contemplation' to 'Contemplation' Transitions to relationship
# Fixed  52 in 59
# Modifying line from  8 to 5
# the 'Quasi-stationary equilibrium' to 'Unfreezing' Transitions to relationship
# Fixed  11 in 6
# Modifying line from  5 to 6
# the 'Unfreezing' to 'Moving' Transitions to relationship
# Fixed  12 in 6
# Modifying line from  6 to 7
# the 'Moving' to 'Freezing' Transitions to relationship
# Fixed  13 in 6
# Modifying line from  52 to 69
# the 'Self-regulatory resources' to 'Assets' Influences relationship
# Fixed  139 in 60
# Modifying line from  69 to 52
# the 'Assets' to 'Self-regulatory resources' Influences relationship
# Fixed  138 in 60
# Modifying line from  52 to 64
# the 'Self-regulatory resources' to 'Social power' Influences relationship
# Fixed  132 in 60
# Modifying line from  64 to 52
# the 'Social power' to 'Self-regulatory resources' Influences relationship
# Fixed  131 in 60
# Modifying line from  64 to 69
# the 'Social power' to 'Assets' Influences relationship
# Fixed  140 in 60
# Modifying line from  69 to 64
# the 'Assets' to 'Social power' Influences relationship
# Fixed  137 in 60
# Modifying line from  13 to 5
# the 'Vested interests' to 'Norms' Influences relationship
# Fixed  35 in 62
# Modifying line from  12 to 4
# the 'Social environment / consensus' to 'Behaviour' Influences relationship
# Fixed  18 in 64
# Modifying line from  9 to 10
# the 'Intention to change' to 'Behaviour change' Influences relationship
# Fixed  41 in 66
# Modifying line from  10 to 12
# the 'Antecedents / environmental factors' to 'Affordances/ Perceived environmental factors' Influences relationship
# Fixed  38 in 67
# Modifying line from  12 to 11
# the 'Affordances/ Perceived environmental factors' to 'Walking' Influences relationship
# Fixed  39 in 67
# Modifying line from  20 to 13
# the 'Social identity' to 'Inter-group differentiation' Influences relationship
# Fixed  33 in 68
# Modifying line from  27 to 30
# the 'Group norms' to 'Desires' Influences relationship
# Fixed  61 in 69
# Modifying line from  11 to 21
# the 'Self-referent values' to 'Social influences' Influences relationship
# Fixed  73 in 69
# Modifying line from  13 to 21
# the 'Group-referent values' to 'Social influences' Influences relationship
# Fixed  87 in 69
# Modifying line from  35 to 19
# the 'Health intention' to 'Behaviour change / maintenance' Influences relationship
# Fixed  107 in 72
# Modifying line from  18 to 6
# the 'Job relevance' to 'Perceived usefulness' Influences relationship
# Fixed  42 in 73
# Modifying line from  21 to 6
# the 'Subjective norm' to 'Perceived usefulness' Influences relationship
# Fixed  46 in 73
# Modifying line from  15 to 5
# the 'Computer anxiety' to 'Perceived ease of use' Influences relationship
# Fixed  38 in 73
# Modifying line from  16 to 5
# the 'Computer playfulness' to 'Perceived ease of use' Influences relationship
# Fixed  39 in 73
# Modifying line from  9 to 5
# the 'Perceived enjoyment' to 'Perceived ease of use' Influences relationship
# Fixed  40 in 73
# Modifying line from  10 to 5
# the 'Objective usability' to 'Perceived ease of use' Influences relationship
# Fixed  30 in 73
# Modifying line from  5 to 4
# the 'Perceived ease of use' to 'Behavioural intention' Influences relationship
# Fixed  25 in 73
# Modifying line from  5 to 6
# the 'Perceived ease of use' to 'Perceived usefulness' Influences relationship
# Fixed  53 in 73
# Modifying line from  21 to 4
# the 'Subjective norm' to 'Behavioural intention' Influences relationship
# Fixed  47 in 73
# Modifying line from  10 to 5
# Label not recognised:  ​+
# the 'Intentions' to 'Observed behaviour' ​+ relationship
# Fixed  24 in 74
# Modifying line from  6 to 8
# the 'Conscious' to 'Threat-avoidance outcomes' Influences relationship
# Fixed  21 in 76
# Modifying line from  6 to 10
# the 'Conscious' to 'Health behaviour-oriented outcomes' Influences relationship
# Fixed  22 in 76
# Modifying line from  5 to 12
# the 'Unconscious' to 'Health-defeating outcomes' Influences relationship
# Fixed  24 in 76
# Modifying line from  5 to 13
# the 'Unconscious' to 'Health-facilitating outcomes' Influences relationship
# Fixed  25 in 76
# Modifying line from  5 to 15
# the 'Unconscious' to 'Avoidance of body-oriented health behaviour' Influences relationship
# Fixed  28 in 76
# Modifying line from  7 to 5
# the 'Habit' to 'Acts / behaviour' Influences relationship
# Fixed  32 in 77
# Modifying line from  8 to 5
# the 'Specific behavioural intentions' to 'Acts / behaviour' Influences relationship
# Fixed  30 in 77
# Modifying line from  10 to 3
# the 'Descriptive norms' to 'Behaviour' Influences relationship
# Fixed  34 in 78
# Modifying line from  6 to 4
# the 'Perceived behavioural control' to 'Subjective norms' Influences relationship
# Fixed  27 in 79
# Modifying line from  3 to 9
# Label not recognised:  ​+
# the 'Intention' to 'Behaviour' ​+ relationship
# Fixed  30 in 79
# Modifying line from  5 to 15
# the 'Discursive and practical consciousness' to 'Lifestyles' Influences relationship
# Fixed  21 in 9

# %%
# write the files out again, fixed
for model_num in theory_row_dicts.keys():
    model_filename = model_filenames[model_num]+"MODIFIED"
    with codecs.open("theories_2025/processed/"+model_filename+".csv",mode='w', encoding="utf-8") as outfile:
        fieldNames = [k for k in theory_row_dicts[model_num]['1'].keys()]
        #print (model_num,fieldNames)
        writer = csv.DictWriter(outfile,fieldNames)
        writer.writeheader()
        for rowId in theory_row_dicts[model_num].keys():
            writer.writerow(theory_row_dicts[model_num][rowId])
